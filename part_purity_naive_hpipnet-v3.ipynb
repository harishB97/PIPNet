# %% [markdown]
# Supposed to be the cleaned version of v2. v2 works fine

# %%
import torch.nn as nn
import torch

import sys, os
import random
import numpy as np
from shutil import copy
import matplotlib.pyplot as plt
from copy import deepcopy

from omegaconf import OmegaConf
import shutil
import pickle
import random
from tqdm import tqdm

from torchvision.datasets.folder import ImageFolder
from torch.utils.data import DataLoader
# from skimage.filters import threshold_local, gaussian
import torch.nn.functional as F
import pdb

# %%
# len(nodeproto_overspecificity_score)

# nodeproto_overspecificity_score['129+043']

import torch
torch.cuda.is_available()
# Out:
# True

# %%
# 154 18 species Naive hpipnet with mask
# run_path = "runs/154-PruningNaiveHPIPNet_cnext13_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/162-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60_cnext13_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/163-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.2MinCont=0.1_cnext13_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/164-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext13_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/165-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=2.0MinCont=0.1_cnext13_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/166-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=2.0MinCont=0.1_cnext26_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/167-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/168-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-29-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/169-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=2.0MinCont=0.1_cnext26_CUB-29-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/170-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60MinCont=0.1_cnext26_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/171-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60MinCont=0.1_cnext26_CUB-29-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/172-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.1MinCont=0.1_cnext26_CUB-29-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/173-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.1MinCont=0.1_cnext26_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/176-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=2.0MinCont=0.1_cnext26_CUB-190-imgnet-224_with-equalize-aug_img=224_nprotos=20"

run_path = "/home/harishbabu/projects/PIPNet_wandb/runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/179-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-224_WeightedCE_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/180-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=2.0MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/181-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=2.0MinCont=0.1_cnext26_CUB-190-224_WeightedCE_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/182-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.1MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/183-PruningBF=1.1NaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/184-PruningBF=1.1NaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/192-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=05epsEps=85Cl=4.0NoTanhDescMinCont=0.5_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20"

# run_path = "runs/202-PruningBF=1.1NaiveHPIPNetMaskL1=0.5MaskTrainExtra=05epsEps=60Cl=2.0TanhDesc=0.05MinCont=0.1_cnext13_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=10pc"

# run_path = "/home/harishbabu/projects/PIPNet/runs/211-178cloneWithGeoMeanOvsp-PruningBF=1.1NaiveHPIPNetMaskL1=0.5MaskTrainExtra=05epsEps=60Cl=2.0TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=10pc"

# run_path = "runs/221-178like_nprotos=10pc-cnext26_PruningBF=1.1NaiveHPIPNetMaskL1=0.5MaskTrainExtra=05epsEps=60Cl=2.0TanhDesc=0.05NoMinCont_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224"

# run_path = "runs/223-NoAlTanH178like_nprotos=10pc-cnext26_PruningBF=1.1NaiveHPIPNetMaskL1=0.5MaskTrainExtra=05epsEps=60Cl=2.0TanhDesc=0.05MinCont=0.1_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224"

# run_path = "runs/224-NoOrth178like_nprotos=10pc-cnext26_PruningBF=1.1NaiveHPIPNetMaskL1=0.5MaskTrainExtra=05epsEps=60Cl=2.0TanhDesc=0.05MinCont=0.1_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224"

try:
    sys.path.remove('/home/harishbabu/projects/PIPNet')
except:
    pass
sys.path.insert(0, os.path.join(run_path, 'source_clone'))

print(run_path)
# Out:
# /home/harishbabu/projects/PIPNet_wandb/runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20

# %%
from pipnet.pipnet import PIPNet, get_network
from util.log import Log
from util.args import get_args, save_args, get_optimizer_nn
from util.data import get_dataloaders
from util.func import init_weights_xavier
from pipnet.train import train_pipnet, test_pipnet
# from pipnet.test import eval_pipnet, get_thresholds, eval_ood
from util.eval_cub_csv import eval_prototypes_cub_parts_csv, get_topk_cub, get_proto_patches_cub
from util.vis_pipnet import visualize, visualize_topk
from util.visualize_prediction import vis_pred, vis_pred_experiments
from util.node import Node
from util.phylo_utils import construct_phylo_tree, construct_discretized_phylo_tree
from util.func import get_patch_size
from util.data import ModifiedLabelLoader
# Out:
# Heatmaps showing where a prototype is found will not be generated because OpenCV is not installed.

# %% [markdown]
# # Load model

# %%
args_file = open(os.path.join(run_path, 'metadata', 'args.pickle'), 'rb')
args = pickle.load(args_file)

if args.phylo_config:
    phylo_config = OmegaConf.load(args.phylo_config)

if args.phylo_config:
    # construct the phylo tree
    if phylo_config.phyloDistances_string == 'None':
        if '031' in run_path: # this run uses a different phylogeny file that had an extra root node which is a mistake
            root = construct_phylo_tree('/home/harishbabu/data/phlyogenyCUB/18Species-with-extra-root-node/1_tree-consensus-Hacket-18Species-modified_cub-names_v1.phy')
        else:
            root = construct_phylo_tree(phylo_config.phylogeny_path)
        print('-'*25 + ' No discretization ' + '-'*25)
    else:
        root = construct_discretized_phylo_tree(phylo_config.phylogeny_path, phylo_config.phyloDistances_string)
        print('-'*25 + ' Discretized ' + '-'*25)
else:
    # construct the tree (original hierarchy as described in the paper)
    root = Node("root")
    root.add_children(['animal','vehicle','everyday_object','weapon','scuba_diver'])
    root.add_children_to('animal',['non_primate','primate'])
    root.add_children_to('non_primate',['African_elephant','giant_panda','lion'])
    root.add_children_to('primate',['capuchin','gibbon','orangutan'])
    root.add_children_to('vehicle',['ambulance','pickup','sports_car'])
    root.add_children_to('everyday_object',['laptop','sandal','wine_bottle'])
    root.add_children_to('weapon',['assault_rifle','rifle'])
    # flat root
    # root.add_children(['scuba_diver','African_elephant','giant_panda','lion','capuchin','gibbon','orangutan','ambulance','pickup','sports_car','laptop','sandal','wine_bottle','assault_rifle','rifle'])
root.assign_all_descendents()

exp_no = int(os.path.basename(run_path)[:3])

if exp_no < 77:
    if ('num_protos_per_descendant' in args) and (args.num_protos_per_descendant > 0):
        for node in root.nodes_with_children():
            node.set_num_protos(args.num_protos_per_descendant)
if exp_no == 77:
    # update num of protos per node based on num_protos_per_descendant
    if args.num_features == 0 and args.num_protos_per_descendant == 0:
        raise Exception('Either of num_features or num_protos_per_descendant must be greater than zero')
    for node in root.nodes_with_children():
        node.set_num_protos(num_protos_per_descendant=args.num_protos_per_descendant,\
                                                            min_protos=args.num_features)
else:
    if ('num_protos_per_child' in args) and ('num_protos_per_descendant' in args):
        if args.num_features == 0 and args.num_protos_per_descendant == 0 and args.num_protos_per_child == 0:
            raise Exception('Either of num_features or num_protos_per_descendant or num_protos_per_child must be greater than zero')
        for node in root.nodes_with_children():
            node.set_num_protos(num_protos_per_descendant=args.num_protos_per_descendant,\
                                num_protos_per_child=args.num_protos_per_child,\
                                min_protos=args.num_features,\
                                split_protos=('protopool' in args) and (args.protopool == 'n'))
    elif ('num_protos_per_descendant' in args):
        # update num of protos per node based on num_protos_per_descendant
        if args.num_features == 0 and args.num_protos_per_descendant == 0 and args.num_protos_per_child == 0:
            raise Exception('Either of num_features or num_protos_per_descendant or num_protos_per_child must be greater than zero')
        for node in root.nodes_with_children():
            node.set_num_protos(num_protos_per_descendant=args.num_protos_per_descendant,\
                                min_protos=args.num_features,\
                                split_protos=('protopool' in args) and (args.protopool == 'n'))
# Out:
# ------------------------- No discretization -------------------------

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    device_ids = [torch.cuda.current_device()]
else:
    device = torch.device('cpu')
    device_ids = []

# args_file = open(os.path.join(run_path, 'metadata', 'args.pickle'), 'rb')
# args = pickle.load(args_file)

args.batch_size = 1

# ckpt_file_name = 'net_overspecific_pruned_replaced_thresh=0.5_last'
ckpt_file_name = 'net_trained_last'
# ckpt_file_name = 'net_trained_10'
# ckpt_file_name = 'net_pretrained'
epoch = ckpt_file_name.split('_')[-1]

ckpt_path = os.path.join(run_path, 'checkpoints', ckpt_file_name)
checkpoint = torch.load(ckpt_path, map_location=device)

if ckpt_file_name != 'net_trained_last':
    print('\n', (10*'-')+'WARNING: Not using the final trained model'+(10*'-'), '\n')

# Obtain the dataset and dataloaders
trainloader, trainloader_pretraining, trainloader_normal, trainloader_normal_augment, projectloader, testloader, test_projectloader, classes = get_dataloaders(args, device)

print(args.batch_size, trainloader.batch_size)

if len(classes)<=20:
    if args.validation_size == 0.:
        print("Classes: ", testloader.dataset.class_to_idx, flush=True)
    else:
        print("Classes: ", str(classes), flush=True)

# Create a convolutional network based on arguments and add 1x1 conv layer
feature_net, add_on_layers, pool_layer, classification_layers, num_prototypes = get_network(len(classes), args, root=root)
   
# Create a PIP-Net
net = PIPNet(num_classes=len(classes),
                    num_prototypes=num_prototypes,
                    feature_net = feature_net,
                    args = args,
                    add_on_layers = add_on_layers,
                    pool_layer = pool_layer,
                    classification_layers = classification_layers,
                    num_parent_nodes = len(root.nodes_with_children()),
                    root = root
                    )
net = net.to(device=device)
net = nn.DataParallel(net, device_ids = device_ids)    
net.load_state_dict(checkpoint['model_state_dict'],strict=True)
# print(net.eval())
criterion = nn.NLLLoss(reduction='mean').to(device)
# Out:
# Dropping 0 samples from trainloader
# Dropping 0 samples from trainloader_normal
# Dropping 0 samples from trainloader_normal_augment
# Num classes (k) =  190 ['cub_001_Black_footed_Albatross', 'cub_002_Laysan_Albatross', 'cub_003_Sooty_Albatross', 'cub_004_Groove_billed_Ani', 'cub_005_Crested_Auklet'] etc.
# 1 1
# /home/harishbabu/.conda/envs/hpnet4/lib/python3.9/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Number of prototypes:  20
# ----------Prototypes per descendant: 0----------
# Assigned 20 protos to node root
# Assigned 20 protos to node 129+024+067
# Assigned 20 protos to node 089+046
# Assigned 20 protos to node 129+065
# Assigned 20 protos to node 024+051
# Assigned 20 protos to node 067+070
# Assigned 20 protos to node 089+090
# Assigned 20 protos to node 046+087
# Assigned 20 protos to node 129+192
# Assigned 20 protos to node 065+006
# Assigned 20 protos to node 024+031
# Assigned 20 protos to node 051+052
# Assigned 20 protos to node 067+068
# Assigned 20 protos to node 129+043
# Assigned 20 protos to node 192+081
# Assigned 20 protos to node 065+144
# Assigned 20 protos to node 006+071
# Assigned 20 protos to node 024+086
# Assigned 20 protos to node 031+004
# Assigned 20 protos to node 051+053
# Assigned 20 protos to node 067+069
# Assigned 20 protos to node 129+018
# Assigned 20 protos to node 043+078
# Assigned 20 protos to node 192+036
# Assigned 20 protos to node 081+083
# Assigned 20 protos to node 065+084
# Assigned 20 protos to node 144+147
# Assigned 20 protos to node 006+058
# Assigned 20 protos to node 071+072
# Assigned 20 protos to node 024+001
# Assigned 20 protos to node 031+032
# Assigned 20 protos to node 051+050
# Assigned 20 protos to node 129+107
# Assigned 20 protos to node 043+042
# Assigned 20 protos to node 078+038
# Assigned 20 protos to node 192+191
# Assigned 20 protos to node 036+188
# Assigned 20 protos to node 081+082
# Assigned 20 protos to node 065+061
# Assigned 20 protos to node 084+063
# Assigned 20 protos to node 144+143
# Assigned 20 protos to node 006+008
# Assigned 20 protos to node 024+100
# Assigned 20 protos to node 001+045
# Assigned 20 protos to node 031+033
# Assigned 20 protos to node 129+136
# Assigned 20 protos to node 107+151
# Assigned 20 protos to node 043+040
# Assigned 20 protos to node 078+041
# Assigned 20 protos to node 192+187
# Assigned 20 protos to node 191+189
# Assigned 20 protos to node 081+080
# Assigned 20 protos to node 082+079
# Assigned 20 protos to node 065+066
# Assigned 20 protos to node 061+064
# Assigned 20 protos to node 144+142
# Assigned 20 protos to node 006+005
# Assigned 20 protos to node 008+106
# Assigned 20 protos to node 024+023
# Assigned 20 protos to node 100+101
# Assigned 20 protos to node 001+003
# Assigned 20 protos to node 129+199
# Assigned 20 protos to node 136+085
# Assigned 20 protos to node 107+111
# Assigned 20 protos to node 151+153
# Assigned 20 protos to node 043+037
# Assigned 20 protos to node 040+102
# Assigned 20 protos to node 078+077
# Assigned 20 protos to node 192+190
# Assigned 20 protos to node 065+062
# Assigned 20 protos to node 144+145
# Assigned 20 protos to node 006+007
# Assigned 20 protos to node 024+025
# Assigned 20 protos to node 001+002
# Assigned 20 protos to node 129+118
# Assigned 20 protos to node 199+186
# Assigned 20 protos to node 136+138
# Assigned 20 protos to node 107+073
# Assigned 20 protos to node 111+112
# Assigned 20 protos to node 151+157
# Assigned 20 protos to node 153+154
# Assigned 20 protos to node 043+039
# Assigned 20 protos to node 065+059
# Assigned 20 protos to node 144+146
# Assigned 20 protos to node 129+104
# Assigned 20 protos to node 199+150
# Assigned 20 protos to node 186+185
# Assigned 20 protos to node 136+137
# Assigned 20 protos to node 107+093
# Assigned 20 protos to node 073+074
# Assigned 20 protos to node 151+156
# Assigned 20 protos to node 157+152
# Assigned 20 protos to node 153+155
# Assigned 20 protos to node 065+060
# Assigned 20 protos to node 144+141
# Assigned 20 protos to node 129+035
# Assigned 20 protos to node 199+094
# Assigned 20 protos to node 150+019
# Assigned 20 protos to node 107+030
# Assigned 20 protos to node 129+054
# Assigned 20 protos to node 035+055
# Assigned 20 protos to node 199+028
# Assigned 20 protos to node 150+149
# Assigned 20 protos to node 107+029
# Assigned 20 protos to node 129+175
# Assigned 20 protos to node 054+140
# Assigned 20 protos to node 035+048
# Assigned 20 protos to node 199+198
# Assigned 20 protos to node 150+091
# Assigned 20 protos to node 107+108
# Assigned 20 protos to node 129+011
# Assigned 20 protos to node 175+020
# Assigned 20 protos to node 054+057
# Assigned 20 protos to node 140+017
# Assigned 20 protos to node 035+056
# Assigned 20 protos to node 048+047
# Assigned 20 protos to node 199+194
# Assigned 20 protos to node 129+121
# Assigned 20 protos to node 011+013
# Assigned 20 protos to node 175+099
# Assigned 20 protos to node 054+014
# Assigned 20 protos to node 140+139
# Assigned 20 protos to node 035+034
# Assigned 20 protos to node 199+193
# Assigned 20 protos to node 129+117
# Assigned 20 protos to node 011+095
# Assigned 20 protos to node 013+088
# Assigned 20 protos to node 175+181
# Assigned 20 protos to node 054+016
# Assigned 20 protos to node 199+197
# Assigned 20 protos to node 193+195
# Assigned 20 protos to node 129+133
# Assigned 20 protos to node 117+114
# Assigned 20 protos to node 011+026
# Assigned 20 protos to node 095+096
# Assigned 20 protos to node 013+012
# Assigned 20 protos to node 175+168+173+183
# Assigned 20 protos to node 054+015
# Assigned 20 protos to node 199+196
# Assigned 20 protos to node 129+021
# Assigned 20 protos to node 133+130
# Assigned 20 protos to node 117+115
# Assigned 20 protos to node 011+049
# Assigned 20 protos to node 026+010
# Assigned 20 protos to node 095+098
# Assigned 20 protos to node 096+097
# Assigned 20 protos to node 175+162
# Assigned 20 protos to node 168+177
# Assigned 20 protos to node 173+161
# Assigned 20 protos to node 183+159
# Assigned 20 protos to node 129+128
# Assigned 20 protos to node 021+148
# Assigned 20 protos to node 133+076
# Assigned 20 protos to node 130+120
# Assigned 20 protos to node 117+116
# Assigned 20 protos to node 115+119
# Assigned 20 protos to node 011+009
# Assigned 20 protos to node 026+027
# Assigned 20 protos to node 175+167
# Assigned 20 protos to node 162+180
# Assigned 20 protos to node 168+200
# Assigned 20 protos to node 177+178
# Assigned 20 protos to node 173+179
# Assigned 20 protos to node 161+166
# Assigned 20 protos to node 183+184
# Assigned 20 protos to node 129+127
# Assigned 20 protos to node 128+131
# Assigned 20 protos to node 133+132
# Assigned 20 protos to node 175+169
# Assigned 20 protos to node 168+170
# Assigned 20 protos to node 173+172
# Assigned 20 protos to node 129+123
# Assigned 20 protos to node 128+124
# Assigned 20 protos to node 133+122
# Assigned 20 protos to node 175+165+182
# Assigned 20 protos to node 129+125
# Assigned 20 protos to node 123+113
# Assigned 20 protos to node 128+126
# Assigned 20 protos to node 175+160
# Assigned 20 protos to node 165+164+163
# Assigned 20 protos to node 175+176
# Assigned 20 protos to node 160+109
# Assigned 20 protos to node 165+158
# Assigned 20 protos to node 175+174

# %%
# Forward one batch through the backbone to get the latent output size
with torch.no_grad():
    xs1, _, _ = next(iter(trainloader))
    xs1 = xs1.to(device)
    _, proto_features, _, _ = net(xs1)
    wshape = proto_features['root'].shape[-1]
    args.wshape = wshape #needed for calculating image patch size
    print("Output shape: ", proto_features['root'].shape, flush=True)
    
print(args.wshape)
# Out:
# Output shape:  torch.Size([1, 20, 26, 26])
# 26

# %% [markdown]
# # Utils

# %%
from collections import defaultdict
import csv
import pandas as pd
import csv
import numpy as np
import pandas as pd
import os
from PIL import Image
from tqdm import tqdm
import torch
from util.func import get_patch_size
import csv
import torchvision.transforms as transforms
import torchvision
from util.vis_pipnet import get_img_coordinates


def get_topk_cub_nodewise(net, root, projectloader, k, epoch, device, args):   

    list_csvfile_topk = []
    list_node_wise_df = []
    dict_node_wise_df = {}

    if isinstance(projectloader.sampler, torch.utils.data.RandomSampler):
        raise Exception('Dataset should not be in shuffle')
    # Make sure the model is in evaluation mode
    net.eval()
    
    # IMPORTANT: dataloader should NOT be in shuffle, because imgs will not be shuffled, indexing wont be right
    name2label = projectloader.dataset.class_to_idx
    label2name = {label:name for name, label in name2label.items()}
    # Show progress on progress bar
    project_iter = tqdm(enumerate(projectloader),
                        total=len(projectloader),
                        desc='Collecting top-k Prototypes CUB parts',
                        mininterval=50.,
                        ncols=0)
    imgs = projectloader.dataset.imgs

    patchsize, skip = get_patch_size(args)

    scores_per_prototype = dict() # maps node.name -> proto_idx -> leaf_name -> list(topk)
    for node in root.nodes_with_children():
        scores_per_prototype[node.name] = defaultdict(lambda: defaultdict(list))

        # Iterate through the projection set
    for i, (xs, orig_y) in project_iter:
        xs= xs.to(device)

        # coarse_label = ys.item()
        leaf_label = orig_y.item()
        leaf_name = label2name[leaf_label]

        with torch.no_grad():
            # Use the model to classify this batch of input data
            _, pfs_dict, pooled_dict, _ = net(xs)

            for node in root.nodes_with_children():

                if leaf_name not in node.leaf_descendents:
                    continue

                classification_weights = getattr(net.module, '_'+node.name+'_classification').weight

                child_name = node.closest_descendent_for(leaf_name).name
                coarse_label = node.children_to_labels[child_name]
                coarse_label2name = {label: name for name, label in node.children_to_labels.items()}
                
                pfs = pfs_dict[node.name]
                pooled = pooled_dict[node.name]
                pooled = pooled.squeeze(0) 
                pfs = pfs.squeeze(0) 
                for p in range(pooled.shape[0]):

                    if (classification_weights[coarse_label, p].item() > 1e-3):
                        scores_per_prototype[node.name][p][leaf_label].append((i, pooled[p].item(), pfs[p,:,:]))
    
    csvfolderpath = os.path.join(args.log_dir, f'node_wise_top{k}')
    os.makedirs(csvfolderpath, exist_ok=True)

    for node in root.nodes_with_children():
        proto_img_coordinates = []
        proto_img_coordinates_df = []
        csvfilepath = os.path.join(csvfolderpath, f'{node.name}_prototypes_top{k}_{str(epoch)}.csv')
        print('csv filepath:', csvfilepath)
        too_small = set()
        protoype_iter = tqdm(enumerate(scores_per_prototype[node.name].keys()), total=len(list(scores_per_prototype[node.name].keys())),mininterval=5.,ncols=0,desc='Collecting top-k patch coordinates CUB')
        with open(csvfilepath, "w", newline='') as csvfile:
            print("Writing CSV file with top k image patches..", flush=True)
            writer = csv.writer(csvfile, delimiter=',')
            writer.writerow(["node", "child", "leaf", "prototype", \
                             "img name", "h_min_224", "h_max_224", \
                             "w_min_224", "w_max_224", "scores"])
            for _, prototype in protoype_iter:
                for leaf_label in scores_per_prototype[node.name][prototype]:
                    leaf_descendent_name = label2name[leaf_label]
                    child_name = node.closest_descendent_for(leaf_descendent_name).name
                    leaf_descendent_name = leaf_descendent_name[4:7] # taking only the number from class name
                    df = pd.DataFrame(scores_per_prototype[node.name][prototype][leaf_label], columns=['img_id', 'scores', 'latent_activation'])
                    topk = df.nlargest(k, 'scores')
                    for index, row in topk.iterrows():
                        imgid = int(row['img_id'])
                        imgname = imgs[imgid][0]
                        with torch.no_grad():
                            if row['scores'] < 0.1:
                                too_small.add(p)
                                
                            location_h, location_h_idx = torch.max(row['latent_activation'], dim=0)
                            _, location_w_idx = torch.max(location_h, dim=0)
                            location = (location_h_idx[location_w_idx].item(), location_w_idx.item())
                            h_coor_min, h_coor_max, w_coor_min, w_coor_max = get_img_coordinates(args.image_size, row['latent_activation'].unsqueeze(0).shape, \
                                                                                                 patchsize, skip, location[0], location[1])
                            
                            proto_img_coordinates.append([node.name, child_name, leaf_descendent_name, \
                                                          prototype, imgname, h_coor_min, h_coor_max, \
                                                          w_coor_min, w_coor_max, row['scores']])
                            proto_img_coordinates_df.append([node.name, child_name, leaf_descendent_name, \
                                                          prototype, imgname, h_coor_min, h_coor_max, \
                                                          w_coor_min, w_coor_max, row['scores'], row['latent_activation']])
                # write intermediate results in case of large dataset
                if len(proto_img_coordinates) > 10000:
                    writer.writerows(proto_img_coordinates)
                    proto_img_coordinates = []
            print("Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes", too_small, flush=True)
    
            writer.writerows(proto_img_coordinates) 
        # do something about this
        df = pd.DataFrame(proto_img_coordinates_df, columns=["node", "child", "leaf", "prototype", \
                                                         "img name", "h_min_224", "h_max_224", \
                                                         "w_min_224", "w_max_224", "scores", 'latent_activation'])
        list_csvfile_topk.append(csvfilepath)
        list_node_wise_df.append(df)
        dict_node_wise_df[node.name] = df
    # return df
    return list_csvfile_topk, list_node_wise_df, dict_node_wise_df

def eval_prototypes_cub_parts_csv_nodewise_maxmin(node, csvfile, parts_loc_path, parts_name_path, imgs_id_path, epoch, args, desc_threshold=0, log=None):
    patchsize, _ = get_patch_size(args)
    imgresize = float(args.image_size)
    path_to_id = dict()
    id_to_path = dict()
    with open(imgs_id_path) as f:
        for line in f:
            id, path = line.split('\n')[0].split(' ')
            path_to_id[path]=id
            id_to_path[id]=path

    img_to_part_xy_vis = dict()
    with open(parts_loc_path) as f:
        for line in f:
            img, partid, x, y, vis = line.split('\n')[0].split(' ')
            vis = str(int(float(vis)))
            x =float(x)
            y =float(y)
            if x > 1.06 or y > 1.05:
                raise Exception('Provide normalized coordinated for part loc')
            if img not in img_to_part_xy_vis.keys():
                img_to_part_xy_vis[img]=dict()
            if vis == '1':
                img_to_part_xy_vis[img][partid]=(x,y)

    parts_id_to_name = dict()
    parts_name_to_id = dict()
    with open (parts_name_path) as f:
        for line in f:
            id, name = line.split('\n')[0].split(' ',1)
            parts_id_to_name[id]=name
            parts_name_to_id[name]=id
#     print(parts_id_to_name)

    # merge left and right cub parts
    duplicate_part_ids = []
    with open (parts_name_path) as f:
        for line in f:
            id, name = line.split('\n')[0].split(' ',1)
            if 'left' in name:
                new_name = name.replace('left', 'right')
                
                duplicate_part_ids.append((id, parts_name_to_id[new_name]))
           
    proto_parts_presences = dict()
    child_name_to_protos = defaultdict(set)
    
    with open (csvfile, newline='') as f:
        filereader = csv.reader(f, delimiter=',')
        next(filereader) #skip header
        for (node_name, child_name, leaf_descendant_name, prototype, imgname, h_min_224, h_max_224, w_min_224, w_max_224, scores) in filereader:
            child_name_to_protos[child_name].add(prototype)
            
            if prototype not in proto_parts_presences.keys():
                proto_parts_presences[prototype]=dict()
            if leaf_descendant_name not in proto_parts_presences[prototype].keys():
                proto_parts_presences[prototype][leaf_descendant_name]=dict()
            p = prototype
            img = Image.open(imgname)
            imgname = imgname.replace('\\', '/')
            imgnamec, imgnamef = imgname.split('/')[-2:]
            if 'normal_' in imgnamef:
                imgnamef = imgnamef.split('normal_')[-1]
            imgname = imgnamec+'/'+imgnamef
            img_id = path_to_id[imgname]
            img_orig_width, img_orig_height = img.size
            h_min_224, h_max_224, w_min_224, w_max_224 = float(h_min_224), float(h_max_224), float(w_min_224), float(w_max_224)
            
            
            diffh = h_max_224 - h_min_224
            diffw = w_max_224 - w_min_224
            if diffh > patchsize: #patch size too big, we take the center. otherwise the bigger the patch, the higher the purity.
                correction = diffh-patchsize
                h_min_224 = h_min_224 + correction//2.
                h_max_224 = h_max_224 - correction//2.
            if diffw > patchsize:
                correction = diffw-patchsize
                w_min_224 = w_min_224 + correction//2.
                w_max_224 = w_max_224 - correction//2.

            normalized_h_min = (h_min_224/imgresize) 
            normalized_h_max = (h_max_224/imgresize) 
            normalized_w_min = (w_min_224/imgresize) 
            normalized_w_max = (w_max_224/imgresize) 
                        
            part_dict_img = img_to_part_xy_vis[img_id]
            for part in part_dict_img.keys():
                x,y = part_dict_img[part]                
                part_in_patch = 0 
                if y >= normalized_h_min and y <= normalized_h_max:
                    if x >= normalized_w_min and x <= normalized_w_max:
                        part_in_patch = 1
                if part not in proto_parts_presences[p][leaf_descendant_name].keys():
                    proto_parts_presences[p][leaf_descendant_name][part]=[]
                    
                proto_parts_presences[p][leaf_descendant_name][part].append(part_in_patch)
            
            for pair in duplicate_part_ids:
                if pair[0] in part_dict_img.keys():
                    if pair[1] in part_dict_img.keys():
                        presence0 = proto_parts_presences[p][leaf_descendant_name][pair[0]][-1]
                        presence1 = proto_parts_presences[p][leaf_descendant_name][pair[1]][-1]
                        if presence0 > presence1: 
                            proto_parts_presences[p][leaf_descendant_name][pair[1]][-1] = presence0

                        del proto_parts_presences[p][leaf_descendant_name][pair[0]]
                    else:

                        if pair[1] not in proto_parts_presences[p][leaf_descendant_name].keys():
                            proto_parts_presences[p][leaf_descendant_name][pair[1]]=[]
                        proto_parts_presences[p][leaf_descendant_name][pair[1]].append(proto_parts_presences[p][leaf_descendant_name][pair[0]][-1])
                        del proto_parts_presences[p][leaf_descendant_name][pair[0]]
                        
    print("Number of prototypes in parts_presences: ", len(proto_parts_presences.keys()), flush=True)
    
    prototypes_part_related = 0
    max_presence_purity = dict()
    max_presence_purity_part = dict()
    max_presence_purity_sum = dict()

    most_often_present_purity = dict()
    part_most_present = dict()

    # for each of a proto taking the least occurence with respect to topk from each descendant
    proto_parts_presences_copy = dict()
    for proto in proto_parts_presences.keys():
        proto_parts_presences_copy[proto] = dict()
        for part in part_dict_img.keys():
            proto_parts_presences_copy[proto][part] = None
            for leaf_descendant_name in proto_parts_presences[proto].keys():

                # to avoid the keyvalue error
                if part not in proto_parts_presences[proto][leaf_descendant_name]:
                    continue
                
                if proto_parts_presences_copy[proto][part] is None:
                    proto_parts_presences_copy[proto][part] = proto_parts_presences[proto][leaf_descendant_name][part]
                else:
                    if np.array(proto_parts_presences_copy[proto][part]).sum() > np.array(proto_parts_presences[proto][leaf_descendant_name][part]).sum():
                        proto_parts_presences_copy[proto][part] = proto_parts_presences[proto][leaf_descendant_name][part]
            if proto_parts_presences_copy[proto][part] is None:
                # meaning the part did not occur in any of the descendant
                del proto_parts_presences_copy[proto][part]
    proto_parts_presences = proto_parts_presences_copy
    
    for proto in proto_parts_presences.keys():
        
        max_presence_purity[proto]= 0.
        part_most_present[proto] = ('0',0)
        most_often_present_purity[proto] = 0.

        # CUB parts 7,8 and 9 are  duplicate (right and left). additional check that these should not occur (already fixed earlier in this function)
        if ('7' in proto_parts_presences[proto].keys() or '8' in proto_parts_presences[proto].keys() or '9' in proto_parts_presences[proto].keys()):
            print("unused part in keys! ", proto, proto_parts_presences[proto].keys(), proto_parts_presences[proto], flush=True)
            raise ValueError()
        
        for part in proto_parts_presences[proto].keys():
            presence_purity = np.mean(proto_parts_presences[proto][part])
            sum_occurs = np.array(proto_parts_presences[proto][part]).sum()
        
            # evaluate whether the purity of this prototype for this part is higher than for other parts
            if presence_purity > max_presence_purity[proto]:
                max_presence_purity[proto]=presence_purity
                max_presence_purity_part[proto]=parts_id_to_name[part]
                max_presence_purity_sum[proto] = sum_occurs
            elif presence_purity == max_presence_purity[proto]:
                if presence_purity == 0.:
                    max_presence_purity[proto]=presence_purity
                    max_presence_purity_part[proto]=parts_id_to_name[part]
                    max_presence_purity_sum[proto] = sum_occurs
                elif sum_occurs > max_presence_purity_sum[proto]:
                    max_presence_purity[proto]=presence_purity
                    max_presence_purity_part[proto]=parts_id_to_name[part]
                    max_presence_purity_sum[proto] = sum_occurs
        
            if sum_occurs > part_most_present[proto][1]:
                part_most_present[proto] = (part, sum_occurs)
                most_often_present_purity[proto]=presence_purity         
        if max_presence_purity[proto] > 0.5:
            prototypes_part_related += 1 
        
            
    print(f"Part-related (purity>0.5): {prototypes_part_related}", flush=True)
    purity_of_child = {}
    for child_name in child_name_to_protos:
        purity_of_child[child_name] = np.mean([max_presence_purity[p] for p in child_name_to_protos[child_name]])
        std = np.std([max_presence_purity[p] for p in child_name_to_protos[child_name]])
        num_descendants = node.get_node(child_name).num_leaf_descendents()
        print('Node:', node.name, '| Child:', child_name, '| Purity:', purity_of_child[child_name], '| Num desc:', num_descendants, '| Num protos:', len(child_name_to_protos[child_name]))
        for p in child_name_to_protos[child_name]:
            print('\tProto:', p, max_presence_purity[p])

    if log:
        log.log_values('log_epoch_overview', "p_cub_"+str(epoch), "mean purity (averaged over all prototypes, corresponding to purest part)", "std purity", "mean purity (averaged over all prototypes, corresponding to part with most often overlap)", "std purity", "# prototypes in csv", "#part-related prototypes (purity > 0.5)","","")

        log.log_values('log_epoch_overview', "p_cub_"+str(epoch), np.mean(list(max_presence_purity.values())), np.std(list(max_presence_purity.values())), np.mean(list(most_often_present_purity.values())), np.std(list(most_often_present_purity.values())), len(list(proto_parts_presences.keys())), prototypes_part_related, "", "")

    overall_node_purity = np.mean([max_presence_purity[p] for child_name in child_name_to_protos for p in child_name_to_protos[child_name]])
    return overall_node_purity, max_presence_purity

# %% [markdown]
# # Find subtree root - only for finding does not affect the run, use the value found here in the visualization block

# %%
leaf_descendents = set(['cub_052_Pied_billed_Grebe', 'cub_004_Groove_billed_Ani'])
subtree_root = root
for node in root.nodes_with_children():
    if leaf_descendents.issubset(node.leaf_descendents) and (len(node.leaf_descendents) < len(subtree_root.leaf_descendents)):
        subtree_root = node
# root.get_node('053+004')
print(subtree_root.name)
# 024+051 for CUB-18
# Out:
# 024+051

# %% [markdown]
# # Hyperparameters

# %%
TOPK = 10
maindataloader = testloader # projectloader, trainloader_normal, trainloader_normal_augment, projectloader, testloader, test_projectloader
subtree_root = root#.get_node('024+051')

# %% [markdown]
# # For PIPNet

# %%
try:
    projectset_img0_path = maindataloader.dataset.samples[0][0]
except:
    projectset_img0_path = maindataloader.dataset.dataset.samples[0][0]

parts_name_path = '/projects/ml4science/harishbabu/data/CUB_200_2011/parts/parts.txt'
imgs_id_path = '/projects/ml4science/harishbabu/data/CUB_200_2011/images_cub.txt'
print(projectset_img0_path)
# print(project_path)
# Out:
# /projects/ml4science/harishbabu/data/CUB_190_pt_224/dataset_segmented_imgnet_pt/test_segmented_imagenet_background_crop/cub_001_Black_footed_Albatross/Black_Footed_Albatross_0001_796111.jpg

# %%
image_meta_file_base_path = os.path.dirname(os.path.dirname(projectset_img0_path))
image_meta_filepath = os.path.join(image_meta_file_base_path, 'image_meta_file.json')

import json

with open(image_meta_filepath, 'r') as file:
    image_meta = json.load(file)
    
print(image_meta)
# Out:
# {'cropped': True, 'padded': True, 'segmented': True, 'imagenet_background': True, 'sample_class_name': 'cub_001_Black_footed_Albatross'}

# %%
dataset_path = '/projects/ml4science/harishbabu/data/CUB_200_2011/'  # part locs are loaded from here

if image_meta['cropped'] and image_meta['padded']:
    part_locs_file = os.path.join(dataset_path, 'parts', 'part_locs_normalized_after_cropped_after_padded.txt') 
    print('*-'*40)
    print('\t\t\tIMPORTANT: Using CROPPED and PADDED part locations')
    print('*-'*40)
elif not image_meta['cropped'] and image_meta['padded']:
    part_locs_file = os.path.join(dataset_path, 'parts', 'part_locs_normalized_after_padded.txt') 
    print('*-'*40)
    print('\t\t\tIMPORTANT: Using NOT CROPPED and PADDED part locations')
    print('*-'*40)
elif image_meta['cropped'] and not image_meta['padded']:
    part_locs_file = os.path.join(dataset_path, 'parts', 'part_locs_normalized_after_cropped.txt') 
    print('*-'*40)
    print('\t\t\tIMPORTANT: Using CROPPED and NOT PADDED part locations')
    print('*-'*40)
elif not image_meta['cropped'] and not image_meta['padded']:
    part_locs_file = os.path.join(dataset_path, 'parts', 'part_locs_normalized.txt') 
    print('*-'*40)
    print('\t\t\tIMPORTANT: Using NOT CROPPED and NOT PADDED part locations')
    print('*-'*40)
# Out:
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# 			IMPORTANT: Using CROPPED and PADDED part locations
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-

# %%
import ntpath
NUM_PARTS = 15
images_file = os.path.join(dataset_path, 'images_cub.txt')

# Read the image index to filename mapping
img_filename_to_index = {} # image filename to image index
with open(images_file, 'r') as file:
    for line in file:
        index, filename = line.strip().split()
        img_filename = ntpath.basename(filename)
        img_filename_to_index[img_filename] = int(index)

# Load part locations
image_part_locs = defaultdict(list)
with open(part_locs_file, 'r') as file:
    for line in file:
        parts = line.strip().split()
        image_index, part_id, x, y, visible = int(parts[0]), int(parts[1]), float(parts[2]), float(parts[3]), bool(float(parts[4]))
        image_part_locs[image_index].append((part_id, x, y, visible))

# %%
def unshuffle_dataloader(dataloader, batch_size=1):
    if type(dataloader.dataset) == ImageFolder:
        dataset = dataloader.dataset
    else:
        dataset = dataloader.dataset.dataset#.dataset
    new_dataloader = DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=dataloader.num_workers,
        pin_memory=dataloader.pin_memory,
        drop_last=dataloader.drop_last,
        timeout=dataloader.timeout,
        worker_init_fn=dataloader.worker_init_fn,
        multiprocessing_context=dataloader.multiprocessing_context,
        generator=dataloader.generator,
        prefetch_factor=dataloader.prefetch_factor,
        persistent_workers=dataloader.persistent_workers
    )
    return new_dataloader

maindataloader = unshuffle_dataloader(maindataloader, batch_size=1)
print(maindataloader.batch_size)

# %% [markdown]
# # Calculate part purity

# %% [markdown]
# ## Create the CSV file with info about the Top-K image patches

# %%
list_csvfile_topk, list_node_wise_df, dict_node_wise_df = get_topk_cub_nodewise(net, root, maindataloader, \
                                                                                 TOPK, str(epoch), device, args)
# Out:
# Collecting top-k Prototypes CUB parts: 100% 5512/5512 [04:07<00:00, 22.23it/s]
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/root_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/9 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 9/9 [00:02<00:00,  4.45it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+024+067_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00,  9.08it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/089+046_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/9 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 9/9 [00:00<00:00, 177.98it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+065_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:01<00:00,  5.65it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/024+051_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/11 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 11/11 [00:00<00:00, 39.99it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/067+070_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 152.39it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/089+090_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 270.96it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/046+087_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 303.66it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+192_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/12 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 12/12 [00:01<00:00,  6.35it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/065+006_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/12 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 12/12 [00:00<00:00, 29.95it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/024+031_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/12 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 12/12 [00:00<00:00, 50.66it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/051+052_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 167.84it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/067+068_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 208.19it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+043_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:01<00:00,  6.79it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/192+081_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/12 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 12/12 [00:00<00:00, 62.35it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/065+144_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/10 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 10/10 [00:00<00:00, 46.23it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/006+071_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/9 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 9/9 [00:00<00:00, 88.46it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/024+086_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/13 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 13/13 [00:00<00:00, 63.91it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/031+004_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 148.89it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/051+053_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 212.32it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/067+069_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 322.66it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+018_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/12 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 12/12 [00:01<00:00,  6.50it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/043+078_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:00<00:00, 74.58it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/192+036_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 99.37it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/081+083_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 116.32it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/065+084_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 69.49it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/144+147_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/9 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 9/9 [00:00<00:00, 98.23it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/006+058_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/9 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 9/9 [00:00<00:00, 100.17it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/071+072_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 289.14it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/024+001_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/10 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 10/10 [00:00<00:00, 80.87it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/031+032_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 211.50it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/051+050_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 322.84it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+107_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:01<00:00,  6.50it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/043+042_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:00<00:00, 91.56it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/078+038_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 151.27it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/192+191_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 140.16it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/036+188_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 302.21it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/081+082_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:00<00:00, 179.91it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/065+061_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/9 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 9/9 [00:00<00:00, 100.22it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/084+063_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 324.29it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/144+143_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/9 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 9/9 [00:00<00:00, 100.64it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/006+008_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 133.62it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/024+100_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/9 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 9/9 [00:00<00:00, 138.60it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/001+045_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:00<00:00, 160.13it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/031+033_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 299.53it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+136_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:01<00:00,  7.51it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/107+151_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/12 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 12/12 [00:00<00:00, 46.13it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/043+040_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/9 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 9/9 [00:00<00:00, 136.89it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/078+041_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 205.61it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/192+187_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 216.39it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/191+189_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 299.94it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/081+080_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 301.45it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/082+079_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 309.57it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/065+066_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:00<00:00, 126.40it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/061+064_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 302.30it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/144+142_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:00<00:00, 126.33it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/006+005_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 211.41it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/008+106_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 305.94it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/024+023_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 217.66it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/100+101_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 257.76it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/001+003_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 186.49it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+199_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:00<00:00, 11.95it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/136+085_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 173.57it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/107+111_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/10 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 10/10 [00:00<00:00, 67.95it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/151+153_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/8 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 8/8 [00:00<00:00, 103.54it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/043+037_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 225.08it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/040+102_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 280.82it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/078+077_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 312.12it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/192+190_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 308.97it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/065+062_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 150.94it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/144+145_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 173.94it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/006+007_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 319.30it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/024+025_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 296.53it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/001+002_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 297.30it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+118_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 10.74it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes {19}
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/199+186_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/10 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 10/10 [00:00<00:00, 43.67it/s]
# ...
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/162+180_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 287.89it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/168+200_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 220.99it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/177+178_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 293.03it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/173+179_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 203.95it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/161+166_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 289.69it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/183+184_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 306.28it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+127_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 114.34it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/128+131_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 156.01it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/133+132_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 203.86it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/175+169_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/10 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 10/10 [00:00<00:00, 50.79it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/168+170_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 243.10it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/173+172_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 300.46it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+123_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 174.85it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/128+124_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/3 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 3/3 [00:00<00:00, 188.23it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/133+122_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 311.64it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/175+165+182_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/10 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 10/10 [00:00<00:00, 107.64it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/129+125_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 318.25it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/123+113_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 314.92it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/128+126_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/5 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 5/5 [00:00<00:00, 310.92it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath:
#  ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/175+160_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 139.51it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/165+164+163_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 265.11it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/175+176_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/7 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 7/7 [00:00<00:00, 220.55it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/160+109_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/6 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 6/6 [00:00<00:00, 318.42it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/165+158_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/3 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 3/3 [00:00<00:00, 278.90it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()
# csv filepath: ./runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20/node_wise_top10/175+174_prototypes_top10_last.csv
# Collecting top-k patch coordinates CUB:   0% 0/4 [00:00<?, ?it/s]
# Writing CSV file with top k image patches..
# Collecting top-k patch coordinates CUB: 100% 4/4 [00:00<00:00, 300.67it/s]
# Warning: image patches included in topk, but similarity < 0.1! This might unfairly reduce the purity metric because prototype has less than k similar image patches. You could consider reducing k for prototypes set()

# %% [markdown]
# ## Calculate part purity from the created CSV files

# %%
node_wise_purity = []
node_wise_purity_of_unmasked = []
node_wise_purity_of_masked = []
for csvfile_topk, node in zip(list_csvfile_topk, root.nodes_with_children()):

    if node.name not in subtree_root.descendents:
        print('Skipping node', node.name)
        continue
        
    node_purity, max_presence_purity = eval_prototypes_cub_parts_csv_nodewise_maxmin(node, csvfile_topk, part_locs_file, parts_name_path, \
                              imgs_id_path, 'projectloader_topk_'+str(epoch), args, desc_threshold=0.2)
    node_wise_purity.append(node_purity)
    proto_presence = getattr(net.module, '_'+node.name+'_proto_presence')
    node_wise_purity_of_unmasked.append(np.mean([max_presence_purity[p] for p in max_presence_purity if (proto_presence[int(p), 0] < proto_presence[int(p), 1])]))
    node_wise_purity_of_masked.append(np.mean([max_presence_purity[p] for p in max_presence_purity if (proto_presence[int(p), 0] > proto_presence[int(p), 1])]))
# Out:
# Skipping node root
# Number of prototypes in parts_presences:  13
# Part-related (purity>0.5): 5
# Node: 129+024+067 | Child: 024+051 | Purity: 0.2 | Num desc: 18 | Num protos: 5
# 	Proto: 14 0.0
# 	Proto: 12 0.0
# 	Proto: 19 0.0
# 	Proto: 11 0.1111111111111111
# 	Proto: 15 0.8888888888888888
# Node: 129+024+067 | Child: 129+065 | Purity: 0.3 | Num desc: 164 | Num protos: 6
# 	Proto: 8 0.0
# 	Proto: 1 0.3333333333333333
# 	Proto: 0 0.6666666666666666
# 	Proto: 4 0.2
# 	Proto: 5 0.6
# 	Proto: 9 0.0
# Node: 129+024+067 | Child: 067+070 | Purity: 0.9 | Num desc: 4 | Num protos: 2
# 	Proto: 21 1.0
# 	Proto: 29 0.8
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 7
# Node: 089+046 | Child: 046+087 | Purity: 0.7 | Num desc: 2 | Num protos: 4
# 	Proto: 11 0.7
# 	Proto: 18 1.0
# 	Proto: 17 0.1
# 	Proto: 15 1.0
# Node: 089+046 | Child: 089+090 | Purity: 0.925 | Num desc: 2 | Num protos: 4
# 	Proto: 3 0.9
# 	Proto: 7 0.9
# 	Proto: 4 0.9
# 	Proto: 9 1.0
# /home/harishbabu/.conda/envs/hpnet4/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/harishbabu/.conda/envs/hpnet4/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Number of prototypes in parts_presences:  14
# Part-related (purity>0.5): 2
# Node: 129+065 | Child: 065+006 | Purity: 0.22857142857142856 | Num desc: 24 | Num protos: 7
# 	Proto: 14 0.5555555555555556
# 	Proto: 18 0.2
# 	Proto: 13 0.1
# 	Proto: 12 0.4444444444444444
# 	Proto: 19 0.0
# 	Proto: 11 0.3
# 	Proto: 16 0.0
# Node: 129+065 | Child: 129+192 | Purity: 0.3523809523809524 | Num desc: 140 | Num protos: 7
# 	Proto: 8 0.4444444444444444
# 	Proto: 0 0.5555555555555556
# 	Proto: 3 0.16666666666666666
# 	Proto: 7 0.4
# 	Proto: 5 0.4
# 	Proto: 2 0.0
# 	Proto: 9 0.5
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 4
# Node: 024+051 | Child: 024+031 | Purity: 0.25 | Num desc: 14 | Num protos: 6
# 	Proto: 8 0.0
# 	Proto: 0 0.0
# 	Proto: 3 0.0
# 	Proto: 7 0.0
# 	Proto: 5 0.875
# 	Proto: 2 0.625
# Node: 024+051 | Child: 051+052 | Purity: 0.45 | Num desc: 4 | Num protos: 4
# 	Proto: 10 0.0
# 	Proto: 19 0.9
# 	Proto: 12 0.9
# 	Proto: 17 0.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 5
# Node: 067+070 | Child: 067+068 | Purity: 0.7749999999999999 | Num desc: 3 | Num protos: 4
# 	Proto: 0 0.9
# 	Proto: 2 0.5
# 	Proto: 4 1.0
# 	Proto: 6 0.7
# Node: 067+070 | Child: cub_070_Green_Violetear | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 14 1.0
# 	Proto: 12 0.9
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 089+090 | Child: cub_089_Hooded_Merganser | Purity: 0.9666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 0 1.0
# 	Proto: 2 0.9
# 	Proto: 6 1.0
# Node: 089+090 | Child: cub_090_Red_breasted_Merganser | Purity: 1.0 | Num desc: 1 | Num protos: 3
# 	Proto: 10 1.0
# 	Proto: 11 1.0
# 	Proto: 12 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 046+087 | Child: cub_046_Gadwall | Purity: 1.0 | Num desc: 1 | Num protos: 3
# 	Proto: 6 1.0
# 	Proto: 2 1.0
# 	Proto: 9 1.0
# Node: 046+087 | Child: cub_087_Mallard | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 18 0.9
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  12
# Part-related (purity>0.5): 5
# Node: 129+192 | Child: 129+043 | Purity: 0.3333333333333333 | Num desc: 128 | Num protos: 6
# 	Proto: 1 0.4
# 	Proto: 0 0.1
# 	Proto: 4 0.1
# 	Proto: 3 0.4
# 	Proto: 5 0.6
# 	Proto: 6 0.4
# Node: 129+192 | Child: 192+081 | Purity: 0.5259259259259259 | Num desc: 12 | Num protos: 6
# 	Proto: 13 0.3
# 	Proto: 17 0.5555555555555556
# 	Proto: 19 0.4
# 	Proto: 11 0.7
# 	Proto: 16 0.6
# 	Proto: 15 0.6
# Number of prototypes in parts_presences:  12
# Part-related (purity>0.5): 5
# Node: 065+006 | Child: 006+071 | Purity: 0.175 | Num desc: 8 | Num protos: 4
# 	Proto: 15 0.0
# 	Proto: 14 0.3
# 	Proto: 13 0.4
# 	Proto: 17 0.0
# Node: 065+006 | Child: 065+144 | Purity: 0.5736111111111112 | Num desc: 16 | Num protos: 8
# 	Proto: 8 0.6666666666666666
# 	Proto: 0 0.2222222222222222
# 	Proto: 3 0.0
# 	Proto: 7 0.8
# 	Proto: 5 0.9
# 	Proto: 6 0.8
# 	Proto: 2 0.7
# 	Proto: 9 0.5
# Number of prototypes in parts_presences:  14
# Part-related (purity>0.5): 10
# Node: 024+031 | Child: 024+086 | Purity: 0.5916666666666667 | Num desc: 10 | Num protos: 8
# 	Proto: 8 0.2222222222222222
# 	Proto: 0 0.8
# 	Proto: 4 0.7777777777777778
# 	Proto: 3 0.2222222222222222
# 	Proto: 7 0.2222222222222222
# 	Proto: 5 0.8888888888888888
# 	Proto: 6 0.8
# 	Proto: 9 0.8
# Node: 024+031 | Child: 031+004 | Purity: 0.7301587301587302 | Num desc: 4 | Num protos: 6
# 	Proto: 14 0.9
# 	Proto: 18 0.7142857142857143
# 	Proto: 13 0.9
# 	Proto: 12 1.0
# 	Proto: 10 0.6666666666666666
# 	Proto: 15 0.2
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node:
666666666667 | Num desc: 2 | Num protos: 3
# 	Proto: 10 1.0
# 	Proto: 15 0.9
# 	Proto: 14 1.0
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 10
# Node: 151+153 | Child: 151+157 | Purity: 0.8648148148148148 | Num desc: 4 | Num protos: 6
# 	Proto: 0 0.9
# 	Proto: 3 0.7
# 	Proto: 5 1.0
# 	Proto: 6 0.8888888888888888
# 	Proto: 2 0.7
# 	Proto: 9 1.0
# Node: 151+153 | Child: 153+154 | Purity: 0.925 | Num desc: 3 | Num protos: 4
# 	Proto: 13 1.0
# 	Proto: 16 0.9
# 	Proto: 12 1.0
# 	Proto: 19 0.8
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 5
# Node: 043+037 | Child: cub_037_Acadian_Flycatcher | Purity: 0.6534722222222222 | Num desc: 1 | Num protos: 4
# 	Proto: 10 0.8888888888888888
# 	Proto: 19 0.625
# 	Proto: 14 0.1
# 	Proto: 17 1.0
# Node: 043+037 | Child: 043+039 | Purity: 0.6111111111111112 | Num desc: 2 | Num protos: 3
# 	Proto: 5 0.5555555555555556
# 	Proto: 1 0.5
# 	Proto: 9 0.7777777777777778
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 040+102 | Child: cub_040_Olive_sided_Flycatcher | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 6 0.6
# 	Proto: 5 1.0
# Node: 040+102 | Child: cub_102_Western_Wood_Pewee | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 10 1.0
# 	Proto: 13 0.9
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 078+077 | Child: cub_077_Tropical_Kingbird | Purity: 0.8500000000000001 | Num desc: 1 | Num protos: 2
# 	Proto: 18 0.9
# 	Proto: 12 0.8
# Node: 078+077 | Child: cub_078_Gray_Kingbird | Purity: 0.9583333333333334 | Num desc: 1 | Num protos: 3
# 	Proto: 0 0.875
# 	Proto: 3 1.0
# 	Proto: 5 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 3
# Node: 192+190 | Child: cub_190_Red_cockaded_Woodpecker | Purity: 0.7 | Num desc: 1 | Num protos: 2
# 	Proto: 11 0.5
# 	Proto: 15 0.9
# Node: 192+190 | Child: cub_192_Downy_Woodpecker | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 0 0.6
# 	Proto: 9 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 3
# Node: 065+062 | Child: 065+059 | Purity: 0.7999999999999999 | Num desc: 3 | Num protos: 3
# 	Proto: 8 0.9
# 	Proto: 7 0.5
# 	Proto: 1 1.0
# Node: 065+062 | Child: cub_062_Herring_Gull | Purity: 0.7 | Num desc: 1 | Num protos: 2
# 	Proto: 16 1.0
# 	Proto: 18 0.4
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 5
# Node: 144+145 | Child: 144+146 | Purity: 0.711111111111111 | Num desc: 3 | Num protos: 4
# 	Proto: 6 0.4444444444444444
# 	Proto: 2 0.9
# 	Proto: 1 0.7
# 	Proto: 4 0.8
# Node: 144+145 | Child: cub_145_Elegant_Tern | Purity: 0.8888888888888888 | Num desc: 1 | Num protos: 2
# 	Proto: 16 0.7777777777777778
# 	Proto: 18 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 006+007 | Child: cub_006_Least_Auklet | Purity: 0.85 | Num desc: 1 | Num protos: 4
# 	Proto: 0 0.8
# 	Proto: 3 0.6
# 	Proto: 1 1.0
# 	Proto: 6 1.0
# Node: 006+007 | Child: cub_007_Parakeet_Auklet | Purity: 0.8000000000000002 | Num desc: 1 | Num protos: 3
# 	Proto: 15 0.9
# 	Proto: 16 0.8
# 	Proto: 18 0.7
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 024+025 | Child: cub_024_Red_faced_Cormorant | Purity: 0.8500000000000001 | Num desc: 1 | Num protos: 2
# 	Proto: 1 0.9
# 	Proto: 9 0.8
# Node: 024+025 | Child: cub_025_Pelagic_Cormorant | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 16 0.9
# 	Proto: 14 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 001+002 | Child: cub_001_Black_footed_Albatross | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 2 1.0
# 	Proto: 9 1.0
# Node: 001+002 | Child: cub_002_Laysan_Albatross | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 19 1.0
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 4
# Node: 129+118 | Child: 129+104 | Purity: 0.5599999999999999 | Num desc: 81 | Num protos: 5
# 	Proto: 1 0.3
# 	Proto: 4 0.5555555555555556
# 	Proto: 3 0.4444444444444444
# 	Proto: 5 0.8
# 	Proto: 9 0.7
# Node: 129+118 | Child: cub_118_House_Sparrow | Purity: 0.3333333333333333 | Num desc: 1 | Num protos: 3
# 	Proto: 15 0
333333333333 | Num desc: 1 | Num protos: 3
# 	Proto: 16 0.0
# 	Proto: 14 0.0
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  11
# Part-related (purity>0.5): 7
# Node: 199+150 | Child: 150+019 | Purity: 0.7 | Num desc: 4 | Num protos: 4
# 	Proto: 11 0.7
# 	Proto: 14 0.1
# 	Proto: 18 1.0
# 	Proto: 19 1.0
# Node: 199+150 | Child: 199+094 | Purity: 0.4714285714285714 | Num desc: 9 | Num protos: 7
# 	Proto: 8 0.0
# 	Proto: 1 0.8
# 	Proto: 4 0.8
# 	Proto: 3 0.7
# 	Proto: 7 0.0
# 	Proto: 6 0.4
# 	Proto: 9 0.6
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 3
# Node: 186+185 | Child: cub_185_Bohemian_Waxwing | Purity: 0.40740740740740744 | Num desc: 1 | Num protos: 3
# 	Proto: 19 0.7777777777777778
# 	Proto: 16 0.0
# 	Proto: 17 0.4444444444444444
# Node: 186+185 | Child: cub_186_Cedar_Waxwing | Purity: 0.6666666666666667 | Num desc: 1 | Num protos: 2
# 	Proto: 3 0.5555555555555556
# 	Proto: 4 0.7777777777777778
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 136+137 | Child: cub_136_Barn_Swallow | Purity: 0.9444444444444444 | Num desc: 1 | Num protos: 2
# 	Proto: 6 0.8888888888888888
# 	Proto: 7 1.0
# Node: 136+137 | Child: cub_137_Cliff_Swallow | Purity: 0.7666666666666666 | Num desc: 1 | Num protos: 3
# 	Proto: 10 0.7
# 	Proto: 16 0.6
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 6
# Node: 107+093 | Child: 107+030 | Purity: 0.6977777777777778 | Num desc: 4 | Num protos: 5
# 	Proto: 1 0.3
# 	Proto: 4 0.8
# 	Proto: 3 0.8
# 	Proto: 7 0.7
# 	Proto: 9 0.8888888888888888
# Node: 107+093 | Child: cub_093_Clark_Nutcracker | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 13 1.0
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  3
# Part-related (purity>0.5): 3
# Node: 073+074 | Child: cub_073_Blue_Jay | Purity: 0.9 | Num desc: 1 | Num protos: 1
# 	Proto: 6 0.9
# Node: 073+074 | Child: cub_074_Florida_Jay | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 18 0.9
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 151+156 | Child: cub_151_Black_capped_Vireo | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 7 0.9
# 	Proto: 1 0.9
# 	Proto: 4 1.0
# Node: 151+156 | Child: cub_156_White_eyed_Vireo | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 15 1.0
# 	Proto: 14 0.9
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 157+152 | Child: cub_152_Blue_headed_Vireo | Purity: 0.8333333333333334 | Num desc: 1 | Num protos: 3
# 	Proto: 15 0.9
# 	Proto: 12 0.6
# 	Proto: 17 1.0
# Node: 157+152 | Child: cub_157_Yellow_throated_Vireo | Purity: 0.9666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 6 0.9
# 	Proto: 7 1.0
# 	Proto: 1 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 6
# Node: 153+155 | Child: cub_153_Philadelphia_Vireo | Purity: 0.6999999999999998 | Num desc: 1 | Num protos: 3
# 	Proto: 6 0.6
# 	Proto: 2 0.8
# 	Proto: 1 0.7
# Node: 153+155 | Child: cub_155_Warbling_Vireo | Purity: 0.7250000000000001 | Num desc: 1 | Num protos: 4
# 	Proto: 11 0.6
# 	Proto: 19 0.5
# 	Proto: 14 1.0
# 	Proto: 17 0.8
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 2
# Node: 065+060 | Child: cub_060_Glaucous_winged_Gull | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 11 0.6
# 	Proto: 16 0.9
# Node: 065+060 | Child: cub_065_Slaty_backed_Gull | Purity: 0.41666666666666663 | Num desc: 1 | Num protos: 2
# 	Proto: 0 0.3333333333333333
# 	Proto: 8 0.5
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 144+141 | Child: cub_141_Artic_Tern | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto:
Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 3 0.9
# 	Proto: 8 0.9
# 	Proto: 1 0.9
# Node: 107+108 | Child: cub_108_White_necked_Raven | Purity: 0.9 | Num desc: 1 | Num protos: 1
# 	Proto: 18 0.9
# Number of prototypes in parts_presences:  13
# Part-related (purity>0.5): 5
# Node: 129+011 | Child: 011+013 | Purity: 0.5972222222222222 | Num desc: 13 | Num protos: 6
# 	Proto: 14 0.75
# 	Proto: 13 1.0
# 	Proto: 12 0.2
# 	Proto: 10 0.8
# 	Proto: 16 0.5
# 	Proto: 15 0.3333333333333333
# Node: 129+011 | Child: 129+121 | Purity: 0.3428571428571429 | Num desc: 23 | Num protos: 7
# 	Proto: 1 0.6
# 	Proto: 0 0.2
# 	Proto: 3 0.0
# 	Proto: 7 0.0
# 	Proto: 5 0.4
# 	Proto: 6 0.7
# 	Proto: 2 0.5
# Number of prototypes in parts_presences:  12
# Part-related (purity>0.5): 10
# Node: 175+020 | Child: cub_020_Yellow_breasted_Chat | Purity: 0.85 | Num desc: 1 | Num protos: 4
# 	Proto: 11 1.0
# 	Proto: 13 0.5
# 	Proto: 16 0.9
# 	Proto: 12 1.0
# Node: 175+020 | Child: 175+099 | Purity: 0.7375 | Num desc: 29 | Num protos: 8
# 	Proto: 8 0.5
# 	Proto: 0 0.7
# 	Proto: 4 1.0
# 	Proto: 3 1.0
# 	Proto: 7 0.7
# 	Proto: 5 0.6
# 	Proto: 6 0.7
# 	Proto: 9 0.7
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 10
# Node: 054+057 | Child: 054+014 | Purity: 0.9 | Num desc: 4 | Num protos: 8
# 	Proto: 8 0.8
# 	Proto: 1 1.0
# 	Proto: 0 0.9
# 	Proto: 4 0.8
# 	Proto: 3 1.0
# 	Proto: 7 0.9
# 	Proto: 6 0.9
# 	Proto: 2 0.9
# Node: 054+057 | Child: cub_057_Rose_breasted_Grosbeak | Purity: 0.85 | Num desc: 1 | Num protos: 2
# 	Proto: 14 1.0
# 	Proto: 17 0.7
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 6
# Node: 140+017 | Child: cub_017_Cardinal | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 10 0.9
# 	Proto: 16 0.8
# 	Proto: 14 1.0
# Node: 140+017 | Child: 140+139 | Purity: 0.8222222222222222 | Num desc: 2 | Num protos: 4
# 	Proto: 5 0.8888888888888888
# 	Proto: 6 0.5
# 	Proto: 8 0.9
# 	Proto: 4 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 6
# Node: 035+056 | Child: 035+034 | Purity: 0.725 | Num desc: 2 | Num protos: 4
# 	Proto: 3 0.7
# 	Proto: 7 1.0
# 	Proto: 1 0.9
# 	Proto: 6 0.3
# Node: 035+056 | Child: cub_056_Pine_Grosbeak | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 10 0.9
# 	Proto: 15 0.9
# 	Proto: 14 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 048+047 | Child: cub_047_American_Goldfinch | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 12 1.0
# 	Proto: 17 0.8
# Node: 048+047 | Child: cub_048_European_Goldfinch | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 2 0.6
# 	Proto: 7 1.0
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 7
# Node: 199+194 | Child: 199+193 | Purity: 0.6925925925925925 | Num desc: 5 | Num protos: 6
# 	Proto: 8 0.6
# 	Proto: 1 0.9
# 	Proto: 0 0.9
# 	Proto: 4 0.9
# 	Proto: 3 0.3
# 	Proto: 9 0.5555555555555556
# Node: 199+194 | Child: cub_194_Cactus_Wren | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 15 1.0
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 8
# Node: 129+121 | Child: 129+117 | Purity: 0.5814814814814815 | Num desc: 22 | Num protos: 6
# 	Proto: 8 0.6
# 	Proto: 1 0.3
# 	Proto: 3 0.8888888888888888
# 	Proto: 5 0.1
# 	Proto: 2 0.8
# 	Proto: 9 0.8
# Node: 129+121 | Child: cub_121_Grasshopper_Sparrow | Purity: 0.875 | Num desc: 1 | Num protos: 4
# 	Proto: 10 0.7
# 	Proto: 11 0.9
# 	Proto: 14 0.9
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 6
# Node: 011+013 | Child: 011+095 | Purity: 0.5166666666666666 | Num desc: 10 | Num protos: 6
# 	Proto: 1 0.7
# 	Proto: 0 0.6
# 	Proto: 4 0.7
# 	Proto: 3 0.0
# 	Proto: 5 0.2
# 	Proto: 6 0.9
# Node: 011+013 | Child: 013+088 | Purity: 0.4666666666666666 | Num desc: 3 | Num protos: 3
# 	Proto: 10 0.7
# 	Proto: 11 0.0
# 	Proto: 13 0.7
# Number of prototypes in parts_presences:  11
# Part-related (purity>0.5): 9
# Node: 175+099 | Child: cub_099_Ovenbird | Purity: 0.8833333333333333 | Num desc: 1 | Num protos: 6
# 	Proto: 14 0.9
# 	Proto: 12 0.9
# 	Proto: 17 1.0
# 	Proto: 11 0.8
# 	Proto: 10 0.7
# 	Proto: 16 1.0
# Node: 175+099 | Child: 175+181 | Purity: 0.6355555555555557 | Num desc: 28 | Num protos: 5
# 	Proto: 1 1.0
# 	Proto: 0 0.3333333333333333
# 	Proto: 7 0.7
# 	Proto: 5 0.4444444444444444
# 	Proto: 6 0.7
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 5
# Node: 054+014 | Child: cub_014_Indigo_Bunting | Purity: 0.8333333333333334 | Num desc: 1 | Num protos: 3
# 	Proto: 18 0.5
# 	Proto: 12 1.0
# 	Proto: 17 1.0
# Node: 054+014 | Child: 054+016 | Purity: 0.5577777777777777 | Num desc: 3 | Num protos: 5
# 	Proto: 8 0.7
# 	Proto: 1 0.3
# 	Proto: 0 0.8888888888888888
# 	Proto: 5 0.9
# 	Proto: 6 0.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 3
# Node: 140+139 | Child: cub_139_Scarlet_Tanager | Purity: 0.9375 | Num desc: 1 | Num protos: 2
# 	Proto: 16 0.875
# 	Proto: 18 1.0
# Node: 140+139 | Child: cub_140_Summer_Tanager | Purity: 0.7222222222222222 | Num desc: 1 | Num protos: 2
# 	Proto: 0 1.0
# 	Proto: 1 0.4444444444444444
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 035+034 | Child: cub_034_Gray_crowned_Rosy_Finch | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 10 1.0
# 	Proto: 19 0.7
# 	Proto: 17 1.0
# Node: 035+034 | Child: cub_035_Purple_Finch | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 0 1.0
# 	Proto: 1 0.8
# 	Proto: 6 1.0
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 8
# Node: 199+193 | Child: 193+195 | Purity: 0.8000000000000002 | Num desc: 2 | Num protos: 3
# 	Proto: 10 0.6
# 	Proto: 18 1.0
# 	Proto: 13 0.8
# Node: 199+193 | Child: 199+197 | Purity: 0.8055555555555555 | Num desc: 3 | Num protos: 6
# 	Proto: 1 0.3333333333333333
# 	Proto: 4 0.9
# 	Proto: 7 0.9
# 	Proto: 5 0.7
# 	Proto: 6 1.0
# 	Proto: 9 1.0
# Number of prototypes in parts_presences:  13
# Part-related (purity>0.5): 5
# Node: 129+117 | Child: 129+133 | Purity: 0.34285714285714286 | Num desc: 17 | Num protos: 7
# 	Proto: 1 0.2
# 	Proto: 0 0.4
# 	Proto: 4 0.0
# 	Proto: 3 0.0
# 	Proto: 7 0.2
# 	Proto: 5 0.7
# 	Proto: 6 0.9
# Node: 129+117 | Child: 117+114 | Purity: 0.5462962962962963 | Num desc: 5 | Num protos: 6
# 	Proto: 18 0.7777777777777778
# 	Proto: 13 0.0
# 	Proto: 12 0.5
# 	Proto: 19 0.9
# 	Proto: 10 0.4
# 	Proto: 15 0.7
# Number of prototypes in parts_presences:  12
# Part-related (purity>0.5): 6
# ...
# 	Proto: 18 0.5
# Node: 129+021 | Child: 129+128 | Purity: 0.6999999999999998 | Num desc: 9 | Num protos: 6
# 	Proto: 8 0.9
# 	Proto: 0 0.8
# 	Proto: 4 0.3
# 	Proto: 6 0.8
# 	Proto: 2 0.8
# 	Proto: 9 0.6
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 8
# Node: 133+130 | Child: 133+076 | Purity: 0.7749999999999999 | Num desc: 4 | Num protos: 4
# 	Proto: 5 1.0
# 	Proto: 2 0.7
# 	Proto: 1 0.6
# 	Proto: 9 0.8
# Node: 133+130 | Child: 130+120 | Purity: 0.875 | Num desc: 2 | Num protos: 4
# 	Proto: 10 0.8
# 	Proto: 15 1.0
# 	Proto: 14 0.9
# 	Proto: 19 0.8
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 8
# Node: 117+115 | Child: 115+119 | Purity: 0.95 | Num desc: 2 | Num protos: 4
# 	Proto: 11 1.0
# 	Proto: 16 1.0
# 	Proto: 18 0.8
# 	Proto: 19 1.0
# Node: 117+115 | Child: 117+116 | Purity: 0.85 | Num desc: 2 | Num protos: 4
# 	Proto: 0 1.0
# 	Proto: 5 0.9
# 	Proto: 6 0.6
# 	Proto: 9 0.9
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 011+049 | Child: 011+009 | Purity: 0.7611111111111111 | Num desc: 2 | Num protos: 4
# 	Proto: 0 0.5555555555555556
# 	Proto: 2 1.0
# 	Proto: 6 0.6
# 	Proto: 9 0.8888888888888888
# Node: 011+049 | Child: cub_049_Boat_tailed_Grackle | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 10 0.7
# 	Proto: 15 1.0
# 	Proto: 14 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 3
# Node: 026+010 | Child: cub_010_Red_winged_Blackbird | Purity: 0.4444444444444444 | Num desc: 1 | Num protos: 1
# 	Proto: 18 0.4444444444444444
# Node: 026+010 | Child: 026+027 | Purity: 0.7999999999999999 | Num desc: 2 | Num protos: 3
# 	Proto: 3 0.8
# 	Proto: 5 0.7
# 	Proto: 9 0.9
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 095+098 | Child: cub_095_Baltimore_Oriole | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 2 1.0
# 	Proto: 7 1.0
# Node: 095+098 | Child: cub_098_Scott_Oriole | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 10 1.0
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 096+097 | Child: cub_096_Hooded_Oriole | Purity: 0.9444444444444444 | Num desc: 1 | Num protos: 2
# 	Proto: 0 0.8888888888888888
# 	Proto: 6 1.0
# Node: 096+097 | Child: cub_097_Orchard_Oriole | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 15 1.0
# 	Proto: 14 1.0
# Number of prototypes in parts_presences:  11
# Part-related (purity>0.5): 11
# Node: 175+162 | Child: 175+167 | Purity: 0.8458333333333333 | Num desc: 12 | Num protos: 8
# 	Proto: 8 0.6
# 	Proto: 0 0.9
# 	Proto: 4 0.8
# 	Proto: 3 0.8
# 	Proto: 7 1.0
# 	Proto: 5 0.8888888888888888
# 	Proto: 6 0.7777777777777778
# 	Proto: 9 1.0
# Node: 175+162 | Child: 162+180 | Purity: 0.8888888888888888 | Num desc: 2 | Num protos: 3
# 	Proto: 11 0.6666666666666666
# 	Proto: 14 1.0
# 	Proto: 12 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 168+177 | Child: 168+200 | Purity: 0.9 | Num desc: 3 | Num protos: 4
# 	Proto: 5 1.0
# 	Proto: 3 0.8
# 	Proto: 2 0.9
# 	Proto: 1 0.9
# Node: 168+177 | Child: 177+178 | Purity: 0.9629629629629629 | Num desc: 2 | Num protos: 3
# 	Proto: 10 1.0
# 	Proto: 12 0.8888888888888888
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 173+161 | Child: 161+166 | Purity: 0.9 | Num desc: 2 | Num protos: 2
# 	Proto: 14 0.9
# 	Proto: 13 0.9
# Node: 173+161 | Child: 173+179 | Purity: 0.875 | Num desc: 3 | Num protos: 4
# 	Proto: 3 0.8
# 	Proto: 7 0.7
# 	Proto: 5 1.0
# 	Proto: 6 1.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 183+159 | Child: cub_159_Black_and_white_Warbler | Purity: 0.8000000000000002 | Num desc: 1 | Num protos: 3
# 	Proto: 11 1.0
# 	Proto: 17 0.6
# 	Proto: 15 0.8
# Node: 183+159 | Child: 183+184 | Purity: 0.7999999999999999 | Num desc: 2 | Num protos: 3
# 	Proto: 2 0.9
# 	Proto: 1 0.9
# 	Proto: 4 0.6
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 10
# Node: 129+128 | Child: 129+127 | Purity: 0.7644444444444444 | Num desc: 5 | Num protos: 5
# 	Proto: 1 0.7
# 	Proto: 3 0.9
# 	Proto: 5 1.0
# 	Proto: 6 0.6666666666666666
# 	Proto: 9 0.5555555555555556
# Node: 129+128 | Child: 128+131 | Purity: 0.9 | Num desc: 4 | Num protos: 5
# 	Proto: 18 0.9
# 	Proto: 13 0.9
# 	Proto: 12 0.9
# 	Proto: 11 1.0
# 	Proto: 15 0.8
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 021+148 | Child: cub_021_Eastern_Towhee | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 2 0.9
# 	Proto: 5 0.9
# Node: 021+148 | Child: cub_148_Green_tailed_Towhee | Purity: 0.8666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 16 1.0
# 	Proto: 18 0.7
# 	Proto: 19 0.9
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 133+076 | Child: cub_076_Dark_eyed_Junco | Purity: 0.8666666666666666 | Num desc: 1 | Num protos: 3
# 	Proto: 10 1.0
# 	Proto: 16 0.9
# 	Proto: 14 0.7
# Node: 133+076 | Child: 133+132 | Purity: 0.7750000000000001 | Num desc: 3 | Num protos: 4
# 	Proto: 0 0.8
# 	Proto: 7 0.9
# 	Proto: 1 0.7
# 	Proto: 4 0.7
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 130+120 | Child: cub_120_Fox_Sparrow | Purity: 0.7000000000000001 | Num desc: 1 | Num protos: 3
# 	Proto: 15 0.7
# 	Proto: 16 0.5
# 	Proto: 12 0.9
# Node: 130+120 | Child: cub_130_Tree_Sparrow | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 3 0.9
# 	Proto: 1 0.9
# Number of prototypes in parts_presences:  3
# Part-related (purity>0.5): 3
# Node: 117+116 | Child: cub_116_Chipping_Sparrow | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 16 1.0
# 	Proto: 13 0.6
# Node: 117+116 | Child: cub_117_Clay_colored_Sparrow | Purity: 1.0 | Num desc: 1 | Num protos: 1
# 	Proto: 8 1.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 4
# Node: 115+119 | Child: cub_115_Brewer_Sparrow | Purity: 0.7000000000000001 | Num desc: 1 | Num protos: 3
# 	Proto: 6 0.9
# 	Proto: 7 0.8
# 	Proto: 5 0.4
# Node: 115+119 | Child: cub_119_Field_Sparrow | Purity: 0.7666666666666666 | Num desc: 1 | Num protos: 3
# 	Proto: 15 0.4
# 	Proto: 14 1.0
# 	Proto: 18 0.9
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 011+009 | Child: cub_009_Brewer_Blackbird | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 10 1.0
# 	Proto: 13 0.9
# Node: 011+009 | Child: cub_011_Rusty_Blackbird | Purity: 0.6 | Num desc: 1 | Num protos: 3
# 	Proto: 3 0.0
# 	Proto: 7 1.0
# 	Proto: 5 0.8
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 026+027 | Child: cub_026_Bronzed_Cowbird | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 3 1.0
# 	Proto: 1 1.0
# Node: 026+027 | Child: cub_027_Shiny_Cowbird | Purity: 1.0 | Num desc: 1 | Num protos: 3
# 	Proto: 15 1.0
# 	Proto: 16 1.0
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 7
# Node: 175+167 | Child: 175+169 | Purity: 0.7407407407407408 | Num desc: 11 | Num protos: 6
# 	Proto: 1 0.8
# 	Proto: 0 0.5
# 	Proto: 3 0.5555555555555556
# 	Proto: 6 0.8
# 	Proto: 2 0.8888888888888888
# 	Proto: 9 0.9
# Node: 175+167 | Child: cub_167_Hooded_Warbler | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 11 1.0
# 	Proto: 13 0.9
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 162+180 | Child: cub_162_Canada_Warbler | Purity: 0.8666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 0 0.8
# 	Proto: 5 0.8
# 	Proto: 6 1.0
# Node: 162+180 | Child: cub_180_Wilson_Warbler | Purity: 0.8666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 16 1.0
# 	Proto: 12 0.8
# 	Proto: 17 0.8
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 168+200 | Child: 168+170 | Purity: 0.8400000000000001 | Num desc: 2 | Num protos: 5
# 	Proto: 0 1.0
# 	Proto: 3 0.7
# 	Proto: 5 0.8
# 	Proto: 6 1.0
# 	Proto: 2 0.7
# Node: 168+200 | Child: cub_200_Common_Yellowthroat | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 10 0.9
# 	Proto: 15 0.9
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 177+178 | Child: cub_177_Prothonotary_Warbler | Purity: 0.8518518518518517 | Num desc: 1 | Num protos: 3
# 	Proto: 0 1.0
# 	Proto: 2 0.5555555555555556
# 	Proto: 9 1.0
# Node: 177+178 | Child: cub_178_Swainson_Warbler | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 15 1.0
# 	Proto: 17 0.8
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 3
# Node: 173+179 | Child: 173+172 | Purity: 0.4666666666666666 | Num desc: 2 | Num protos: 3
# 	Proto: 0 1.0
# 	Proto: 7 0.2
# 	Proto: 9 0.2
# Node: 173+179 | Child: cub_179_Tennessee_Warbler | Purity: 0.7333333333333334 | Num desc: 1 | Num protos: 3
# 	Proto: 16 0.4
# 	Proto: 14 0.8
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 161+166 | Child: cub_161_Blue_winged_Warbler | Purity: 0.65 | Num desc: 1 | Num protos: 2
# 	Proto: 3 0.8
# 	Proto: 5 0.5
# Node: 161+166 | Child: cub_166_Golden_winged_Warbler | Purity: 0.8000000000000002 | Num desc: 1 | Num protos: 3
# 	Proto: 10 0.9
# 	Proto: 11 0.8
# 	Proto: 12 0.7
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 183+184 | Child: cub_183_Northern_Waterthrush | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 0 1.0
# 	Proto: 9 0.8
# Node: 183+184 | Child: cub_184_Louisiana_Waterthrush | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 11 1.0
# 	Proto: 19 0.9
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 5
# Node: 129+127 | Child: 129+123 | Purity: 0.7250000000000001 | Num desc: 4 | Num protos: 4
# 	Proto: 5 0.9
# 	Proto: 0 0.5
# 	Proto: 7 0.8
# 	Proto: 4 0.7
# Node: 129+127 | Child: cub_127_Savannah_Sparrow | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 14 0.9
# 	Proto: 17 0.7
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 128+131 | Child: 128+124 | Purity: 0.8499999999999999 | Num desc: 3 | Num protos: 4
# 	Proto: 0 1.0
# 	Proto: 5 0.9
# 	Proto: 6 0.7
# 	Proto: 9 0.8
# Node: 128+131 | Child: cub_131_Vesper_Sparrow | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 10 0.9
# 	Proto: 19 1.0
# 	Proto: 17 0.9
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 133+132 | Child: 133+122 | Purity: 0.7666666666666667 | Num desc: 2 | Num protos: 3
# 	Proto: 0 0.8
# 	Proto: 3 0.9
# 	Proto: 4 0.6
# Node: 133+132 | Child: cub_132_White_crowned_Sparrow | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 16 1.0
# 	Proto: 12 0.8
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 7
# Node: 175+169 | Child: 175+165+182 | Purity: 0.8800000000000001 | Num desc: 10 | Num protos: 5
# 	Proto: 0 0.9
# 	Proto: 3 1.0
# 	Proto: 5 1.0
# 	Proto: 2 0.8
# 	Proto: 9 0.7
# Node: 175+169 | Child: cub_169_Magnolia_Warbler | Purity: 0.7666666666666666 | Num desc: 1 | Num protos: 3
# 	Proto: 16 1.0
# 	Proto: 14 0.9
# 	Proto: 17 0.4
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 168+170 | Child: cub_168_Kentucky_Warbler | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 2 1.0
# 	Proto: 1 1.0
# Node: 168+170 | Child: cub_170_Mourning_Warbler | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 11 0.9
# 	Proto: 18 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 173+172 | Child: cub_172_Nashville_Warbler | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 14 0.9
# 	Proto: 18 0.6
# Node: 173+172 | Child: cub_173_Orange_crowned_Warbler | Purity: 0.8222222222222223 | Num desc: 1 | Num protos: 3
# 	Proto: 6 0.6666666666666666
# 	Proto: 4 0.8
# 	Proto: 9 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 6
# Node: 129+123 | Child: 123+113 | Purity: 0.89375 | Num desc: 2 | Num protos: 4
# 	Proto: 10 1.0
# 	Proto: 15 0.875
# 	Proto: 18 1.0
# 	Proto: 13 0.7
# Node: 129+123 | Child: 129+125 | Purity: 0.7999999999999999 | Num desc: 2 | Num protos: 3
# 	Proto: 0 1.0
# 	Proto: 5 0.9
# 	Proto: 9 0.5
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 128+124 | Child: cub_124_Le_Conte_Sparrow | Purity: 0.8500000000000001 | Num desc: 1 | Num protos: 2
# 	Proto: 14 0.8
# 	Proto: 18 0.9
# Node: 128+124 | Child: 128+126 | Purity: 0.7666666666666666 | Num desc: 2 | Num protos: 3
# 	Proto: 6 0.9
# 	Proto: 2 0.7
# 	Proto: 1 0.7
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 133+122 | Child: cub_122_Harris_Sparrow | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 10 0.6
# 	Proto: 16 0.9
# Node: 133+122 | Child: cub_133_White_throated_Sparrow | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 3 0.8
# 	Proto: 5 0.8
# Number of prototypes in parts_presences:  13
# Part-related (purity>0.5): 9
# Node: 175+165+182 | Child: 175+160 | Purity: 0.75 | Num desc: 5 | Num protos: 4
# 	Proto: 6 0.7
# 	Proto: 8 0.9
# 	Proto: 7 0.6
# 	Proto: 1 0.8
# Node: 175+165+182 | Child: 165+164+163 | Purity: 0.6273148148148148 | Num desc: 4 | Num protos: 6
# 	Proto: 13 0.5
# 	Proto: 19 1.0
# 	Proto: 11 0.5
# 	Proto: 10 0.875
# 	Proto: 16 0.8888888888888888
# 	Proto: 15 0.0
# Node: 175+165+182 | Child: cub_182_Yellow_Warbler | Purity: 0.6 | Num desc: 1 | Num protos: 3
# 	Proto: 28 0.8
# 	Proto: 20 0.1
# 	Proto: 24 0.9
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 129+125 | Child: cub_125_Lincoln_Sparrow | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 11 1.0
# 	Proto: 16 0.9
# Node: 129+125 | Child: cub_129_Song_Sparrow | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 3 1.0
# 	Proto: 4 0.9
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 123+113 | Child: cub_113_Baird_Sparrow | Purity: 0.8500000000000001 | Num desc: 1 | Num protos: 2
# 	Proto: 15 0.8
# 	Proto: 19 0.9
# Node: 123+113 | Child: cub_123_Henslow_Sparrow | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 6 0.9
# 	Proto: 1 0.9
# 	Proto: 9 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 128+126 | Child: cub_126_Nelson_Sharp_tailed_Sparrow | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 10 1.0
# 	Proto: 15 1.0
# Node: 128+126 | Child: cub_128_Seaside_Sparrow | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 3 1.0
# 	Proto: 8 0.9
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 9
# Node: 175+160 | Child: 160+109 | Purity: 0.8 | Num desc: 2 | Num protos: 4
# 	Proto: 11 1.0
# 	Proto: 13 0.6
# 	Proto: 16 0.8
# 	Proto: 12 0.8
# Node: 175+160 | Child: 175+176 | Purity: 0.8800000000000001 | Num desc: 3 | Num protos: 5
# 	Proto: 8 0.6
# 	Proto: 1 1.0
# 	Proto: 0 0.9
# 	Proto: 3 1.0
# 	Proto: 5 0.9
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 9
# Node: 165+164+163 | Child: 165+158 | Purity: 0.95 | Num desc: 2 | Num protos: 2
# 	Proto: 3 1.0
# 	Proto: 2 0.9
# Node: 165+164+163 | Child: cub_163_Cape_May_Warbler | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 26 0.7
# 	Proto: 29 1.0
# 	Proto: 28 1.0
# Node: 165+164+163 | Child: cub_164_Cerulean_Warbler | Purity: 0.975 | Num desc: 1 | Num protos: 4
# 	Proto: 11 1.0
# 	Proto: 14 0.9
# 	Proto: 12 1.0
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 175+176 | Child: 175+174 | Purity: 0.8333333333333334 | Num desc: 2 | Num protos: 3
# 	Proto: 5 0.6
# 	Proto: 6 1.0
# 	Proto: 1 0.9
# Node: 175+176 | Child: cub_176_Prairie_Warbler | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 16 1.0
# 	Proto: 18 0.5
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 4
# Node: 160+109 | Child: cub_109_American_Redstart | Purity: 0.762962962962963 | Num desc: 1 | Num protos: 3
# 	Proto: 15 0.4
# 	Proto: 13 0.8888888888888888
# 	Proto: 12 1.0
# Node: 160+109 | Child: cub_160_Black_throated_Blue_Warbler | Purity: 0.45999999999999996 | Num desc: 1 | Num protos: 5
# 	Proto: 1 0.9
# 	Proto: 0 0.4
# 	Proto: 7 0.2
# 	Proto: 5 0.8
# 	Proto: 6 0.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 165+158 | Child: cub_158_Bay_breasted_Warbler | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 18 1.0
# 	Proto: 12 1.0
# Node: 165+158 | Child: cub_165_Chestnut_sided_Warbler | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 6 0.8
# 	Proto: 7 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 175+174 | Child: cub_174_Palm_Warbler | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 15 1.0
# 	Proto: 16 1.0
# Node: 175+174 | Child: cub_175_Pine_Warbler | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 3 0.9
# 	Proto: 8 0.9

# %%
print('Before masking')
print(np.mean(node_wise_purity))
print(np.std(node_wise_purity))
print(np.nanmean(node_wise_purity))
print(np.nanstd(node_wise_purity))
# Out:
# Before masking
# 0.7595504933213104
# 0.16935414044602232
# 0.7595504933213104
# 0.16935414044602232

# %%
print('After masking (of unmasked protos)')
print(np.mean(node_wise_purity_of_unmasked))
print(np.std(node_wise_purity_of_unmasked))
print(np.nanmean(node_wise_purity_of_unmasked))
print(np.nanstd(node_wise_purity_of_unmasked))
# Out:
# After masking (of unmasked protos)
# nan
# nan
# 0.7868323261909405
# 0.15414251688018996

# %%
print('Of masked protos')
print(np.mean(node_wise_purity_of_masked))
print(np.std(node_wise_purity_of_masked))
print(np.nanmean(node_wise_purity_of_masked))
print(np.nanstd(node_wise_purity_of_masked))
# Out:
# Of masked protos
# nan
# nan
# 0.41106091787543403
# 0.2229958080930179

# %%
getattr(net.module, '_'+'root'+'_proto_presence')

import pandas as pd
from collections import defaultdict
import pdb

data = defaultdict(list)

for node in root.nodes_with_children():
    proto_presence = getattr(net.module, '_'+node.name+'_proto_presence')
    classification_weights = getattr(net.module, '_'+node.name+'_classification').weight
    for i in range(proto_presence.shape[0]):
        if (proto_presence[i, 0] > proto_presence[i, 1]):
            masked = 1
        else:
            masked = 0
        relevant_proto_classes = torch.nonzero(classification_weights[:, i] > 1e-3)
        relevant_proto_class_indices = [class_idx.item() for class_idx in relevant_proto_classes]
        if len(relevant_proto_class_indices) > 0:
            relevant_proto = 1
        else:
            relevant_proto = 0
        data['node_name'].append(node.name)
        data['proto_num'].append(i)
        data['masked'].append(masked)
        data['relevant_proto'].append(relevant_proto)

df = pd.DataFrame(data)

df.to_csv(os.path.join(run_path, 'proto_presence.csv'))

# %%
run_path
# Out:
# '/home/harishbabu/projects/PIPNet_wandb/runs/178-PruningNaiveHPIPNetMaskL1=0.5MaskTrainExtra=15epsEps=60TanhDesc=0.05MinCont=0.1_cnext26_CUB-190-imgnet-224_WeightedCE_with-equalize-aug_img=224_nprotos=20'

# %% [markdown]
# # Ratio of good protos / Total protos

# %%
import torch.nn.functional as F

total_relevant_protos = 0.
total_good_protos = 0.

with torch.no_grad():
    for node in root.nodes_with_children():
        label_to_children = {v: k for k, v in node.children_to_labels.items()}
        classification_weights = getattr(net.module, '_'+node.name+'_classification').weight
        proto_presence = getattr(net.module, '_'+node.name+'_proto_presence')
        proto_presence = F.gumbel_softmax(proto_presence, tau=0.5, hard=True, dim=-1)
        masked_classification_weights = proto_presence[:, 1].unsqueeze(0) * classification_weights
        all_protos_masked = False
        for class_idx in range(masked_classification_weights.shape[0]):
            # print(node.name, label_to_children[class_idx], 'relevant:', (classification_weights[class_idx, :] > 1e-3).sum().item(), \
            #       'Good ones:', (masked_classification_weights[class_idx, :] > 1e-3).sum().item(), \
            #       'Good proto idxs:', torch.nonzero(masked_classification_weights[class_idx, :] > 1e-3).reshape(-1))
            print(node.name, label_to_children[class_idx], 'Good/Total:', f'{(masked_classification_weights[class_idx, :] > 1e-3).sum().item()}/{(classification_weights[class_idx, :] > 1e-3).sum().item()}', \
                 'Good proto idxs:', torch.nonzero(masked_classification_weights[class_idx, :] > 1e-3).reshape(-1))
            total_relevant_protos += (classification_weights[class_idx, :] > 1e-3).sum().item()
            total_good_protos += (masked_classification_weights[class_idx, :] > 1e-3).sum().item()

print('Total protos:', total_relevant_protos, 'Total good protos:', total_good_protos, 'Ratio:', total_good_protos/total_relevant_protos)
# Out:
# root 129+024+067 Good/Total: 0/8 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# root 089+046 Good/Total: 2/2 Good proto idxs: tensor([12, 16], device='cuda:0')
# 129+024+067 129+065 Good/Total: 0/6 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+024+067 024+051 Good/Total: 0/5 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+024+067 067+070 Good/Total: 2/2 Good proto idxs: tensor([21, 29], device='cuda:0')
# 089+046 089+090 Good/Total: 4/4 Good proto idxs: tensor([3, 4, 7, 9], device='cuda:0')
# 089+046 046+087 Good/Total: 4/4 Good proto idxs: tensor([11, 15, 17, 18], device='cuda:0')
# 129+065 129+192 Good/Total: 0/7 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+065 065+006 Good/Total: 0/7 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 024+051 024+031 Good/Total: 0/6 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 024+051 051+052 Good/Total: 4/4 Good proto idxs: tensor([10, 12, 17, 19], device='cuda:0')
# 067+070 067+068 Good/Total: 4/4 Good proto idxs: tensor([0, 2, 4, 6], device='cuda:0')
# 067+070 cub_070_Green_Violetear Good/Total: 2/2 Good proto idxs: tensor([12, 14], device='cuda:0')
# 089+090 cub_089_Hooded_Merganser Good/Total: 3/3 Good proto idxs: tensor([0, 2, 6], device='cuda:0')
# 089+090 cub_090_Red_breasted_Merganser Good/Total: 3/3 Good proto idxs: tensor([10, 11, 12], device='cuda:0')
# 046+087 cub_046_Gadwall Good/Total: 3/3 Good proto idxs: tensor([2, 6, 9], device='cuda:0')
# 046+087 cub_087_Mallard Good/Total: 2/2 Good proto idxs: tensor([18, 19], device='cuda:0')
# 129+192 129+043 Good/Total: 0/6 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+192 192+081 Good/Total: 0/6 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 065+006 065+144 Good/Total: 0/8 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 065+006 006+071 Good/Total: 3/4 Good proto idxs: tensor([14, 15, 17], device='cuda:0')
# 024+031 024+086 Good/Total: 6/8 Good proto idxs: tensor([0, 3, 4, 5, 6, 9], device='cuda:0')
# 024+031 031+004 Good/Total: 6/6 Good proto idxs: tensor([10, 12, 13, 14, 15, 18], device='cuda:0')
# 051+052 051+053 Good/Total: 4/4 Good proto idxs: tensor([3, 4, 5, 7], device='cuda:0')
# 051+052 cub_052_Pied_billed_Grebe Good/Total: 3/3 Good proto idxs: tensor([11, 16, 18], device='cuda:0')
# 067+068 067+069 Good/Total: 4/4 Good proto idxs: tensor([2, 4, 5, 8], device='cuda:0')
# 067+068 cub_068_Ruby_throated_Hummingbird Good/Total: 2/2 Good proto idxs: tensor([14, 18], device='cuda:0')
# 129+043 129+018 Good/Total: 0/6 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+043 043+078 Good/Total: 1/3 Good proto idxs: tensor([10], device='cuda:0')
# 192+081 192+036 Good/Total: 4/4 Good proto idxs: tensor([1, 3, 6, 7], device='cuda:0')
# 192+081 081+083 Good/Total: 5/5 Good proto idxs: tensor([11, 12, 14, 15, 17], device='cuda:0')
# 065+144 065+084 Good/Total: 5/6 Good proto idxs: tensor([0, 1, 2, 3, 9], device='cuda:0')
# 065+144 144+147 Good/Total: 4/5 Good proto idxs: tensor([10, 14, 15, 16], device='cuda:0')
# 006+071 006+058 Good/Total: 7/7 Good proto idxs: tensor([2, 3, 4, 6, 7, 8, 9], device='cuda:0')
# 006+071 071+072 Good/Total: 5/5 Good proto idxs: tensor([11, 14, 17, 18, 19], device='cuda:0')
# 024+086 024+001 Good/Total: 7/7 Good proto idxs: tensor([0, 2, 3, 4, 5, 7, 9], device='cuda:0')
# 024+086 cub_086_Pacific_Loon Good/Total: 4/4 Good proto idxs: tensor([12, 13, 14, 16], device='cuda:0')
# 031+004 031+032 Good/Total: 4/4 Good proto idxs: tensor([0, 2, 4, 9], device='cuda:0')
# 031+004 cub_004_Groove_billed_Ani Good/Total: 2/2 Good proto idxs: tensor([11, 14], device='cuda:0')
# 051+053 051+050 Good/Total: 3/3 Good proto idxs: tensor([0, 3, 8], device='cuda:0')
# 051+053 cub_053_Western_Grebe Good/Total: 2/2 Good proto idxs: tensor([15, 17], device='cuda:0')
# 067+069 cub_067_Anna_Hummingbird Good/Total: 3/3 Good proto idxs: tensor([1, 2, 9], device='cuda:0')
# 067+069 cub_069_Rufous_Hummingbird Good/Total: 3/3 Good proto idxs: tensor([13, 18, 19], device='cuda:0')
# 129+018 129+107 Good/Total: 0/8 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+018 cub_018_Spotted_Catbird Good/Total: 3/4 Good proto idxs: tensor([10, 14, 18], device='cuda:0')
# 043+078 043+042 Good/Total: 5/5 Good proto idxs: tensor([0, 3, 4, 5, 6], device='cuda:0')
# 043+078 078+038 Good/Total: 5/5 Good proto idxs: tensor([14, 15, 16, 17, 19], device='cuda:0')
# 192+036 192+191 Good/Total: 5/5 Good proto idxs: tensor([1, 3, 4, 5, 8], device='cuda:0')
# 192+036 036+188 Good/Total: 2/2 Good proto idxs: tensor([15, 17], device='cuda:0')
# 081+083 081+082 Good/Total: 6/6 Good proto idxs: tensor([0, 3, 4, 5, 6, 8], device='cuda:0')
# 081+083 cub_083_White_breasted_Kingfisher Good/Total: 2/2 Good proto idxs: tensor([15, 17], device='cuda:0')
# 065+084 065+061 Good/Total: 6/6 Good proto idxs: tensor([1, 2, 5, 7, 8, 9], device='cuda:0')
# 065+084 084+063 Good/Total: 5/5 Good proto idxs: tensor([11, 12, 14, 15, 17], device='cuda:0')
# 144+147 144+143 Good/Total: 5/5 Good proto idxs: tensor([0, 2, 7, 8, 9], device='cuda:0')
# 144+147 cub_147_Least_Tern Good/Total: 3/3 Good proto idxs: tensor([10, 14, 19], device='cuda:0')
# 006+058 006+008 Good/Total: 7/7 Good proto idxs: tensor([2, 4, 5, 6, 7, 8, 9], device='cuda:0')
# 006+058 cub_058_Pigeon_Guillemot Good/Total: 3/3 Good proto idxs: tensor([14, 17, 19], device='cuda:0')
# 071+072 cub_071_Long_tailed_Jaeger Good/Total: 2/2 Good proto idxs: tensor([3, 5], device='cuda:0')
# 071+072 cub_072_Pomarine_Jaeger Good/Total: 3/3 Good proto idxs: tensor([12, 17, 19], device='cuda:0')
# 024+001 024+100 Good/Total: 7/7 Good proto idxs: tensor([0, 1, 5, 6, 7, 8, 9], device='cuda:0')
# 024+001 001+045 Good/Total: 3/3 Good proto idxs: tensor([10, 15, 19], device='cuda:0')
# 031+032 031+033 Good/Total: 3/3 Good proto idxs: tensor([3, 6, 7], device='cuda:0')
# 031+032 cub_032_Mangrove_Cuckoo Good/Total: 2/2 Good proto idxs: tensor([15, 19], device='cuda:0')
# 051+050 cub_051_Horned_Grebe Good/Total: 2/2 Good proto idxs: tensor([0, 1], device='cuda:0')
# 051+050 cub_050_Eared_Grebe Good/Total: 3/3 Good proto idxs: tensor([11, 16, 19], device='cuda:0')
# 129+107 129+136 Good/Total: 0/9 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+107 107+151 Good/Total: 0/4 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 043+042 043+040 Good/Total: 6/6 Good proto idxs: tensor([0, 3, 4, 6, 7, 9], device='cuda:0')
# 043+042 cub_042_Vermilion_Flycatcher Good/Total: 4/4 Good proto idxs: tensor([10, 13, 15, 19], device='cuda:0')
# 078+038 078+041 Good/Total: 4/4 Good proto idxs: tensor([4, 6, 7, 9], device='cuda:0')
# 078+038 cub_038_Great_Crested_Flycatcher Good/Total: 2/2 Good proto idxs: tensor([12, 13], device='cuda:0')
# 192+191 192+187 Good/Total: 5/5 Good proto idxs: tensor([1, 3, 5, 6, 9], device='cuda:0')
# 192+191 191+189 Good/Total: 4/4 Good proto idxs: tensor([11, 14, 15, 18], device='cuda:0')
# 036+188 cub_036_Northern_Flicker Good/Total: 2/2 Good proto idxs: tensor([2, 5], device='cuda:0')
# 036+188 cub_188_Pileated_Woodpecker Good/Total: 2/2 Good proto idxs: tensor([12, 14], device='cuda:0')
# 081+082 081+080 Good/Total: 4/4 Good proto idxs: tensor([2, 4, 5, 8], device='cuda:0')
# 081+082 082+079 Good/Total: 4/4 Good proto idxs: tensor([12, 14, 15, 18], device='cuda:0')
# 065+061 065+066 Good/Total: 5/5 Good proto idxs: tensor([0, 2, 4, 5, 9], device='cuda:0')
# 065+061 061+064 Good/Total: 4/4 Good proto idxs: tensor([11, 15, 16, 18], device='cuda:0')
# 084+063 cub_084_Red_legged_Kittiwake Good/Total: 2/2 Good proto idxs: tensor([4, 8], device='cuda:0')
# 084+063 cub_063_Ivory_Gull Good/Total: 3/3 Good proto idxs: tensor([14, 18, 19], device='cuda:0')
# 144+143 144+142 Good/Total: 4/4 Good proto idxs: tensor([1, 2, 5, 7], device='cuda:0')
# 144+143 cub_143_Caspian_Tern Good/Total: 3/3 Good proto idxs: tensor([10, 11, 13], device='cuda:0')
# 006+008 006+005 Good/Total: 3/3 Good proto idxs: tensor([1, 2, 3], device='cuda:0')
# 006+008 008+106 Good/Total: 3/3 Good proto idxs: tensor([10, 16, 19], device='cuda:0')
# 024+100 024+023 Good/Total: 6/6 Good proto idxs: tensor([0, 1, 2, 4, 8, 9], device='cuda:0')
# 024+100 100+101 Good/Total: 3/3 Good proto idxs: tensor([13, 14, 16], device='cuda:0')
# 001+045 001+003 Good/Total: 5/5 Good proto idxs: tensor([0, 1, 2, 4, 7], device='cuda:0')
# 001+045 cub_045_Northern_Fulmar Good/Total: 2/2 Good proto idxs: tensor([10, 19], device='cuda:0')
# 031+033 cub_031_Black_billed_Cuckoo Good/Total: 3/3 Good proto idxs: tensor([0, 1, 9], device='cuda:0')
# 031+033 cub_033_Yellow_billed_Cuckoo Good/Total: 3/3 Good proto idxs: tensor([15, 17, 19], device='cuda:0')
# 129+136 129+199 Good/Total: 0/7 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+136 136+085 Good/Total: 2/4 Good proto idxs: tensor([11, 12], device='cuda:0')
# 107+151 107+111 Good/Total: 5/7 Good proto idxs: tensor([1, 2, 3, 6, 7], device='cuda:0')
# 107+151 151+153 Good/Total: 6/6 Good proto idxs: tensor([10, 12, 13, 15, 16, 19], device='cuda:0')
# 043+040 043+037 Good/Total: 6/6 Good proto idxs: tensor([1, 4, 5, 7, 8, 9], device='cuda:0')
# 043+040 040+102 Good/Total: 2/2 Good proto idxs: tensor([13, 17], device='cuda:0')
# 078+041 078+077 Good/Total: 4/4 Good proto idxs: tensor([0, 1, 2, 7], device='cuda:0')
# 078+041 cub_041_Scissor_tailed_Flycatcher Good/Total: 2/2 Good proto idxs: tensor([14, 15], device='cuda:0')
# 192+187 192+190 Good/Total: 3/3 Good proto idxs: tensor([0, 2, 8], device='cuda:0')
# 192+187 cub_187_American_Three_toed_Woodpecker Good/Total: 3/3 Good proto idxs: tensor([17, 18, 19], device='cuda:0')
# 191+189 cub_191_Red_headed_Woodpecker Good/Total: 2/2 Good proto idxs: tensor([0, 3], device='cuda:0')
# 191+189 cub_189_Red_bellied_Woodpecker Good/Total: 2/2 Good proto idxs: tensor([12, 17], device='cuda:0')
# 081+080 cub_081_Pied_Kingfisher Good/Total: 3/3 Good proto idxs: tensor([0, 1, 8], device='cuda:0')
# 081+080 cub_080_Green_Kingfisher Good/Total: 2/2 Good proto idxs: tensor([12, 17], device='cuda:0')
# 082+079 cub_082_Ringed_Kingfisher Good/Total: 2/2 Good proto idxs: tensor([1, 8], device='cuda:0')
# 082+079 cub_079_Belted_Kingfisher Good/Total: 2/2 Good proto idxs: tensor([12, 14], device='cuda:0')
# 065+066 065+062 Good/Total: 4/4 Good proto idxs: tensor([0, 1, 3, 8], device='cuda:0')
# 065+066 cub_066_Western_Gull Good/Total: 3/3 Good proto idxs: tensor([16, 17, 19], device='cuda:0')
# 061+064 cub_061_Heermann_Gull Good/Total: 2/2 Good proto idxs: tensor([2, 9], device='cuda:0')
# 061+064 cub_064_Ring_billed_Gull Good/Total: 3/3 Good proto idxs: tensor([10, 11, 16], device='cuda:0')
# 144+142 144+145 Good/Total: 6/6 Good proto idxs: tensor([0, 1, 2, 6, 7, 9], device='cuda:0')
# 144+142 cub_142_Black_Tern Good/Total: 3/3 Good proto idxs: tensor([12, 14, 16], device='cuda:0')
# 006+005 006+007 Good/Total: 3/3 Good proto idxs: tensor([0, 3, 5], device='cuda:0')
# 006+005 cub_005_Crested_Auklet Good/Total: 2/2 Good proto idxs: tensor([11, 13], device='cuda:0')
# 008+106 cub_008_Rhinoceros_Auklet Good/Total: 3/3 Good proto idxs: tensor([1, 3, 8], device='cuda:0')
# 008+106 cub_106_Horned_Puffin Good/Total: 3/3 Good proto idxs: tensor([12, 15, 16], device='cuda:0')
# 024+023 024+025 Good/Total: 3/3 Good proto idxs: tensor([1, 5, 8], device='cuda:0')
# 024+023 cub_023_Brandt_Cormorant Good/Total: 3/3 Good proto idxs: tensor([15, 16, 18], device='cuda:0')
# 100+101 cub_100_Brown_Pelican Good/Total: 3/3 Good proto idxs: tensor([0, 5, 8], device='cuda:0')
# 100+101 cub_101_White_Pelican Good/Total: 2/2 Good proto idxs: tensor([10, 17], device='cuda:0')
# 001+003 001+002 Good/Total: 3/3 Good proto idxs: tensor([0, 7, 8], device='cuda:0')
# 001+003 cub_003_Sooty_Albatross Good/Total: 2/2 Good proto idxs: tensor([13, 14], device='cuda:0')
# 129+199 129+118 Good/Total: 0/7 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+199 199+186 Good/Total: 0/5 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 136+085 136+138 Good/Total: 4/4 Good proto idxs: tensor([0, 3, 4, 8], device='cuda:0')
# 136+085 cub_085_Horned_Lark Good/Total: 2/2 Good proto idxs: tensor([14, 18], device='cuda:0')
# 107+111 107+073 Good/Total: 7/7 Good proto idxs: tensor([1, 2, 3, 4, 6, 7, 9], device='cuda:0')
# 107+111 111+112 Good/Total: 3/3 Good proto idxs: tensor([10, 14, 15], device='cuda:0')
# 151+153 151+157 Good/Total: 6/6 Good proto idxs: tensor([0, 2, 3, 5, 6, 9], device='cuda:0')
# 151+153 153+154 Good/Total: 4/4 Good proto idxs: tensor([12, 13, 16, 19], device='cuda:0')
# 043+037 043+039 Good/Total: 3/3 Good proto idxs: tensor([1, 5, 9], device='cuda:0')
# 043+037 cub_037_Acadian_Flycatcher Good/Total: 4/4 Good proto idxs: tensor([10, 14, 17, 19], device='cuda:0')
# 040+102 cub_040_Olive_sided_Flycatcher Good/Total: 2/2 Good proto idxs: tensor([5, 6], device='cuda:0')
# 040+102 cub_102_Western_Wood_Pewee Good/Total: 2/2 Good proto idxs: tensor([10, 13], device='cuda:0')
# 078+077 cub_078_Gray_Kingbird Good/Total: 3/3 Good proto idxs: tensor([0, 3, 5], device='cuda:0')
# 078+077 cub_077_Tropical_Kingbird Good/Total: 2/2 Good proto idxs: tensor([12, 18], device='cuda:0')
# 192+190 cub_192_Downy_Woodpecker Good/Total: 2/2 Good proto idxs: tensor([0, 9], device='cuda:0')
# 192+190 cub_190_Red_cockaded_Woodpecker Good/Total: 2/2 Good proto idxs: tensor([11, 15], device='cuda:0')
# 065+062 065+059 Good/Total: 3/3 Good proto idxs: tensor([1, 7, 8], device='cuda:0')
# 065+062 cub_062_Herring_Gull Good/Total: 2/2 Good proto idxs: tensor([16, 18], device='cuda:0')
# 144+145 144+146 Good/Total: 4/4 Good proto idxs: tensor([1, 2, 4, 6], device='cuda:0')
# 144+145 cub_145_Elegant_Tern Good/Total: 2/2 Good proto idxs: tensor([16, 18], device='cuda:0')
# 006+007 cub_006_Least_Auklet Good/Total: 4/4 Good proto idxs: tensor([0, 1, 3, 6], device='cuda:0')
# 006+007 cub_007_Parakeet_Auklet Good/Total: 3/3 Good proto idxs: tensor([15, 16, 18], device='cuda:0')
# 024+025 cub_024_Red_faced_Cormorant Good/Total: 2/2 Good proto idxs: tensor([1, 9], device='cuda:0')
# 024+025 cub_025_Pelagic_Cormorant Good/Total: 2/2 Good proto idxs: tensor([14, 16], device='cuda:0')
# 001+002 cub_001_Black_footed_Albatross Good/Total: 2/2 Good proto idxs: tensor([2, 9], device='cuda:0')
# 001+002 cub_002_Laysan_Albatross Good/Total: 2/2 Good proto idxs: tensor([17, 19], device='cuda:0')
# 129+118 129+104 Good/Total: 0/5 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+118 cub_118_House_Sparrow Good/Total: 1/3 Good proto idxs: tensor([14], device='cuda:0')
# 199+186 199+150 Good/Total: 6/7 Good proto idxs: tensor([0, 2, 3, 5, 6, 9], device='cuda:0')
# 199+186 186+185 Good/Total: 4/4 Good proto idxs: tensor([11, 13, 14, 19], device='cuda:0')
# 136+138 136+137 Good/Total: 4/4 Good proto idxs: tensor([1, 4, 6, 7], device='cuda:0')
# 136+138 cub_138_Tree_Swallow Good/Total: 2/2 Good proto idxs: tensor([11, 15], device='cuda:0')
# 107+073 107+093 Good/Total: 7/7 Good proto idxs: tensor([0, 3, 4, 5, 7, 8, 9], device='cuda:0')
# 107+073 073+074 Good/Total: 2/2 Good proto idxs: tensor([15, 19], device='cuda:0')
# 111+112 cub_111_Loggerhead_Shrike Good/Total: 3/3 Good proto idxs: tensor([5, 7, 8], device='cuda:0')
# 111+112 cub_112_Great_Grey_Shrike Good/Total: 2/2 Good proto idxs: tensor([10, 19], device='cuda:0')
# 151+157 151+156 Good/Total: 3/3 Good proto idxs: tensor([2, 4, 6], device='cuda:0')
# 151+157 157+152 Good/Total: 3/3 Good proto idxs: tensor([11, 13, 19], device='cuda:0')
# 153+154 153+155 Good/Total: 4/4 Good proto idxs: tensor([2, 3, 5, 6], device='cuda:0')
# 153+154 cub_154_Red_eyed_Vireo Good/Total: 2/2 Good proto idxs: tensor([10, 15], device='cuda:0')
# 043+039 cub_043_Yellow_bellied_Flycatcher Good/Total: 3/3 Good proto idxs: tensor([3, 8, 9], device='cuda:0')
# 043+039 cub_039_Least_Flycatcher Good/Total: 3/3 Good proto idxs: tensor([14, 16, 18], device='cuda:0')
# 065+059 065+060 Good/Total: 2/2 Good proto idxs: tensor([2, 3], device='cuda:0')
# 065+059 cub_059_California_Gull Good/Total: 2/2 Good proto idxs: tensor([15, 16], device='cuda:0')
# 144+146 144+141 Good/Total: 4/4 Good proto idxs: tensor([1, 4, 5, 9], device='cuda:0')
# 144+146 cub_146_Forsters_Tern Good/Total: 2/2 Good proto idxs: tensor([12, 19], device='cuda:0')
# 129+104 129+035 Good/Total: 0/7 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+104 cub_104_American_Pipit Good/Total: 2/3 Good proto idxs: tensor([16, 19], device='cuda:0')
# 199+150 199+094 Good/Total: 4/7 Good proto idxs: tensor([1, 3, 4, 9], device='cuda:0')
# 199+150 150+019 Good/Total: 4/4 Good proto idxs: tensor([11, 14, 18, 19], device='cuda:0')
# 186+185 cub_186_Cedar_Waxwing Good/Total: 2/2 Good proto idxs: tensor([3, 4], device='cuda:0')
# 186+185 cub_185_Bohemian_Waxwing Good/Total: 3/3 Good proto idxs: tensor([16, 17, 19], device='cuda:0')
# 136+137 cub_136_Barn_Swallow Good/Total: 2/2 Good proto idxs: tensor([6, 7], device='cuda:0')
# 136+137 cub_137_Cliff_Swallow Good/Total: 3/3 Good proto idxs: tensor([10, 16, 17], device='cuda:0')
# 107+093 107+030 Good/Total: 5/5 Good proto idxs: tensor([1, 3, 4, 7, 9], device='cuda:0')
# 107+093 cub_093_Clark_Nutcracker Good/Total: 2/2 Good proto idxs: tensor([13, 19], device='cuda:0')
# 073+074 cub_073_Blue_Jay Good/Total: 1/1 Good proto idxs: tensor([6], device='cuda:0')
# 073+074 cub_074_Florida_Jay Good/Total: 2/2 Good proto idxs: tensor([17, 18], device='cuda:0')
# 151+156 cub_151_Black_capped_Vireo Good/Total: 3/3 Good proto idxs: tensor([1, 4, 7], device='cuda:0')
# 151+156 cub_156_White_eyed_Vireo Good/Total: 2/2 Good proto idxs: tensor([14, 15], device='cuda:0')
# 157+152 cub_157_Yellow_throated_Vireo Good/Total: 3/3 Good proto idxs: tensor([1, 6, 7], device='cuda:0')
# 157+152 cub_152_Blue_headed_Vireo Good/Total: 3/3 Good proto idxs: tensor([12, 15, 17], device='cuda:0')
# 153+155 cub_153_Philadelphia_Vireo Good/Total: 3/3 Good proto idxs: tensor([1, 2, 6], device='cuda:0')
# 153+155 cub_155_Warbling_Vireo Good/Total: 4/4 Good proto idxs: tensor([11, 14, 17, 19], device='cuda:0')
# 065+060 cub_065_Slaty_backed_Gull Good/Total: 2/2 Good proto idxs: tensor([0, 8], device='cuda:0')
# 065+060 cub_060_Glaucous_winged_Gull Good/Total: 2/2 Good proto idxs: tensor([11, 16], device='cuda:0')
# 144+141 cub_144_Common_Tern Good/Total: 4/4 Good proto idxs: tensor([0, 1, 2, 4], device='cuda:0')
# 144+141 cub_141_Artic_Tern Good/Total: 3/3 Good proto idxs: tensor([11, 15, 19], device='cuda:0')
# 129+035 129+054 Good/Total: 0/9 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+035 035+055 Good/Total: 3/4 Good proto idxs: tensor([11, 16, 18], device='cuda:0')
# 199+094 199+028 Good/Total: 7/7 Good proto idxs: tensor([0, 2, 3, 4, 5, 7, 9], device='cuda:0')
# 199+094 cub_094_White_breasted_Nuthatch Good/Total: 3/3 Good proto idxs: tensor([14, 16, 17], device='cuda:0')
# 150+019 150+149 Good/Total: 4/4 Good proto idxs: tensor([2, 4, 6, 9], device='cuda:0')
# 150+019 cub_019_Gray_Catbird Good/Total: 2/2 Good proto idxs: tensor([10, 14], device='cuda:0')
# 107+030 107+029 Good/Total: 3/3 Good proto idxs: tensor([5, 7, 9], device='cuda:0')
# 107+030 cub_030_Fish_Crow Good/Total: 3/3 Good proto idxs: tensor([11, 15, 16], device='cuda:0')
# 129+054 129+175 Good/Total: 0/8 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+054 054+140 Good/Total: 4/5 Good proto idxs: tensor([11, 15, 16, 19], device='cuda:0')
# 035+055 035+048 Good/Total: 7/7 Good proto idxs: tensor([0, 1, 2, 4, 5, 6, 7], device='cuda:0')
# 035+055 cub_055_Evening_Grosbeak Good/Total: 4/4 Good proto idxs: tensor([11, 15, 18, 19], device='cuda:0')
# 199+028 199+198 Good/Total: 7/7 Good proto idxs: tensor([0, 1, 2, 3, 6, 8, 9], device='cuda:0')
# 199+028 cub_028_Brown_Creeper Good/Total: 3/3 Good proto idxs: tensor([13, 16, 18], device='cuda:0')
# 150+149 150+091 Good/Total: 4/4 Good proto idxs: tensor([1, 5, 6, 9], device='cuda:0')
# 150+149 cub_149_Brown_Thrasher Good/Total: 3/3 Good proto idxs: tensor([11, 12, 15], device='cuda:0')
# 107+029 107+108 Good/Total: 3/3 Good proto idxs: tensor([0, 1, 6], device='cuda:0')
# 107+029 cub_029_American_Crow Good/Total: 2/2 Good proto idxs: tensor([17, 19], device='cuda:0')
# 129+175 129+011 Good/Total: 0/10 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+175 175+020 Good/Total: 0/6 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 054+140 054+057 Good/Total: 6/6 Good proto idxs: tensor([0, 1, 3, 4, 6, 7], device='cuda:0')
# 054+140 140+017 Good/Total: 4/4 Good proto idxs: tensor([10, 13, 14, 19], device='cuda:0')
# 035+048 035+056 Good/Total: 3/3 Good proto idxs: tensor([5, 7, 8], device='cuda:0')
# 035+048 048+047 Good/Total: 4/4 Good proto idxs: tensor([10, 16, 18, 19], device='cuda:0')
# 199+198 199+194 Good/Total: 6/6 Good proto idxs: tensor([0, 3, 4, 5, 6, 9], device='cuda:0')
# 199+198 cub_198_Rock_Wren Good/Total: 3/3 Good proto idxs: tensor([12, 14, 15], device='cuda:0')
# 150+091 cub_150_Sage_Thrasher Good/Total: 2/2 Good proto idxs: tensor([1, 3], device='cuda:0')
# 150+091 cub_091_Mockingbird Good/Total: 3/3 Good proto idxs: tensor([10, 15, 16], device='cuda:0')
# 107+108 cub_107_Common_Raven Good/Total: 3/3 Good proto idxs: tensor([1, 3, 8], device='cuda:0')
# 107+108 cub_108_White_necked_Raven Good/Total: 1/1 Good proto idxs: tensor([18], device='cuda:0')
# 129+011 129+121 Good/Total: 0/7 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+011 011+013 Good/Total: 1/6 Good proto idxs: tensor([14], device='cuda:0')
# 175+020 175+099 Good/Total: 0/8 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 175+020 cub_020_Yellow_breasted_Chat Good/Total: 4/4 Good proto idxs: tensor([11, 12, 13, 16], device='cuda:0')
# 054+057 054+014 Good/Total: 8/8 Good proto idxs: tensor([0, 1, 2, 3, 4, 6, 7, 8], device='cuda:0')
# 054+057 cub_057_Rose_breasted_Grosbeak Good/Total: 2/2 Good proto idxs: tensor([14, 17], device='cuda:0')
# 140+017 140+139 Good/Total: 4/4 Good proto idxs: tensor([4, 5, 6, 8], device='cuda:0')
# 140+017 cub_017_Cardinal Good/Total: 3/3 Good proto idxs: tensor([10, 14, 16], device='cuda:0')
# 035+056 035+034 Good/Total: 4/4 Good proto idxs: tensor([1, 3, 6, 7], device='cuda:0')
# 035+056 cub_056_Pine_Grosbeak Good/Total: 3/3 Good proto idxs: tensor([10, 14, 15], device='cuda:0')
# 048+047 cub_048_European_Goldfinch Good/Total: 2/2 Good proto idxs: tensor([2, 7], device='cuda:0')
# 048+047 cub_047_American_Goldfinch Good/Total: 2/2 Good proto idxs: tensor([12, 17], device='cuda:0')
# 199+194 199+193 Good/Total: 6/6 Good proto idxs: tensor([0, 1, 3, 4, 8, 9], device='cuda:0')
# 199+194 cub_194_Cactus_Wren Good/Total: 2/2 Good proto idxs: tensor([15, 17], device='cuda:0')
# 129+121 129+117 Good/Total: 3/6 Good proto idxs: tensor([2, 3, 8], device='cuda:0')
# 129+121 cub_121_Grasshopper_Sparrow Good/Total: 4/4 Good proto idxs: tensor([10, 11, 14, 17], device='cuda:0')
# 011+013 011+095 Good/Total: 4/6 Good proto idxs: tensor([0, 1, 4, 6], device='cuda:0')
# 011+013 013+088 Good/Total: 3/3 Good proto idxs: tensor([10, 11, 13], device='cuda:0')
# 175+099 175+181 Good/Total: 3/5 Good proto idxs: tensor([0, 5, 7], device='cuda:0')
# 175+099 cub_099_Ovenbird Good/Total: 6/6 Good proto idxs: tensor([10, 11, 12, 14, 16, 17], device='cuda:0')
# 054+014 054+016 Good/Total: 5/5 Good proto idxs: tensor([0, 1, 5, 6, 8], device='cuda:0')
# 054+014 cub_014_Indigo_Bunting Good/Total: 3/3 Good proto idxs: tensor([12, 17, 18], device='cuda:0')
# 140+139 cub_140_Summer_Tanager Good/Total: 2/2 Good proto idxs: tensor([0, 1], device='cuda:0')
# 140+139 cub_139_Scarlet_Tanager Good/Total: 2/2 Good proto idxs: tensor([16, 18], device='cuda:0')
# 035+034 cub_035_Purple_Finch Good/Total: 3/3 Good proto idxs: tensor([0, 1, 6], device='cuda:0')
# 035+034 cub_034_Gray_crowned_Rosy_Finch Good/Total: 3/3 Good proto idxs: tensor([10, 17, 19], device='cuda:0')
# 199+193 199+197 Good/Total: 6/6 Good proto idxs: tensor([1, 4, 5, 6, 7, 9], device='cuda:0')
# 199+193 193+195 Good/Total: 3/3 Good proto idxs: tensor([10, 13, 18], device='cuda:0')
# 129+117 129+133 Good/Total: 0/7 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 129+117 117+114 Good/Total: 5/6 Good proto idxs: tensor([10, 12, 15, 18, 19], device='cuda:0')
# 011+095 011+026 Good/Total: 7/7 Good proto idxs: tensor([0, 1, 5, 6, 7, 8, 9], device='cuda:0')
# 011+095 095+096 Good/Total: 5/5 Good proto idxs: tensor([11, 13, 14, 16, 18], device='cuda:0')
# 013+088 013+012 Good/Total: 4/4 Good proto idxs: tensor([1, 3, 6, 8], device='cuda:0')
# 013+088 cub_088_Western_Meadowlark Good/Total: 2/2 Good proto idxs: tensor([13, 16], device='cuda:0')
# 175+181 175+168+173+183 Good/Total: 0/7 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 175+181 cub_181_Worm_eating_Warbler Good/Total: 5/5 Good proto idxs: tensor([12, 15, 16, 17, 19], device='cuda:0')
# 054+016 054+015 Good/Total: 4/4 Good proto idxs: tensor([2, 3, 4, 5], device='cuda:0')
# 054+016 cub_016_Painted_Bunting Good/Total: 2/2 Good proto idxs: tensor([12, 17], device='cuda:0')
# 199+197 199+196 Good/Total: 2/2 Good proto idxs: tensor([0, 8], device='cuda:0')
# 199+197 cub_197_Marsh_Wren Good/Total: 2/2 Good proto idxs: tensor([10, 19], device='cuda:0')
# 193+195 cub_193_Bewick_Wren Good/Total: 2/2 Good proto idxs: tensor([4, 6], device='cuda:0')
# 193+195 cub_195_Carolina_Wren Good/Total: 3/3 Good proto idxs: tensor([12, 13, 14], device='cuda:0')
# 129+133 129+021 Good/Total: 3/7 Good proto idxs: tensor([3, 6, 7], device='cuda:0')
# 129+133 133+130 Good/Total: 4/6 Good proto idxs: tensor([14, 15, 18, 19], device='cuda:0')
# 117+114 117+115 Good/Total: 7/7 Good proto idxs: tensor([0, 1, 2, 4, 7, 8, 9], device='cuda:0')
# 117+114 cub_114_Black_throated_Sparrow Good/Total: 2/2 Good proto idxs: tensor([13, 15], device='cuda:0')
# 011+026 011+049 Good/Total: 3/3 Good proto idxs: tensor([3, 5, 8], device='cuda:0')
# 011+026 026+010 Good/Total: 4/4 Good proto idxs: tensor([11, 16, 17, 19], device='cuda:0')
# 095+096 095+098 Good/Total: 4/4 Good proto idxs: tensor([0, 3, 4, 8], device='cuda:0')
# 095+096 096+097 Good/Total: 4/4 Good proto idxs: tensor([10, 15, 16, 17], device='cuda:0')
# 013+012 cub_013_Bobolink Good/Total: 2/2 Good proto idxs: tensor([5, 8], device='cuda:0')
# 013+012 cub_012_Yellow_headed_Blackbird Good/Total: 3/3 Good proto idxs: tensor([10, 11, 14], device='cuda:0')
# 175+168+173+183 175+162 Good/Total: 0/8 Good proto idxs: tensor([], device='cuda:0', dtype=torch.int64)
# 175+168+173+183 168+177 Good/Total: 3/6 Good proto idxs: tensor([10, 12, 14], device='cuda:0')
# 175+168+173+183 173+161 Good/Total: 3/6 Good proto idxs: tensor([22, 23, 27], device='cuda:0')
# 175+168+173+183 183+159 Good/Total: 5/5 Good proto idxs: tensor([30, 32, 35, 36, 38], device='cuda:0')
# 054+015 cub_054_Blue_Grosbeak Good/Total: 2/2 Good proto idxs: tensor([1, 7], device='cuda:0')
# 054+015 cub_015_Lazuli_Bunting Good/Total: 2/2 Good proto idxs: tensor([16, 19], device='cuda:0')
# 199+196 cub_199_Winter_Wren Good/Total: 2/2 Good proto idxs: tensor([0, 3], device='cuda:0')
# 199+196 cub_196_House_Wren Good/Total: 2/2 Good proto idxs: tensor([12, 13], device='cuda:0')
# 129+021 129+128 Good/Total: 6/6 Good proto idxs: tensor([0, 2, 4, 6, 8, 9], device='cuda:0')
# 129+021 021+148 Good/Total: 3/3 Good proto idxs: tensor([10, 14, 18], device='cuda:0')
# 133+130 133+076 Good/Total: 4/4 Good proto idxs: tensor([1, 2, 5, 9], device='cuda:0')
# 133+130 130+120 Good/Total: 4/4 Good proto idxs: tensor([10, 14, 15, 19], device='cuda:0')
# 117+115 117+116 Good/Total: 4/4 Good proto idxs: tensor([0, 5, 6, 9], device='cuda:0')
# 117+115 115+119 Good/Total: 4/4 Good proto idxs: tensor([11, 16, 18, 19], device='cuda:0')
# 011+049 011+009 Good/Total: 4/4 Good proto idxs: tensor([0, 2, 6, 9], device='cuda:0')
# 011+049 cub_049_Boat_tailed_Grackle Good/Total: 3/3 Good proto idxs: tensor([10, 14, 15], device='cuda:0')
# 026+010 026+027 Good/Total: 3/3 Good proto idxs: tensor([3, 5, 9], device='cuda:0')
# 026+010 cub_010_Red_winged_Blackbird Good/Total: 1/1 Good proto idxs: tensor([18], device='cuda:0')
# 095+098 cub_095_Baltimore_Oriole Good/Total: 2/2 Good proto idxs: tensor([2, 7], device='cuda:0')
# 095+098 cub_098_Scott_Oriole Good/Total: 2/2 Good proto idxs: tensor([10, 19], device='cuda:0')
# 096+097 cub_096_Hooded_Oriole Good/Total: 2/2 Good proto idxs: tensor([0, 6], device='cuda:0')
# 096+097 cub_097_Orchard_Oriole Good/Total: 2/2 Good proto idxs: tensor([14, 15], device='cuda:0')
# 175+162 175+167 Good/Total: 7/8 Good proto idxs: tensor([0, 3, 5, 6, 7, 8, 9], device='cuda:0')
# 175+162 162+180 Good/Total: 3/3 Good proto idxs: tensor([11, 12, 14], device='cuda:0')
# 168+177 168+200 Good/Total: 4/4 Good proto idxs: tensor([1, 2, 3, 5], device='cuda:0')
# 168+177 177+178 Good/Total: 3/3 Good proto idxs: tensor([10, 12, 17], device='cuda:0')
# 173+161 173+179 Good/Total: 4/4 Good proto idxs: tensor([3, 5, 6, 7], device='cuda:0')
# 173+161 161+166 Good/Total: 2/2 Good proto idxs: tensor([13, 14], device='cuda:0')
# 183+159 183+184 Good/Total: 3/3 Good proto idxs: tensor([1, 2, 4], device='cuda:0')
# 183+159 cub_159_Black_and_white_Warbler Good/Total: 3/3 Good proto idxs: tensor([11, 15, 17], device='cuda:0')
# 129+128 129+127 Good/Total: 5/5 Good proto idxs: tensor([1, 3, 5, 6, 9], device='cuda:0')
# 129+128 128+131 Good/Total: 5/5 Good proto idxs: tensor([11, 12, 13, 15, 18], device='cuda:0')
# 021+148 cub_021_Eastern_Towhee Good/Total: 2/2 Good proto idxs: tensor([2, 5], device='cuda:0')
# 021+148 cub_148_Green_tailed_Towhee Good/Total: 3/3 Good proto idxs: tensor([16, 18, 19], device='cuda:0')
# 133+076 133+132 Good/Total: 4/4 Good proto idxs: tensor([0, 1, 4, 7], device='cuda:0')
# 133+076 cub_076_Dark_eyed_Junco Good/Total: 3/3 Good proto idxs: tensor([10, 14, 16], device='cuda:0')
# 130+120 cub_130_Tree_Sparrow Good/Total: 2/2 Good proto idxs: tensor([1, 3], device='cuda:0')
# 130+120 cub_120_Fox_Sparrow Good/Total: 3/3 Good proto idxs: tensor([12, 15, 16], device='cuda:0')
# 117+116 cub_117_Clay_colored_Sparrow Good/Total: 1/1 Good proto idxs: tensor([8], device='cuda:0')
# 117+116 cub_116_Chipping_Sparrow Good/Total: 2/2 Good proto idxs: tensor([13, 16], device='cuda:0')
# 115+119 cub_115_Brewer_Sparrow Good/Total: 3/3 Good proto idxs: tensor([5, 6, 7], device='cuda:0')
# 115+119 cub_119_Field_Sparrow Good/Total: 3/3 Good proto idxs: tensor([14, 15, 18], device='cuda:0')
# 011+009 cub_011_Rusty_Blackbird Good/Total: 3/3 Good proto idxs: tensor([3, 5, 7], device='cuda:0')
# 011+009 cub_009_Brewer_Blackbird Good/Total: 2/2 Good proto idxs: tensor([10, 13], device='cuda:0')
# 026+027 cub_026_Bronzed_Cowbird Good/Total: 2/2 Good proto idxs: tensor([1, 3], device='cuda:0')
# 026+027 cub_027_Shiny_Cowbird Good/Total: 3/3 Good proto idxs: tensor([15, 16, 19], device='cuda:0')
# 175+167 175+169 Good/Total: 5/6 Good proto idxs: tensor([1, 2, 3, 6, 9], device='cuda:0')
# 175+167 cub_167_Hooded_Warbler Good/Total: 2/2 Good proto idxs: tensor([11, 13], device='cuda:0')
# 162+180 cub_162_Canada_Warbler Good/Total: 3/3 Good proto idxs: tensor([0, 5, 6], device='cuda:0')
# 162+180 cub_180_Wilson_Warbler Good/Total: 3/3 Good proto idxs: tensor([12, 16, 17], device='cuda:0')
# 168+200 168+170 Good/Total: 5/5 Good proto idxs: tensor([0, 2, 3, 5, 6], device='cuda:0')
# 168+200 cub_200_Common_Yellowthroat Good/Total: 2/2 Good proto idxs: tensor([10, 15], device='cuda:0')
# 177+178 cub_177_Prothonotary_Warbler Good/Total: 3/3 Good proto idxs: tensor([0, 2, 9], device='cuda:0')
# 177+178 cub_178_Swainson_Warbler Good/Total: 2/2 Good proto idxs: tensor([15, 17], device='cuda:0')
# 173+179 173+172 Good/Total: 3/3 Good proto idxs: tensor([0, 7, 9], device='cuda:0')
# 173+179 cub_179_Tennessee_Warbler Good/Total: 3/3 Good proto idxs: tensor([14, 16, 17], device='cuda:0')
# 161+166 cub_161_Blue_winged_Warbler Good/Total: 2/2 Good proto idxs: tensor([3, 5], device='cuda:0')
# 161+166 cub_166_Golden_winged_Warbler Good/Total: 3/3 Good proto idxs: tensor([10, 11, 12], device='cuda:0')
# 183+184 cub_183_Northern_Waterthrush Good/Total: 2/2 Good proto idxs: tensor([0, 9], device='cuda:0')
# 183+184 cub_184_Louisiana_Waterthrush Good/Total: 2/2 Good proto idxs: tensor([11, 19], device='cuda:0')
# 129+127 129+123 Good/Total: 4/4 Good proto idxs: tensor([0, 4, 5, 7], device='cuda:0')
# 129+127 cub_127_Savannah_Sparrow Good/Total: 2/2 Good proto idxs: tensor([14, 17], device='cuda:0')
# 128+131 128+124 Good/Total: 4/4 Good proto idxs: tensor([0, 5, 6, 9], device='cuda:0')
# 128+131 cub_131_Vesper_Sparrow Good/Total: 3/3 Good proto idxs: tensor([10, 17, 19], device='cuda:0')
# 133+132 133+122 Good/Total: 3/3 Good proto idxs: tensor([0, 3, 4], device='cuda:0')
# 133+132 cub_132_White_crowned_Sparrow Good/Total: 2/2 Good proto idxs: tensor([12, 16], device='cuda:0')
# 175+169 175+165+182 Good/Total: 5/5 Good proto idxs: tensor([0, 2, 3, 5, 9], device='cuda:0')
# 175+169 cub_169_Magnolia_Warbler Good/Total: 3/3 Good proto idxs: tensor([14, 16, 17], device='cuda:0')
# 168+170 cub_168_Kentucky_Warbler Good/Total: 2/2 Good proto idxs: tensor([1, 2], device='cuda:0')
# 168+170 cub_170_Mourning_Warbler Good/Total: 2/2 Good proto idxs: tensor([11, 18], device='cuda:0')
# 173+172 cub_173_Orange_crowned_Warbler Good/Total: 3/3 Good proto idxs: tensor([4, 6, 9], device='cuda:0')
# 173+172 cub_172_Nashville_Warbler Good/Total: 2/2 Good proto idxs: tensor([14, 18], device='cuda:0')
# 129+123 129+125 Good/Total: 3/3 Good proto idxs: tensor([0, 5, 9], device='cuda:0')
# 129+123 123+113 Good/Total: 4/4 Good proto idxs: tensor([10, 13, 15, 18], device='cuda:0')
# 128+124 128+126 Good/Total: 3/3 Good proto idxs: tensor([1, 2, 6], device='cuda:0')
# 128+124 cub_124_Le_Conte_Sparrow Good/Total: 2/2 Good proto idxs: tensor([14, 18], device='cuda:0')
# 133+122 cub_133_White_throated_Sparrow Good/Total: 2/2 Good proto idxs: tensor([3, 5], device='cuda:0')
# 133+122 cub_122_Harris_Sparrow Good/Total: 2/2 Good proto idxs: tensor([10, 16], device='cuda:0')
# 175+165+182 175+160 Good/Total: 4/4 Good proto idxs: tensor([1, 6, 7, 8], device='cuda:0')
# 175+165+182 165+164+163 Good/Total: 6/6 Good proto idxs: tensor([10, 11, 13, 15, 16, 19], device='cuda:0')
# 175+165+182 cub_182_Yellow_Warbler Good/Total: 3/3 Good proto idxs: tensor([20, 24, 28], device='cuda:0')
# 129+125 cub_129_Song_Sparrow Good/Total: 2/2 Good proto idxs: tensor([3, 4], device='cuda:0')
# 129+125 cub_125_Lincoln_Sparrow Good/Total: 2/2 Good proto idxs: tensor([11, 16], device='cuda:0')
# 123+113 cub_123_Henslow_Sparrow Good/Total: 3/3 Good proto idxs: tensor([1, 6, 9], device='cuda:0')
# 123+113 cub_113_Baird_Sparrow Good/Total: 2/2 Good proto idxs: tensor([15, 19], device='cuda:0')
# 128+126 cub_128_Seaside_Sparrow Good/Total: 2/2 Good proto idxs: tensor([3, 8], device='cuda:0')
# 128+126 cub_126_Nelson_Sharp_tailed_Sparrow Good/Total: 2/2 Good proto idxs: tensor([10, 15], device='cuda:0')
# 175+160 175+176 Good/Total: 5/5 Good proto idxs: tensor([0, 1, 3, 5, 8], device='cuda:0')
# 175+160 160+109 Good/Total: 4/4 Good proto idxs: tensor([11, 12, 13, 16], device='cuda:0')
# 165+164+163 165+158 Good/Total: 2/2 Good proto idxs: tensor([2, 3], device='cuda:0')
# 165+164+163 cub_164_Cerulean_Warbler Good/Total: 4/4 Good proto idxs: tensor([11, 12, 14, 19], device='cuda:0')
# 165+164+163 cub_163_Cape_May_Warbler Good/Total: 3/3 Good proto idxs: tensor([26, 28, 29], device='cuda:0')
# 175+176 175+174 Good/Total: 3/3 Good proto idxs: tensor([1, 5, 6], device='cuda:0')
# 175+176 cub_176_Prairie_Warbler Good/Total: 2/2 Good proto idxs: tensor([16, 18], device='cuda:0')
# 160+109 cub_160_Black_throated_Blue_Warbler Good/Total: 5/5 Good proto idxs: tensor([0, 1, 5, 6, 7], device='cuda:0')
# 160+109 cub_109_American_Redstart Good/Total: 3/3 Good proto idxs: tensor([12, 13, 15], device='cuda:0')
# 165+158 cub_165_Chestnut_sided_Warbler Good/Total: 2/2 Good proto idxs: tensor([6, 7], device='cuda:0')
# 165+158 cub_158_Bay_breasted_Warbler Good/Total: 2/2 Good proto idxs: tensor([12, 18], device='cuda:0')
# 175+174 cub_175_Pine_Warbler Good/Total: 2/2 Good proto idxs: tensor([3, 8], device='cuda:0')
# 175+174 cub_174_Palm_Warbler Good/Total: 2/2 Good proto idxs: tensor([15, 16], device='cuda:0')
# Total protos: 1368.0 Total good protos: 1133.0 Ratio: 0.8282163742690059

# %% [markdown]
# # Pruning based on thresholding

# %%
# Proto activations on leaf descendents - topk images

from util.data import ModifiedLabelLoader
from collections import defaultdict
import heapq
import pdb
from util.vis_pipnet import get_img_coordinates
import torchvision.transforms as transforms
from PIL import ImageFont, Image, ImageDraw as D
import torchvision
from datetime import datetime
from PIL import Image, ImageDraw, ImageFont
import math
from datetime import datetime

vizloader_name = 'testloader' # projectloader
find_non_descendants = False # True, False # param
topk = 10
plot_overspecificity_score = True
subtree_root = root#.get_node('024+051')
    
def get_heap():
    list_ = []
    heapq.heapify(list_)
    return list_

patchsize, skip = get_patch_size(args)

maindataloader_copy = unshuffle_dataloader(maindataloader)


if type(maindataloader_copy.dataset) == ImageFolder:
    name2label = maindataloader_copy.dataset.class_to_idx
    label2name = {label:name for name, label in name2label.items()}
else:
    name2label = maindataloader_copy.dataset.dataset.dataset.class_to_idx
    label2name = {label:name for name, label in name2label.items()}
    
overspecificity_score_and_proto_mask = []
nodeproto_overspecificity_score = defaultdict(dict)

for node in root.nodes_with_children():
#     if node.name == 'root':
#         continue
#     non_leaf_children_names = [child.name for child in node.children if not child.is_leaf()]
#     if len(non_leaf_children_names) == 0: # if all the children are leaf nodes then skip this node
#         continue

    if (node.name not in subtree_root.descendents) and (node.name != subtree_root.name):
        print('Skipping node', node.name)
        continue

    name2label = maindataloader_copy.dataset.class_to_idx
    label2name = {label:name for name, label in name2label.items()}
    modifiedLabelLoader = ModifiedLabelLoader(maindataloader_copy, node)
    coarse_label2name = modifiedLabelLoader.modifiedlabel2name
    node_label_to_children = {label: name for name, label in node.children_to_labels.items()}
    
    imgs = modifiedLabelLoader.filtered_imgs

    img_iter = tqdm(enumerate(modifiedLabelLoader),
                    total=len(modifiedLabelLoader),
                    mininterval=50.,
                    desc='Collecting topk',
                    ncols=0)

    classification_weights = getattr(net.module, '_'+node.name+'_classification').weight
    
    # maps proto_number -> grand_child_name (or descendant leaf name) -> list of top-k activations
    proto_mean_activations = defaultdict(lambda: defaultdict(get_heap))

    # maps class names to the prototypes that belong to that
    class_and_prototypes = defaultdict(set)

    for i, (xs, orig_y, ys) in img_iter:
#         if coarse_label2name[ys.item()] not in non_leaf_children_names:
#             continue

        xs, ys = xs.to(device), ys.to(device)

        with torch.no_grad():
            model_output = net(xs, inference=False)
            if len(model_output) == 3:
                softmaxes, pooled, _ = model_output
            elif len(model_output) == 4:
                _, softmaxes, pooled, _ = model_output
            pooled = pooled[node.name].squeeze(0) 
            softmaxes = softmaxes[node.name]#.squeeze(0)

            for p in range(pooled.shape[0]): # pooled.shape -> [768] (== num of prototypes)
                c_weight = torch.max(classification_weights[:,p]) # classification_weights[:,p].shape -> [200] (== num of classes)
                relevant_proto_classes = torch.nonzero(classification_weights[:, p] > 1e-3)
                relevant_proto_class_names = [node_label_to_children[class_idx.item()] for class_idx in relevant_proto_classes]
                
                # Take the max per prototype.                             
                max_per_prototype, max_idx_per_prototype = torch.max(softmaxes, dim=0)
                max_per_prototype_h, max_idx_per_prototype_h = torch.max(max_per_prototype, dim=1)
                max_per_prototype_w, max_idx_per_prototype_w = torch.max(max_per_prototype_h, dim=1) #shape (num_prototypes)
                
                h_idx = max_idx_per_prototype_h[p, max_idx_per_prototype_w[p]]
                w_idx = max_idx_per_prototype_w[p]

                if len(relevant_proto_class_names) == 0:
                    continue
                
#                 if (len(relevant_proto_class_names) == 1) and (relevant_proto_class_names[0] not in non_leaf_children_names):
#                     continue
                
                h_coor_min, h_coor_max, w_coor_min, w_coor_max = get_img_coordinates(args.image_size, softmaxes.shape, patchsize, skip, h_idx, w_idx)
                latent_activation = softmaxes[:, p, :, :]
                
                if not find_non_descendants:
                    if (coarse_label2name[ys.item()] in relevant_proto_class_names):
                        child_node = root.get_node(coarse_label2name[ys.item()])
                        leaf_descendent = label2name[orig_y.item()]#[4:7]
                        img_to_open = imgs[i][0] # it is a tuple of (path to image, lable)
                        if topk and (len(proto_mean_activations[p][leaf_descendent]) >= topk):
                            heapq.heappushpop(proto_mean_activations[p][leaf_descendent],\
                                              (pooled[p].item(), img_to_open,\
                                               (h_coor_min, h_coor_max, w_coor_min, w_coor_max), latent_activation))
                        else:
                            heapq.heappush(proto_mean_activations[p][leaf_descendent],\
                                           (pooled[p].item(), img_to_open,\
                                            (h_coor_min, h_coor_max, w_coor_min, w_coor_max), latent_activation))
                else:
                    if (coarse_label2name[ys.item()] not in relevant_proto_class_names):
                        child_node = root.get_node(coarse_label2name[ys.item()])
                        leaf_descendent = label2name[orig_y.item()]#[4:7]
                        img_to_open = imgs[i][0] # it is a tuple of (path to image, lable)
                        if topk and (len(proto_mean_activations[p][leaf_descendent]) >= topk):
                            heapq.heappushpop(proto_mean_activations[p][leaf_descendent],\
                                              (pooled[p].item(), img_to_open,\
                                               (h_coor_min, h_coor_max, w_coor_min, w_coor_max), latent_activation))
                        else:
                            heapq.heappush(proto_mean_activations[p][leaf_descendent],\
                                           (pooled[p].item(), img_to_open,\
                                            (h_coor_min, h_coor_max, w_coor_min, w_coor_max), latent_activation))

                class_and_prototypes[', '.join(relevant_proto_class_names)].add(p)

    # write_num_proto_details(proto_mean_activations, node.name, net, threshold=0.2, txt_file=txt_file, args=args)

    if plot_overspecificity_score:
        for child_classname in class_and_prototypes:
            for p in class_and_prototypes[child_classname]:
                mean_activation_of_every_leaf = []
                for leaf_descendent in proto_mean_activations[p]:
                    mean_activation = round(np.mean([activation for activation, *_ in proto_mean_activations[p][leaf_descendent]]), 4)
                    mean_activation_of_every_leaf.append(mean_activation)

                overspecificity_score = 1
                for mean_act in mean_activation_of_every_leaf:
                    overspecificity_score *= mean_act * 1.0
                proto_presence = getattr(net.module, '_'+node.name+'_proto_presence')
                proto_presence = F.gumbel_softmax(proto_presence, tau=0.5, hard=True, dim=-1)
                proto_mask = proto_presence[p, 1].item()
                overspecificity_score_and_proto_mask.append((overspecificity_score, len(mean_activation_of_every_leaf), proto_mask))

                nodeproto_overspecificity_score[node.name][p] = overspecificity_score

    print('Node', node.name)
    for child_classname in class_and_prototypes:
        
        print('\t'*1, 'Child:', child_classname)
        for p in class_and_prototypes[child_classname]:
            
            logstr = '\t'*2 + f'Proto:{p} '
            mean_activation_of_every_leaf = []
            for leaf_descendent in proto_mean_activations[p]:
                mean_activation = round(np.mean([activation for activation, *_ in proto_mean_activations[p][leaf_descendent]]), 4)
                num_images = len(proto_mean_activations[p][leaf_descendent])
                logstr += f'{leaf_descendent}:({mean_activation}) '
                mean_activation_of_every_leaf.append(mean_activation)
            print(logstr)
# Out:
# Collecting topk: 5512it [03:54, 23.47it/s]
# Node root
# 	 Child: 129+024+067
# 		Proto:1 cub_001_Black_footed_Albatross:(0.6081) cub_002_Laysan_Albatross:(0.9775) cub_003_Sooty_Albatross:(0.5331) cub_004_Groove_billed_Ani:(0.9143) cub_005_Crested_Auklet:(0.7488) cub_006_Least_Auklet:(0.6389) cub_007_Parakeet_Auklet:(0.9029) cub_008_Rhinoceros_Auklet:(0.415) cub_009_Brewer_Blackbird:(0.9852) cub_010_Red_winged_Blackbird:(0.9831) cub_011_Rusty_Blackbird:(0.9638) cub_012_Yellow_headed_Blackbird:(0.9737) cub_013_Bobolink:(0.9815) cub_014_Indigo_Bunting:(0.9625) cub_015_Lazuli_Bunting:(0.9491) cub_016_Painted_Bunting:(0.9924) cub_017_Cardinal:(0.9933) cub_018_Spotted_Catbird:(0.9505) cub_019_Gray_Catbird:(0.9788) cub_020_Yellow_breasted_Chat:(0.983) cub_021_Eastern_Towhee:(0.9758) cub_023_Brandt_Cormorant:(0.6744) cub_024_Red_faced_Cormorant:(0.8137) cub_025_Pelagic_Cormorant:(0.9331) cub_026_Bronzed_Cowbird:(0.9842) cub_027_Shiny_Cowbird:(0.988) cub_028_Brown_Creeper:(0.9222) cub_029_American_Crow:(0.9655) cub_030_Fish_Crow:(0.9743) cub_031_Black_billed_Cuckoo:(0
# 	 Child: 051+052
# 		Proto:13 cub_050_Eared_Grebe:(0.9989) cub_051_Horned_Grebe:(0.9889) cub_052_Pied_billed_Grebe:(0.9925) cub_053_Western_Grebe:(0.9783)
# 		Proto:16 cub_050_Eared_Grebe:(0.9098) cub_051_Horned_Grebe:(0.8966) cub_052_Pied_billed_Grebe:(0.9211) cub_053_Western_Grebe:(0.8255)
# 		Proto:17 cub_050_Eared_Grebe:(0.997) cub_051_Horned_Grebe:(0.9884) cub_052_Pied_billed_Grebe:(0.981) cub_053_Western_Grebe:(0.9985)
# 		Proto:18 cub_050_Eared_Grebe:(0.7339) cub_051_Horned_Grebe:(0.7567) cub_052_Pied_billed_Grebe:(0.8026) cub_053_Western_Grebe:(0.6341)
# 		Proto:19 cub_050_Eared_Grebe:(0.9995) cub_051_Horned_Grebe:(0.9999) cub_052_Pied_billed_Grebe:(0.998) cub_053_Western_Grebe:(0.9987)
# Collecting topk: 120it [00:10, 11.05it/s]
# Node 067+070
# 	 Child: 067+068
# 		Proto:0 cub_067_Anna_Hummingbird:(0.9978) cub_068_Ruby_throated_Hummingbird:(0.9988) cub_069_Rufous_Hummingbird:(0.9996)
# 		Proto:9 cub_067_Anna_Hummingbird:(1.0) cub_068_Ruby_throated_Hummingbird:(0.9999) cub_069_Rufous_Hummingbird:(0.9995)
# 		Proto:2 cub_067_Anna_Hummingbird:(0.9989) cub_068_Ruby_throated_Hummingbird:(0.9998) cub_069_Rufous_Hummingbird:(0.9999)
# 		Proto:4 cub_067_Anna_Hummingbird:(0.9987) cub_068_Ruby_throated_Hummingbird:(0.9984) cub_069_Rufous_Hummingbird:(0.999)
# 	 Child: cub_070_Green_Violetear
# 		Proto:14 cub_070_Green_Violetear:(0.9996)
# 		Proto:15 cub_070_Green_Violetear:(0.9999)
# Collecting topk: 100% 60/60 [00:08<00:00,  7.11it/s]
# Node 089+090
# 	 Child: cub_089_Hooded_Merganser
# 		Proto:2 cub_089_Hooded_Merganser:(1.0)
# 		Proto:4 cub_089_Hooded_Merganser:(1.0)
# 	 Child: cub_090_Red_breasted_Merganser
# 		Proto:16 cub_090_Red_breasted_Merganser:(0.9998)
# 		Proto:10 cub_090_Red_breasted_Merganser:(0.9999)
# 		Proto:18 cub_090_Red_breasted_Merganser:(1.0)
# Collecting topk: 100% 60/60 [00:08<00:00,  6.86it/s]
# Node 046+087
# 	 Child: cub_046_Gadwall
# 		Proto:3 cub_046_Gadwall:(1.0)
# 		Proto:6 cub_046_Gadwall:(1.0)
# 	 Child: cub_087_Mallard
# 		Proto:18 cub_087_Mallard:(0.9999)
# 		Proto:19 cub_087_Mallard:(1.0)
# Collecting topk: 4116it [03:01, 22.71it/s]
# Node 129+192
# 	 Child: 129+043
# ...
# 		Proto:19 cub_036_Northern_Flicker:(0.1804) cub_079_Belted_Kingfisher:(0.0972) cub_080_Green_Kingfisher:(0.1016) cub_081_Pied_Kingfisher:(0.1094) cub_082_Ringed_Kingfisher:(0.0889) cub_083_White_breasted_Kingfisher:(0.1603) cub_187_American_Three_toed_Woodpecker:(0.1439) cub_188_Pileated_Woodpecker:(0.2193) cub_189_Red_bellied_Woodpecker:(0.2379) cub_190_Red_cockaded_Woodpecker:(0.1977) cub_191_Red_headed_Woodpecker:(0.2238) cub_192_Downy_Woodpecker:(0.1542)
# Collecting topk: 0it [00:00, ?it/s]

# %% [markdown]
# ## Calculate Part Purity (prune based on threshold)

# %%
threshold = 0.4

total_proto_count = 0
masked_count = 0

node_wise_purity = []
node_wise_purity_of_unmasked = []
node_wise_purity_of_masked = []
for csvfile_topk, node in zip(list_csvfile_topk, root.nodes_with_children()):

    if node.name not in subtree_root.descendents:
        print('Skipping node', node.name)
        continue
        
    node_purity, max_presence_purity = eval_prototypes_cub_parts_csv_nodewise_maxmin(node, csvfile_topk, part_locs_file, parts_name_path, \
                              imgs_id_path, 'projectloader_topk_'+str(epoch), args, desc_threshold=0.2)
    node_wise_purity.append(node_purity)

    total_proto_count += len(nodeproto_overspecificity_score[node.name])
    for p in max_presence_purity:
        if nodeproto_overspecificity_score[node.name][int(p)] < threshold:
            masked_count += 1
        

    # # max_presence_purity[p] for p in max_presence_purity if nodeproto_overspecificity_score[node.name][int(p)] >= threshold
    # node_wise_purity_of_unmasked.append(np.mean([max_presence_purity[p] for p in max_presence_purity if nodeproto_overspecificity_score[node.name][int(p)] >= threshold]))
    # node_wise_purity_of_masked.append(np.mean([max_presence_purity[p] for p in max_presence_purity if nodeproto_overspecificity_score[node.name][int(p)] < threshold]))

    node_wise_purity_of_unmasked += [max_presence_purity[p] for p in max_presence_purity if nodeproto_overspecificity_score[node.name][int(p)] >= threshold]
    node_wise_purity_of_masked += [max_presence_purity[p] for p in max_presence_purity if nodeproto_overspecificity_score[node.name][int(p)] < threshold]
    
    # proto_presence = getattr(net.module, '_'+node.name+'_proto_presence')
    # node_wise_purity_of_unmasked.append(np.mean([max_presence_purity[p] for p in max_presence_purity if (proto_presence[int(p), 0] < proto_presence[int(p), 1])]))
    # node_wise_purity_of_masked.append(np.mean([max_presence_purity[p] for p in max_presence_purity if (proto_presence[int(p), 0] > proto_presence[int(p), 1])]))
# Out:
# Skipping node root
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 1
# Node: 129+024+067 | Child: 024+051 | Purity: 0.15 | Num desc: 18 | Num protos: 2
# 	Proto: 8 0.3
# 	Proto: 7 0.0
# Node: 129+024+067 | Child: 129+065 | Purity: 0.3 | Num desc: 164 | Num protos: 1
# 	Proto: 1 0.3
# Node: 129+024+067 | Child: 067+070 | Purity: 0.6 | Num desc: 4 | Num protos: 2
# 	Proto: 16 0.2
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5):
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 8
# Node: 144+147 | Child: 144+143 | Purity: 0.7355555555555555 | Num desc: 6 | Num protos: 5
# 	Proto: 1 1.0
# 	Proto: 2 0.0
# 	Proto: 0 0.9
# 	Proto: 3 0.8888888888888888
# 	Proto: 7 0.8888888888888888
# Node: 144+147 | Child: cub_147_Least_Tern | Purity: 1.0 | Num desc: 1 | Num protos: 4
# 	Proto: 12 1.0
# 	Proto: 18 1.0
# 	Proto: 19 1.0
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 6
# Node: 006+058 | Child: 006+008 | Purity: 0.5944444444444444 | Num desc: 5 | Num protos: 6
# 	Proto: 1 0.5
# 	Proto: 6 0.5
# 	Proto: 5 0.1111111111111111
# 	Proto: 2 0.5555555555555556
# 	Proto: 0 0.9
# 	Proto: 8 1.0
# Node: 006+058 | Child: cub_058_Pigeon_Guillemot | Purity: 0.8666666666666666 | Num desc: 1 | Num protos: 3
# 	Proto: 16 0.9
# 	Proto: 14 1.0
# 	Proto: 17 0.7
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 071+072 | Child: cub_071_Long_tailed_Jaeger | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 1 1.0
# 	Proto: 9 0.9
# Node: 071+072 | Child: cub_072_Pomarine_Jaeger | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 10 1.0
# 	Proto: 14 1.0
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 6
# Node: 024+001 | Child: 001+045 | Purity: 0.7611111111111111 | Num desc: 4 | Num protos: 4
# 	Proto: 13 0.9
# 	Proto: 19 0.9
# 	Proto: 11 0.8
# 	Proto: 15 0.4444444444444444
# Node: 024+001 | Child: 024+100 | Purity: 0.5157407407407408 | Num desc: 5 | Num protos: 6
# 	Proto: 1 0.8
# 	Proto: 6 0.3
# 	Proto: 5 0.8
# 	Proto: 2 0.0
# 	Proto: 4 0.75
# 	Proto: 7 0.4444444444444444
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 031+032 | Child: 031+033 | Purity: 0.9 | Num desc: 2 | Num protos: 3
# 	Proto: 7 0.8
# 	Proto: 3 0.9
# 	Proto: 5 1.0
# Node: 031+032 | Child: cub_032_Mangrove_Cuckoo | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 12 1.0
# 	Proto: 15 0.8
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 051+050 | Child: cub_050_Eared_Grebe | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 18 0.8
# 	Proto: 19 1.0
# 	Proto: 11 0.9
# Node: 051+050 | Child: cub_051_Horned_Grebe | Purity: 0.9666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 7 1.0
# 	Proto: 4 0.9
# 	Proto: 2 1.0
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 0
# Node: 129+107 | Child: 129+136 | Purity: 0.3 | Num desc: 101 | Num protos: 4
# 	Proto: 6 0.0
# 	Proto: 3 0.3
# 	Proto: 4 0.4
# 	Proto: 2 0.5
# Node: 129+107 | Child: 107+151 | Purity: 0.1 | Num desc: 16 | Num protos: 4
# 	Proto: 19 0.0
# 	Proto: 18 0.4
# 	Proto: 16 0.0
# 	Proto: 11 0.0
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 7
# Node: 043+042 | Child: 043+040 | Purity: 0.6703703703703704 | Num desc: 5 | Num protos: 6
# 	Proto: 1 0.6
# 	Proto: 6 0.8
# 	Proto: 2 0.6
# 	Proto: 9 1.0
# 	Proto: 0 0.8
# 	Proto: 3 0.2222222222222222
# Node: 043+042 | Child: cub_042_Vermilion_Flycatcher | Purity: 0.7333333333333334 | Num desc: 1 | Num protos: 2
# 	Proto: 10 0.6666666666666666
# 	Proto: 15 0.8
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 5
# Node: 078+038 | Child: cub_038_Great_Crested_Flycatcher | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 12 1.0
# 	Proto: 19 1.0
# Node: 078+038 | Child: 078+041 | Purity: 0.7666666666666666 | Num desc: 3 | Num protos: 4
# 	Proto: 6 0.6666666666666666
# 	Proto: 3 0.5
# 	Proto: 9 0.9
# 	Proto: 7 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node:
# 	Proto: 17 0.8
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 031+033 | Child: cub_031_Black_billed_Cuckoo | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 1 0.9
# 	Proto: 0 1.0
# Node: 031+033 | Child: cub_033_Yellow_billed_Cuckoo | Purity: 0.8500000000000001 | Num desc: 1 | Num protos: 2
# 	Proto: 14 0.8
# 	Proto: 15 0.9
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 4
# Node: 129+136 | Child: 129+199 | Purity: 0.7416666666666667 | Num desc: 97 | Num protos: 4
# 	Proto: 6 0.6666666666666666
# 	Proto: 3 0.6
# 	Proto: 4 0.7
# 	Proto: 8 1.0
# Node: 129+136 | Child: 136+085 | Purity: 0.0 | Num desc: 4 | Num protos: 4
# 	Proto: 10 0.0
# 	Proto: 11 0.0
# 	Proto: 14 0.0
# 	Proto: 15 0.0
# Number of prototypes in parts_presences:  12
# Part-related (purity>0.5): 9
# Node: 107+151 | Child: 107+111 | Purity: 0.6380952380952382 | Num desc: 9 | Num protos: 7
# 	Proto: 1 0.0
# 	Proto: 2 0.8888888888888888
# 	Proto: 9 1.0
# 	Proto: 0 0.5
# 	Proto: 8 0.7
# 	Proto: 3 0.6
# 	Proto: 7 0.7777777777777778
# Node: 107+151 | Child: 151+153 | Purity: 0.7577777777777778 | Num desc: 7 | Num protos: 5
# 	Proto: 19 1.0
# 	Proto: 13 0.8888888888888888
# 	Proto: 12 0.4
# 	Proto: 10 0.8
# 	Proto: 18 0.7
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 7
# Node: 043+040 | Child: 043+037 | Purity: 0.7814814814814813 | Num desc: 3 | Num protos: 6
# 	Proto: 5 0.8888888888888888
# 	Proto: 2 1.0
# 	Proto: 9 0.9
# 	Proto: 0 0.5
# 	Proto: 8 0.4
# 	Proto: 4 1.0
# Node: 043+040 | Child: 040+102 | Purity: 1.0 | Num desc: 2 | Num protos: 3
# 	Proto: 18 1.0
# 	Proto: 11 1.0
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 5
# Node: 078+041 | Child: cub_041_Scissor_tailed_Flycatcher | Purity: 0.6 | Num desc: 1 | Num protos: 2
# 	Proto: 13 1.0
# 	Proto: 16 0.2
# Node: 078+041 | Child: 078+077 | Purity: 1.0 | Num desc: 2 | Num protos: 4
# 	Proto: 8 1.0
# 	Proto: 3 1.0
# 	Proto: 0 1.0
# 	Proto: 7 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 192+187 | Child: cub_187_American_Three_toed_Woodpecker | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 18 1.0
# 	Proto: 19 1.0
# Node: 192+187 | Child: 192+190 | Purity: 0.95 | Num desc: 2 | Num protos: 2
# 	Proto: 0 0.9
# 	Proto: 7 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 191+189 | Child: cub_189_Red_bellied_Woodpecker | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 11 1.0
# 	Proto: 17 1.0
# Node: 191+189 | Child: cub_191_Red_headed_Woodpecker | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 1 1.0
# 	Proto: 0 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 081+080 | Child: cub_080_Green_Kingfisher | Purity: 0.6499999999999999 | Num desc: 1 | Num protos: 2
# 	Proto: 18 0.7
# 	Proto: 10 0.6
# Node: 081+080 | Child: cub_081_Pied_Kingfisher | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 1 0.8
# 	Proto: 8 0.8
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 3
# Node: 082+079 | Child: cub_079_Belted_Kingfisher | Purity: 0.41666666666666663 | Num desc: 1 | Num protos: 2
# 	Proto: 16 0.3333333333333333
# 	Proto: 14 0.5
# Node: 082+079 | Child: cub_082_Ringed_Kingfisher | Purity: 0.8333333333333334 | Num desc: 1 | Num protos: 3
# 	Proto: 1 1.0
# 	Proto: 8 0.9
# 	Proto: 7 0.6
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 5
# Node: 065+066 | Child: 065+062 | Purity: 0.7571428571428571 | Num desc: 4 | Num protos: 5
# 	Proto: 6 0.8
# 	Proto: 5 0.8
# 	Proto: 9 0.9
# 	Proto: 0 0.2857142857142857
# 	Proto: 3 1.0
# Node: 065+066 | Child: cub_066_Western_Gull | Purity: 0.5 | Num desc: 1 | Num protos: 3
# 	Proto: 17 1.0
# 	Proto: 16 0.5
# 	Proto: 15 0.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 061+064 | Child: cub_061_Heermann_Gull | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 4 1.0
# 	Proto: 8 1.0
# Node: 061+064 | Child: cub_064_Ring_billed_Gull | Purity: 0.7777777777777778 | Num desc: 1 | Num protos: 2
# 	Proto: 12 1.0
# 	Proto: 11 0.5555555555555556
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 8
# Node: 144+142 | Child: 144+145 | Purity: 0.8400000000000001 | Num desc: 4 | Num protos: 5
# 	Proto: 5 0.7
# 	Proto: 2 0.9
# 	Proto: 9 1.0
# 	Proto: 4 0.7
# 	Proto: 7 0.9
# Node: 144+142 | Child: cub_142_Black_Tern | Purity: 1.0 | Num desc: 1 | Num protos: 3
# 	Proto: 12 1.0
# 	Proto: 14 1.0
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 3
# Node: 006+005 | Child: cub_005_Crested_Auklet | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 13 0.9
# 	Proto: 15 0.6
# Node: 006+005 | Child: 006+007 | Purity: 0.6000000000000001 | Num desc: 2 | Num protos: 2
# 	Proto: 8 0.8
# 	Proto: 5 0.4
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 008+106 | Child: cub_008_Rhinoceros_Auklet | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 8 1.0
# 	Proto: 3 0.9
# 	Proto: 7 0.8
# Node: 008+106 | Child: cub_106_Horned_Puffin | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 16 0.9
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 6
# Node: 024+023 | Child: cub_023_Brandt_Cormorant | Purity: 0.7333333333333334 | Num desc: 1 | Num protos: 3
# 	Proto: 18 0.5
# 	Proto: 19 0.8
# 	Proto: 11 0.9
# Node: 024+023 | Child: 024+025 | Purity: 0.825 | Num desc: 2 | Num protos: 4
# 	Proto: 1 0.8
# 	Proto: 4 0.8
# 	Proto: 9 0.7
# 	Proto: 7 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 3
# Node: 100+101 | Child: cub_100_Brown_Pelican | Purity: 0.5 | Num desc: 1 | Num protos: 2
# 	Proto: 0 0.0
# 	Proto: 5 1.0
# Node: 100+101 | Child: cub_101_White_Pelican | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 19 1.0
# 	Proto: 11 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 001+003 | Child: 001+002 | Purity: 0.8694444444444445 | Num desc: 2 | Num protos: 4
# 	Proto: 7 0.9
# 	Proto: 4 1.0
# 	Proto: 0 0.8
# 	Proto: 5 0.7777777777777778
# Node: 001+003 | Child: cub_003_Sooty_Albatross | Purity: 0.8888888888888888 | Num desc: 1 | Num protos: 1
# 	Proto: 13 0.8888888888888888
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 2
# Node: 129+199 | Child: 129+118 | Purity: 0.4 | Num desc: 82 | Num protos: 2
# 	Proto: 7 0.2
# 	Proto: 2 0.6
# Node: 129+199 | Child: 199+186 | Purity: 0.11851851851851851 | Num desc: 15 | Num protos: 6
# 	Proto: 19 0.0
# 	Proto: 17 0.6
# 	Proto: 13 0.0
# 	Proto: 10 0.1111111111111111
# 	Proto: 18 0.0
# 	Proto: 14 0.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 5
# Node: 136+085 | Child: cub_085_Horned_Lark | Purity: 0.8333333333333334 | Num desc: 1 | Num protos: 3
# 	Proto: 17 0.8
# 	Proto: 14 1.0
# 	Proto: 15 0.7
# Node: 136+085 | Child: 136+138 | Purity: 0.6666666666666666 | Num desc: 3 | Num protos: 3
# 	Proto: 1 0.4
# 	Proto: 3 0.9
# 	Proto: 8 0.7
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 6
# Node: 107+111 | Child: 107+073 | Purity: 0.5968253968253968 | Num desc: 7 | Num protos: 7
# 	Proto: 1 0.4
# 	Proto: 6 0.8
# 	Proto: 5 0.3
# 	Proto: 9 0.3
# 	Proto: 0 0.8888888888888888
# 	Proto: 8 0.6
# 	Proto: 7 0.8888888888888888
# Node: 107+111 | Child: 111+112 | Purity: 0.6 | Num desc: 2 | Num protos: 3
# 	Proto: 12 1.0
# 	Proto: 10 0.2
# 	Proto: 11 0.6
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 8
# Node: 151+153 | Child: 151+157 | Purity: 0.9249999999999999 | Num desc: 4 | Num protos: 4
# 	Proto: 1 0.9
# 	Proto: 3 1.0
# 	Proto: 9 0.9
# 	Proto: 5 0.9
# Node: 151+153 | Child: 153+154 | Purity: 0.9159722222222222 | Num desc: 3 | Num protos: 4
# 	Proto: 12 0.875
# 	Proto: 18 1.0
# 	Proto: 16 0.8888888888888888
# 	Proto: 19 0.9
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 5
# Node: 043+037 | Child: cub_037_Acadian_Flycatcher | Purity: 0.6333333333333333 | Num desc: 1 | Num protos: 3
# 	Proto: 12 0.8
# 	Proto: 16 0.1
# 	Proto: 11 1.0
# Node: 043+037 | Child: 043+039 | Purity: 0.8666666666666667 | Num desc: 2 | Num protos: 3
# 	Proto: 1 1.0
# 	Proto: 0 1.0
# 	Proto: 7 0.6
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 040+102 | Child: cub_040_Olive_sided_Flycatcher | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 4 0.7
# 	Proto: 9 1.0
# 	Proto: 2 1.0
# Node: 040+102 | Child: cub_102_Western_Wood_Pewee | Purity: 0.9666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 13 0.9
# 	Proto: 10 1.0
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 078+077 | Child: cub_077_Tropical_Kingbird | Purity: 0.762962962962963 | Num desc: 1 | Num protos: 3
# 	Proto: 13 0.6
# 	Proto: 18 0.8888888888888888
# 	Proto: 10 0.8
# Node: 078+077 | Child: cub_078_Gray_Kingbird | Purity: 0.7777777777777777 | Num desc: 1 | Num protos: 2
# 	Proto: 1 0.6666666666666666
# 	Proto: 0 0.8888888888888888
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 192+190 | Child: cub_190_Red_cockaded_Woodpecker | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 12 0.8
# 	Proto: 11 0.9
# 	Proto: 17 1.0
# Node: 192+190 | Child: cub_192_Downy_Woodpecker | Purity: 0.55 | Num desc: 1 | Num protos: 2
# 	Proto: 3 0.3
# 	Proto: 4 0.8
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 3
# Node: 065+062 | Child: 065+059 | Purity: 0.5 | Num desc: 3 | Num protos: 4
# 	Proto: 7 0.0
# 	Proto: 5 0.6
# 	Proto: 8 0.8
# 	Proto: 2 0.6
# Node: 065+062 | Child: cub_062_Herring_Gull | Purity: 0.2 | Num desc: 1 | Num protos: 2
# 	Proto: 13 0.3
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 5
# Node: 144+145 | Child: 144+146 | Purity: 0.8666666666666667 | Num desc: 3 | Num protos: 3
# 	Proto: 1 0.8
# 	Proto: 4 0.9
# 	Proto: 0 0.9
# Node: 144+145 | Child: cub_145_Elegant_Tern | Purity: 0.6984126984126985 | Num desc: 1 | Num protos: 3
# 	Proto: 12 0.42857142857142855
# 	Proto: 18 1.0
# 	Proto: 11 0.6666666666666666
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 006+007 | Child: cub_006_Least_Auklet | Purity: 0.9666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 1 0.9
# 	Proto: 9 1.0
# 	Proto: 7 1.0
# Node: 006+007 | Child: cub_007_Parakeet_Auklet | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 12 0.9
# 	Proto: 16 1.0
# 	Proto: 14 0.9
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 024+025 | Child: cub_024_Red_faced_Cormorant | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 9 0.9
# 	Proto: 8 0.9
# Node: 024+025 | Child: cub_025_Pelagic_Cormorant | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 16 1.0
# 	Proto: 10 0.8
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 001+002 | Child: cub_001_Black_footed_Albatross | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 4 1.0
# 	Proto: 9 1.0
# Node: 001+002 | Child: cub_002_Laysan_Albatross | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 17 0.9
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 2
# Node: 129+118 | Child: 129+104 | Purity: 0.38888888888888884 | Num desc: 81 | Num protos: 3
# 	Proto: 6 0.3
# 	Proto: 3 0.2
# 	Proto: 0 0.6666666666666666
# Node: 129+118 | Child: cub_118_House_Sparrow | Purity: 0.2 | Num desc: 1 | Num protos: 4
# 	Proto: 13 0.0
# 	Proto: 16 0.8
# 	Proto: 11 0.0
# 	Proto: 14 0.0
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5):
| Num desc: 1 | Num protos: 2
# 	Proto: 18 0.9
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 7
# Node: 199+150 | Child: 150+019 | Purity: 0.525 | Num desc: 4 | Num protos: 4
# 	Proto: 13 1.0
# 	Proto: 12 0.1
# 	Proto: 16 0.7
# 	Proto: 14 0.3
# Node: 199+150 | Child: 199+094 | Purity: 0.6777777777777777 | Num desc: 9 | Num protos: 6
# 	Proto: 5 0.8
# 	Proto: 2 0.8
# 	Proto: 9 0.6666666666666666
# 	Proto: 0 0.9
# 	Proto: 8 0.0
# 	Proto: 7 0.9
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 4
# Node: 186+185 | Child: cub_185_Bohemian_Waxwing | Purity: 0.4148148148148148 | Num desc: 1 | Num protos: 3
# 	Proto: 13 0.0
# 	Proto: 12 0.8
# 	Proto: 17 0.4444444444444444
# Node: 186+185 | Child: cub_186_Cedar_Waxwing | Purity: 0.7861111111111112 | Num desc: 1 | Num protos: 4
# 	Proto: 6 1.0
# 	Proto: 3 1.0
# 	Proto: 4 0.4444444444444444
# 	Proto: 0 0.7
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 136+137 | Child: cub_136_Barn_Swallow | Purity: 0.6499999999999999 | Num desc: 1 | Num protos: 2
# 	Proto: 6 0.6
# 	Proto: 7 0.7
# Node: 136+137 | Child: cub_137_Cliff_Swallow | Purity: 0.6166666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 13 0.9
# 	Proto: 16 0.7
# 	Proto: 19 0.25
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 5
# Node: 107+093 | Child: 107+030 | Purity: 0.7377777777777779 | Num desc: 4 | Num protos: 5
# 	Proto: 5 0.5
# 	Proto: 9 0.5
# 	Proto: 8 0.8888888888888888
# 	Proto: 3 1.0
# 	Proto: 7 0.8
# Node: 107+093 | Child: cub_093_Clark_Nutcracker | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 17 0.9
# 	Proto: 15 0.7
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 3
# Node: 073+074 | Child: cub_073_Blue_Jay | Purity: 0.7999999999999999 | Num desc: 1 | Num protos: 3
# 	Proto: 6 1.0
# 	Proto: 0 0.5
# 	Proto: 7 0.9
# Node: 073+074 | Child: cub_074_Florida_Jay | Purity: 0.6 | Num desc: 1 | Num protos: 2
# 	Proto: 18 0.5
# 	Proto: 15 0.7
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 5
# Node: 151+156 | Child: cub_151_Black_capped_Vireo | Purity: 0.6999999999999998 | Num desc: 1 | Num protos: 3
# 	Proto: 1 0.9
# 	Proto: 4 0.5
# 	Proto: 7 0.7
# Node: 151+156 | Child: cub_156_White_eyed_Vireo | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 13 0.9
# 	Proto: 14 1.0
# 	Proto: 15 0.9
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 157+152 | Child: cub_152_Blue_headed_Vireo | Purity: 0.9444444444444444 | Num desc: 1 | Num protos: 2
# 	Proto: 12 1.0
# 	Proto: 17 0.8888888888888888
# Node: 157+152 | Child: cub_157_Yellow_throated_Vireo | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 1 0.8
# 	Proto: 4 0.8
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 153+155 | Child: cub_153_Philadelphia_Vireo | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 6 0.9
# 	Proto: 5 0.9
# Node: 153+155 | Child: cub_155_Warbling_Vireo | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 16 1.0
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 3
# Node: 065+060 | Child: cub_060_Glaucous_winged_Gull | Purity: 0.5666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 11 0.7
# 	Proto: 14 1.0
# 	Proto: 17 0.0
# Node: 065+060 | Child: cub_065_Slaty_backed_Gull | Purity: 0.5444444444444444 | Num desc: 1 | Num protos: 3
# 	Proto: 1 0.4
# 	Proto: 6 0.9
# 	Proto: 2 0.3333333333333333
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 3
# Node: 144+141 | Child: cub_141_Artic_Tern | Purity: 0.5074074074074074 | Num desc: 1 | Num protos: 3
# 	Proto: 12 0.2222222222222222
# 	Proto: 10 0.4
# 	Proto: 11 0.9
# Node: 144+141 | Child: cub_144_Common_Tern | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 1 1.0
# 	Proto: 2 1.0
# Number of prototypes in parts_presences:  11
# Part-related (purity>0.5): 5
# Node: 129+035 | Child: 129+054 | Purity: 0.3535714285714286 | Num desc: 74 | Num protos: 7
# 	Proto: 1 0.0
# 	Proto: 5 0.875
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 3 0.6
# 	Proto: 4 0.6666666666666666
# 	Proto: 7 0.3333333333333333
# Node: 129+035 | Child: 035+055 | Purity: 0.3972222222222222 | Num desc: 6 | Num protos: 4
# 	Proto: 12 0.0
# 	Proto: 16 0.0
# 	Proto: 11 0.8888888888888888
# 	Proto: 19 0.7
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 8
# Node: 199+094 | Child: 199+028 | Purity: 0.6666666666666666 | Num desc: 8 | Num protos: 6
# 	Proto: 1 0.9
# 	Proto: 5 0.7
# 	Proto: 2 0.0
# 	Proto: 9 0.9
# 	Proto: 8 0.7
# 	Proto: 3 0.8
# Node: 199+094 | Child: cub_094_White_breasted_Nuthatch | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 11 1.0
# 	Proto: 14 0.8
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 150+019 | Child: cub_019_Gray_Catbird | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 10 1.0
# 	Proto: 14 1.0
# Node: 150+019 | Child: 150+149 | Purity: 0.85 | Num desc: 3 | Num protos: 4
# 	Proto: 8 0.8
# 	Proto: 3 1.0
# 	Proto: 9 0.7
# 	Proto: 7 0.9
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 2
# Node: 107+030 | Child: 107+029 | Purity: 0.35 | Num desc: 3 | Num protos: 4
# 	Proto: 1 0.4
# 	Proto: 3 0.0
# 	Proto: 0 0.5
# 	Proto: 2 0.5
# Node: 107+030 | Child: cub_030_Fish_Crow | Purity: 0.5305555555555556 | Num desc: 1 | Num protos: 4
# 	Proto: 13 0.2222222222222222
# 	Proto: 16 0.2
# 	Proto: 11 0.9
# 	Proto: 15 0.8
# Number of prototypes in parts_presences:  12
# Part-related (purity>0.5): 6
# Node: 129+054 | Child: 129+175 | Purity: 0.49722222222222223 | Num desc: 66 | Num protos: 7
# 	Proto: 1 0.3
# 	Proto: 6 0.6666666666666666
# 	Proto: 2 0.3
# 	Proto: 0 0.8888888888888888
# 	Proto: 8 0.625
# 	Proto: 3 0.2
# 	Proto: 4 0.5
# Node: 129+054 | Child: 054+140 | Purity: 0.52 | Num desc: 8 | Num protos: 5
# 	Proto: 19 0.4
# 	Proto: 10 0.2
# 	Proto: 15 0.6
# 	Proto: 18 0.8
# 	Proto: 14 0.6
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 8
# Node: 035+055 | Child: 035+048 | Purity: 0.8555555555555555 | Num desc: 5 | Num protos: 5
# 	Proto: 1 1.0
# 	Proto: 6 1.0
# 	Proto: 9 0.7
# 	Proto: 0 0.7777777777777778
# 	Proto: 7 0.8
# Node: 035+055 | Child: cub_055_Evening_Grosbeak | Purity: 0.8592592592592592 | Num desc: 1 | Num protos: 3
# 	Proto: 13 0.7777777777777778
# 	Proto: 16 1.0
# 	Proto: 19 0.8
# Number of prototypes in parts_presences:  11
# Part-related (purity>0.5): 6
# Node: 199+028 | Child: cub_028_Brown_Creeper | Purity: 0.625 | Num desc: 1 | Num protos: 4
# 	Proto: 13 0.5
# 	Proto: 12 0.2
# 	Proto: 11 0.9
# 	Proto: 14 0.9
# Node: 199+028 | Child: 199+198 | Purity: 0.5714285714285714 | Num desc: 7 | Num protos: 7
# 	Proto: 1 0.0
# 	Proto: 6 1.0
# 	Proto: 2 0.5
# 	Proto: 9 0.7
# 	Proto: 0 0.7
# 	Proto: 3 0.3
# 	Proto: 4 0.8
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 4
# Node:
# Number of prototypes in parts_presences:  11
# Part-related (purity>0.5): 4
# Node: 129+011 | Child: 011+013 | Purity: 0.2844444444444444 | Num desc: 13 | Num protos: 5
# 	Proto: 13 0.1
# 	Proto: 12 0.0
# 	Proto: 10 0.6666666666666666
# 	Proto: 11 0.1
# 	Proto: 14 0.5555555555555556
# Node: 129+011 | Child: 129+121 | Purity: 0.3833333333333333 | Num desc: 23 | Num protos: 6
# 	Proto: 6 0.3
# 	Proto: 5 0.6
# 	Proto: 9 0.4
# 	Proto: 0 0.3333333333333333
# 	Proto: 3 0.6666666666666666
# 	Proto: 7 0.0
# Number of prototypes in parts_presences:  12
# Part-related (purity>0.5): 5
# Node: 175+020 | Child: cub_020_Yellow_breasted_Chat | Purity: 0.6666666666666666 | Num desc: 1 | Num protos: 3
# 	Proto: 16 0.2
# 	Proto: 14 0.9
# 	Proto: 17 0.9
# Node: 175+020 | Child: 175+099 | Purity: 0.48518518518518516 | Num desc: 29 | Num protos: 9
# 	Proto: 6 0.4
# 	Proto: 5 0.0
# 	Proto: 2 0.7777777777777778
# 	Proto: 9 1.0
# 	Proto: 0 0.4
# 	Proto: 8 0.3
# 	Proto: 3 0.3
# 	Proto: 4 0.3
# 	Proto: 7 0.8888888888888888
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 5
# Node: 054+057 | Child: 054+014 | Purity: 0.7133333333333333 | Num desc: 4 | Num protos: 5
# 	Proto: 1 0.9
# 	Proto: 6 0.5
# 	Proto: 0 0.6666666666666666
# 	Proto: 8 0.7
# 	Proto: 4 0.8
# Node: 054+057 | Child: cub_057_Rose_breasted_Grosbeak | Purity: 0.6 | Num desc: 1 | Num protos: 2
# 	Proto: 18 0.3
# 	Proto: 17 0.9
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 140+017 | Child: cub_017_Cardinal | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 12 0.9
# 	Proto: 17 0.9
# Node: 140+017 | Child: 140+139 | Purity: 0.975 | Num desc: 2 | Num protos: 4
# 	Proto: 7 0.9
# 	Proto: 8 1.0
# 	Proto: 4 1.0
# 	Proto: 5 1.0
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 8
# Node: 035+056 | Child: 035+034 | Purity: 0.8755555555555554 | Num desc: 2 | Num protos: 5
# 	Proto: 1 0.7
# 	Proto: 6 0.8888888888888888
# 	Proto: 9 1.0
# 	Proto: 0 0.9
# 	Proto: 3 0.8888888888888888
# Node: 035+056 | Child: cub_056_Pine_Grosbeak | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 13 0.9
# 	Proto: 16 1.0
# 	Proto: 15 0.8
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 048+047 | Child: cub_047_American_Goldfinch | Purity: 0.6 | Num desc: 1 | Num protos: 2
# 	Proto: 10 0.9
# 	Proto: 15 0.3
# Node: 048+047 | Child: cub_048_European_Goldfinch | Purity: 0.7999999999999999 | Num desc: 1 | Num protos: 3
# 	Proto: 7 0.6
# 	Proto: 6 0.9
# 	Proto: 2 0.9
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 7
# Node: 199+194 | Child: 199+193 | Purity: 0.5759259259259258 | Num desc: 5 | Num protos: 6
# 	Proto: 1 0.5555555555555556
# 	Proto: 6 0.4
# 	Proto: 5 0.7
# 	Proto: 0 0.9
# 	Proto: 8 0.9
# 	Proto: 7 0.0
# Node: 199+194 | Child: cub_194_Cactus_Wren | Purity: 0.7527777777777778 | Num desc: 1 | Num protos: 4
# 	Proto: 17 0.9
# 	Proto: 12 0.1111111111111111
# 	Proto: 19 1.0
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 3
# Node: 129+121 | Child: 129+117 | Purity: 0.4288888888888889 | Num desc: 22 | Num protos: 5
# 	Proto: 1 0.5
# 	Proto: 6 0.7
# 	Proto: 8 0.2
# 	Proto: 3 0.4444444444444444
# 	Proto: 7 0.3
# Node: 129+121 | Child: cub_121_Grasshopper_Sparrow | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 19 0.8
# 	Proto: 14 1.0
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 6
# Node: 011+013 | Child: 011+095 | Purity: 0.5380952380952381 | Num desc: 10 | Num protos: 7
# 	Proto: 1 0.1
# 	Proto: 2 0.4
# 	Proto: 5 0.6666666666666666
# 	Proto: 0 0.8
# 	Proto: 3 0.7
# 	Proto: 4 0.2
# 	Proto: 7 0.9
# Node: 011+013 | Child: 013+088 | Purity: 0.6333333333333333 | Num desc: 3 | Num protos: 3
# 	Proto: 16 0.4
# 	Proto: 10 0.9
# 	Proto: 15 0.6
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 7
# Node: 175+099 | Child: cub_099_Ovenbird | Purity: 0.95 | Num desc: 1 | Num protos: 4
# 	Proto: 12 1.0
# 	Proto: 18 1.0
# 	Proto: 19 0.8
# 	Proto: 11 1.0
# Node: 175+099 | Child: 175+181 | Purity: 0.5972222222222222 | Num desc: 28 | Num protos: 4
# 	Proto: 1 0.6
# 	Proto: 6 0.0
# 	Proto: 7 0.9
# 	Proto: 5 0.8888888888888888
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 4
# Node: 054+014 | Child: cub_014_Indigo_Bunting | Purity: 0.7 | Num desc: 1 | Num protos: 2
# 	Proto: 12 0.9
# 	Proto: 17 0.5
# Node: 054+014 | Child: 054+016 | Purity: 0.70625 | Num desc: 3 | Num protos: 4
# 	Proto: 1 0.8
# 	Proto: 6 0.9
# 	Proto: 8 0.625
# 	Proto: 7 0.5
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 3
# Node: 140+139 | Child: cub_139_Scarlet_Tanager | Purity: 0.39999999999999997 | Num desc: 1 | Num protos: 3
# 	Proto: 18 1.0
# 	Proto: 16 0.2
# 	Proto: 19 0.0
# Node: 140+139 | Child: cub_140_Summer_Tanager | Purity: 0.6333333333333334 | Num desc: 1 | Num protos: 3
# 	Proto: 5 1.0
# 	Proto: 3 0.1
# 	Proto: 2 0.8
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 035+034 | Child: cub_034_Gray_crowned_Rosy_Finch | Purity: 0.8888888888888888 | Num desc: 1 | Num protos: 2
# 	Proto: 12 0.7777777777777778
# 	Proto: 17 1.0
# Node: 035+034 | Child: cub_035_Purple_Finch | Purity: 0.8666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 6 1.0
# 	Proto: 3 0.7
# 	Proto: 5 0.9
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 199+193 | Child: 193+195 | Purity: 0.875 | Num desc: 2 | Num protos: 4
# 	Proto: 13 0.7
# 	Proto: 18 0.9
# 	Proto: 14 0.9
# 	Proto: 15 1.0
# Node: 199+193 | Child: 199+197 | Purity: 0.8296296296296296 | Num desc: 3 | Num protos: 3
# 	Proto: 6 0.8888888888888888
# 	Proto: 9 0.6
# 	Proto: 5 1.0
# Number of prototypes in parts_presences:  11
# Part-related (purity>0.5): 2
# Node: 129+117 | Child: 129+133 | Purity: 0.25 | Num desc: 17 | Num protos: 6
# 	Proto: 1 0.3
# 	Proto: 6 0.0
# 	Proto: 8 0.3
# 	Proto: 3 0.2
# 	Proto: 4 0.7
# 	Proto: 7 0.0
# Node: 129+117 | Child: 117+114 | Purity: 0.24000000000000005 | Num desc: 5 | Num protos: 5
# 	Proto: 19 0.0
# 	Proto: 17 0.8
# 	Proto: 13 0.0
# 	Proto: 10 0.4
# 	Proto: 15 0.0
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 3
# Node: 011+095 | Child: 011+026 | Purity: 0.15 | Num desc: 6 | Num protos: 6
# 	Proto: 6 0.0
# 	Proto: 2 0.6
# 	Proto: 0 0.0
# 	Proto: 8 0.0
# 	Proto: 4 0.3
# 	Proto: 7 0.0
# Node: 011+095 | Child: 095+096 | Purity: 0.525 | Num desc: 4 | Num protos: 4
# 	Proto: 12 0.8
# 	Proto: 16 1.0
# 	Proto: 10 0.0
# 	Proto: 14 0.3
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 013+088 | Child: 013+012 | Purity: 0.8333333333333334 | Num desc: 2 | Num protos: 3
# 	Proto: 1 1.0
# 	Proto: 4 0.8
# 	Proto: 7 0.7
# Node: 013+088 | Child: cub_088_Western_Meadowlark | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 13 1.0
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 5
# Node: 175+181 | Child: 175+168+173+183 | Purity: 0.5592592592592592 | Num desc: 27 | Num protos: 6
# 	Proto: 5 0.5
# 	Proto: 2 0.3
# 	Proto: 9 0.4
# 	Proto: 3 0.6666666666666666
# 	Proto: 4 0.8888888888888888
# 	Proto: 7 0.6
# Node: 175+181 | Child: cub_181_Worm_eating_Warbler | Purity: 0.7000000000000001 | Num desc: 1 | Num protos: 3
# 	Proto: 16 1.0
# 	Proto: 19 0.1
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 054+016 | Child: 054+015 | Purity: 0.7000000000000001 | Num desc: 2 | Num protos: 3
# 	Proto: 7 0.8
# 	Proto: 0 0.3
# 	Proto: 2 1.0
# Node: 054+016 | Child: cub_016_Painted_Bunting | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 16 0.8
# 	Proto: 15 0.7
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 199+197 | Child: 199+196 | Purity: 0.6592592592592593 | Num desc: 2 | Num protos: 3
# 	Proto: 1 0.7
# 	Proto: 6 0.5
# ...
# 	Proto: 14 0.7
# Node: 129+021 | Child: 129+128 | Purity: 0.7977777777777778 | Num desc: 9 | Num protos: 5
# 	Proto: 1 0.5
# 	Proto: 6 1.0
# 	Proto: 9 0.8888888888888888
# 	Proto: 0 1.0
# 	Proto: 4 0.6
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 6
# Node: 133+130 | Child: 133+076 | Purity: 0.6694444444444445 | Num desc: 4 | Num protos: 4
# 	Proto: 1 0.8
# 	Proto: 7 0.4
# 	Proto: 0 0.7
# 	Proto: 5 0.7777777777777778
# Node: 133+130 | Child: 130+120 | Purity: 0.9333333333333332 | Num desc: 2 | Num protos: 3
# 	Proto: 12 1.0
# 	Proto: 19 0.9
# 	Proto: 14 0.9
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 7
# Node: 117+115 | Child: 115+119 | Purity: 0.86 | Num desc: 2 | Num protos: 5
# 	Proto: 17 0.9
# 	Proto: 16 0.7
# 	Proto: 10 1.0
# 	Proto: 18 0.7
# 	Proto: 11 1.0
# Node: 117+115 | Child: 117+116 | Purity: 0.7 | Num desc: 2 | Num protos: 4
# 	Proto: 1 1.0
# 	Proto: 6 0.5
# 	Proto: 9 0.4
# 	Proto: 5 0.9
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 4
# Node: 011+049 | Child: 011+009 | Purity: 0.6 | Num desc: 2 | Num protos: 3
# 	Proto: 1 1.0
# 	Proto: 9 0.3
# 	Proto: 0 0.5
# Node: 011+049 | Child: cub_049_Boat_tailed_Grackle | Purity: 0.8000000000000002 | Num desc: 1 | Num protos: 3
# 	Proto: 16 0.7
# 	Proto: 14 0.9
# 	Proto: 15 0.8
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 026+010 | Child: cub_010_Red_winged_Blackbird | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 18 0.6
# 	Proto: 14 1.0
# Node: 026+010 | Child: 026+027 | Purity: 0.7666666666666667 | Num desc: 2 | Num protos: 3
# 	Proto: 3 0.8
# 	Proto: 4 0.9
# 	Proto: 5 0.6
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 095+098 | Child: cub_095_Baltimore_Oriole | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 9 1.0
# 	Proto: 8 0.5
# Node: 095+098 | Child: cub_098_Scott_Oriole | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 16 0.8
# 	Proto: 10 1.0
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 096+097 | Child: cub_096_Hooded_Oriole | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 4 1.0
# 	Proto: 0 0.9
# Node: 096+097 | Child: cub_097_Orchard_Oriole | Purity: 0.9629629629629629 | Num desc: 1 | Num protos: 3
# 	Proto: 17 1.0
# 	Proto: 14 0.8888888888888888
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  13
# Part-related (purity>0.5): 12
# Node: 175+162 | Child: 175+167 | Purity: 0.7398148148148148 | Num desc: 12 | Num protos: 9
# 	Proto: 6 0.7777777777777778
# 	Proto: 5 0.625
# 	Proto: 2 0.5
# 	Proto: 9 0.6666666666666666
# 	Proto: 0 1.0
# 	Proto: 8 0.8
# 	Proto: 3 0.6
# 	Proto: 4 0.8
# 	Proto: 7 0.8888888888888888
# Node: 175+162 | Child: 162+180 | Purity: 0.8666666666666667 | Num desc: 2 | Num protos: 4
# 	Proto: 17 0.8
# 	Proto: 12 1.0
# 	Proto: 10 0.6666666666666666
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  8
# Part-related (purity>0.5): 7
# Node: 168+177 | Child: 168+200 | Purity: 0.9 | Num desc: 3 | Num protos: 4
# 	Proto: 1 1.0
# 	Proto: 3 0.8
# 	Proto: 9 0.9
# 	Proto: 7 0.9
# Node: 168+177 | Child: 177+178 | Purity: 0.75 | Num desc: 2 | Num protos: 4
# 	Proto: 13 0.0
# 	Proto: 18 1.0
# 	Proto: 10 1.0
# 	Proto: 11 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 6
# Node: 173+161 | Child: 161+166 | Purity: 0.9 | Num desc: 2 | Num protos: 3
# 	Proto: 13 0.9
# 	Proto: 18 0.8
# 	Proto: 16 1.0
# Node: 173+161 | Child: 173+179 | Purity: 0.7027777777777777 | Num desc: 3 | Num protos: 4
# 	Proto: 5 0.9
# 	Proto: 6 0.2222222222222222
# 	Proto: 4 0.8888888888888888
# 	Proto: 2 0.8
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 183+159 | Child: cub_159_Black_and_white_Warbler | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 13 0.9
# 	Proto: 17 1.0
# Node: 183+159 | Child: 183+184 | Purity: 0.9333333333333332 | Num desc: 2 | Num protos: 3
# 	Proto: 1 0.8
# 	Proto: 4 1.0
# 	Proto: 2 1.0
# Number of prototypes in parts_presences:  9
# Part-related (purity>0.5): 8
# Node: 129+128 | Child: 129+127 | Purity: 0.625 | Num desc: 5 | Num protos: 4
# 	Proto: 6 0.0
# 	Proto: 9 0.7
# 	Proto: 0 0.9
# 	Proto: 5 0.9
# Node: 129+128 | Child: 128+131 | Purity: 0.8800000000000001 | Num desc: 4 | Num protos: 5
# 	Proto: 13 1.0
# 	Proto: 16 0.7
# 	Proto: 15 1.0
# 	Proto: 18 0.9
# 	Proto: 11 0.8
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 021+148 | Child: cub_021_Eastern_Towhee | Purity: 0.8500000000000001 | Num desc: 1 | Num protos: 2
# 	Proto: 9 0.9
# 	Proto: 0 0.8
# Node: 021+148 | Child: cub_148_Green_tailed_Towhee | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 16 1.0
# 	Proto: 19 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 3
# Node: 133+076 | Child: cub_076_Dark_eyed_Junco | Purity: 0.6499999999999999 | Num desc: 1 | Num protos: 2
# 	Proto: 12 0.6
# 	Proto: 15 0.7
# Node: 133+076 | Child: 133+132 | Purity: 0.5074074074074074 | Num desc: 3 | Num protos: 3
# 	Proto: 1 0.2222222222222222
# 	Proto: 9 0.4
# 	Proto: 7 0.9
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 130+120 | Child: cub_120_Fox_Sparrow | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 12 0.9
# 	Proto: 15 0.7
# Node: 130+120 | Child: cub_130_Tree_Sparrow | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 4 0.9
# 	Proto: 9 0.6
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 117+116 | Child: cub_116_Chipping_Sparrow | Purity: 0.9666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 18 0.9
# 	Proto: 16 1.0
# 	Proto: 11 1.0
# Node: 117+116 | Child: cub_117_Clay_colored_Sparrow | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 4 1.0
# 	Proto: 8 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 115+119 | Child: cub_115_Brewer_Sparrow | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 1 1.0
# 	Proto: 5 0.6
# Node: 115+119 | Child: cub_119_Field_Sparrow | Purity: 0.5666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 18 0.2
# 	Proto: 19 0.7
# 	Proto: 15 0.8
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 011+009 | Child: cub_009_Brewer_Blackbird | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 13 1.0
# 	Proto: 11 0.9
# Node: 011+009 | Child: cub_011_Rusty_Blackbird | Purity: 0.6333333333333333 | Num desc: 1 | Num protos: 3
# 	Proto: 1 0.0
# 	Proto: 8 0.9
# 	Proto: 7 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 026+027 | Child: cub_026_Bronzed_Cowbird | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 6 1.0
# 	Proto: 2 1.0
# Node: 026+027 | Child: cub_027_Shiny_Cowbird | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 18 0.9
# 	Proto: 19 1.0
# 	Proto: 14 0.9
# Number of prototypes in parts_presences:  11
# Part-related (purity>0.5): 7
# Node: 175+167 | Child: 175+169 | Purity: 0.5126984126984128 | Num desc: 11 | Num protos: 7
# 	Proto: 1 0.7
# 	Proto: 5 0.4
# 	Proto: 2 0.1
# 	Proto: 9 0.8888888888888888
# 	Proto: 0 0.4
# 	Proto: 8 0.5
# 	Proto: 4 0.6
# Node: 175+167 | Child: cub_167_Hooded_Warbler | Purity: 0.9 | Num desc: 1 | Num protos: 4
# 	Proto: 13 0.7
# 	Proto: 12 0.9
# 	Proto: 16 1.0
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 162+180 | Child: cub_162_Canada_Warbler | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 9 0.7
# 	Proto: 8 0.8
# Node: 162+180 | Child: cub_180_Wilson_Warbler | Purity: 0.75 | Num desc: 1 | Num protos: 2
# 	Proto: 16 0.7
# 	Proto: 17 0.8
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 168+200 | Child: 168+170 | Purity: 1.0 | Num desc: 2 | Num protos: 3
# 	Proto: 7 1.0
# 	Proto: 0 1.0
# 	Proto: 2 1.0
# Node: 168+200 | Child: cub_200_Common_Yellowthroat | Purity: 1.0 | Num desc: 1 | Num protos: 3
# 	Proto: 10 1.0
# 	Proto: 14 1.0
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 177+178 | Child: cub_177_Prothonotary_Warbler | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 6 0.9
# 	Proto: 9 1.0
# Node: 177+178 | Child: cub_178_Swainson_Warbler | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 10 0.9
# 	Proto: 15 1.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 4
# Node: 173+179 | Child: 173+172 | Purity: 0.6499999999999999 | Num desc: 2 | Num protos: 4
# 	Proto: 3 0.3
# 	Proto: 9 0.6
# 	Proto: 0 1.0
# 	Proto: 5 0.7
# Node: 173+179 | Child: cub_179_Tennessee_Warbler | Purity: 0.7 | Num desc: 1 | Num protos: 2
# 	Proto: 11 1.0
# 	Proto: 17 0.4
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 161+166 | Child: cub_161_Blue_winged_Warbler | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 0 1.0
# 	Proto: 2 0.8
# Node: 161+166 | Child: cub_166_Golden_winged_Warbler | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 19 0.6
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 183+184 | Child: cub_183_Northern_Waterthrush | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 9 1.0
# 	Proto: 8 0.9
# Node: 183+184 | Child: cub_184_Louisiana_Waterthrush | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 13 1.0
# 	Proto: 16 1.0
# 	Proto: 10 0.7
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 4
# Node: 129+127 | Child: 129+123 | Purity: 0.4644444444444444 | Num desc: 4 | Num protos: 5
# 	Proto: 1 0.2222222222222222
# 	Proto: 6 0.3
# 	Proto: 5 0.9
# 	Proto: 0 0.1
# 	Proto: 8 0.8
# Node: 129+127 | Child: cub_127_Savannah_Sparrow | Purity: 0.7 | Num desc: 1 | Num protos: 2
# 	Proto: 12 0.8
# 	Proto: 19 0.6
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 128+131 | Child: 128+124 | Purity: 0.8583333333333334 | Num desc: 3 | Num protos: 3
# 	Proto: 6 0.875
# 	Proto: 9 0.8
# 	Proto: 5 0.9
# Node: 128+131 | Child: cub_131_Vesper_Sparrow | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 10 1.0
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 4
# Node: 133+132 | Child: 133+122 | Purity: 0.6592592592592593 | Num desc: 2 | Num protos: 3
# 	Proto: 1 0.4
# 	Proto: 0 0.8
# 	Proto: 8 0.7777777777777778
# Node: 133+132 | Child: cub_132_White_crowned_Sparrow | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 12 0.9
# 	Proto: 16 1.0
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 9
# Node: 175+169 | Child: 175+165+182 | Purity: 0.753968253968254 | Num desc: 10 | Num protos: 7
# 	Proto: 6 0.8
# 	Proto: 5 0.7
# 	Proto: 9 0.9
# 	Proto: 0 0.7777777777777778
# 	Proto: 8 0.6
# 	Proto: 3 0.5
# 	Proto: 7 1.0
# Node: 175+169 | Child: cub_169_Magnolia_Warbler | Purity: 0.9 | Num desc: 1 | Num protos: 3
# 	Proto: 13 1.0
# 	Proto: 10 0.7
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 168+170 | Child: cub_168_Kentucky_Warbler | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 9 1.0
# 	Proto: 2 1.0
# Node: 168+170 | Child: cub_170_Mourning_Warbler | Purity: 0.975 | Num desc: 1 | Num protos: 4
# 	Proto: 18 1.0
# 	Proto: 16 0.9
# 	Proto: 11 1.0
# 	Proto: 17 1.0
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 173+172 | Child: cub_172_Nashville_Warbler | Purity: 0.7999999999999999 | Num desc: 1 | Num protos: 3
# 	Proto: 12 0.9
# 	Proto: 19 0.6
# 	Proto: 14 0.9
# Node: 173+172 | Child: cub_173_Orange_crowned_Warbler | Purity: 0.8296296296296296 | Num desc: 1 | Num protos: 3
# 	Proto: 1 0.6
# 	Proto: 9 1.0
# 	Proto: 8 0.8888888888888888
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 6
# Node: 129+123 | Child: 123+113 | Purity: 0.9472222222222222 | Num desc: 2 | Num protos: 4
# 	Proto: 13 0.9
# 	Proto: 18 1.0
# 	Proto: 10 1.0
# 	Proto: 15 0.8888888888888888
# Node: 129+123 | Child: 129+125 | Purity: 1.0 | Num desc: 2 | Num protos: 2
# 	Proto: 6 1.0
# 	Proto: 0 1.0
# Number of prototypes in parts_presences:  3
# Part-related (purity>0.5): 3
# Node: 128+124 | Child: cub_124_Le_Conte_Sparrow | Purity: 0.6 | Num desc: 1 | Num protos: 1
# 	Proto: 14 0.6
# Node: 128+124 | Child: 128+126 | Purity: 0.75 | Num desc: 2 | Num protos: 2
# 	Proto: 1 0.9
# 	Proto: 4 0.6
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 133+122 | Child: cub_122_Harris_Sparrow | Purity: 0.8666666666666667 | Num desc: 1 | Num protos: 3
# 	Proto: 12 0.6
# 	Proto: 16 1.0
# 	Proto: 10 1.0
# Node: 133+122 | Child: cub_133_White_throated_Sparrow | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 7 1.0
# 	Proto: 5 1.0
# Number of prototypes in parts_presences:  10
# Part-related (purity>0.5): 7
# Node: 175+165+182 | Child: 175+160 | Purity: 0.7000000000000001 | Num desc: 5 | Num protos: 3
# 	Proto: 1 0.9
# 	Proto: 6 1.0
# 	Proto: 4 0.2
# Node: 175+165+182 | Child: 165+164+163 | Purity: 0.44305555555555554 | Num desc: 4 | Num protos: 4
# 	Proto: 13 0.0
# 	Proto: 8 0.2222222222222222
# 	Proto: 11 0.75
# 	Proto: 7 0.8
# Node: 175+165+182 | Child: cub_182_Yellow_Warbler | Purity: 0.862962962962963 | Num desc: 1 | Num protos: 3
# 	Proto: 17 0.9
# 	Proto: 18 0.8
# 	Proto: 15 0.8888888888888888
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 4
# Node: 129+125 | Child: cub_125_Lincoln_Sparrow | Purity: 0.7333333333333334 | Num desc: 1 | Num protos: 3
# 	Proto: 13 0.9
# 	Proto: 16 0.3
# 	Proto: 17 1.0
# Node: 129+125 | Child: cub_129_Song_Sparrow | Purity: 0.7999999999999999 | Num desc: 1 | Num protos: 3
# 	Proto: 3 0.5
# 	Proto: 4 0.9
# 	Proto: 5 1.0
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 123+113 | Child: cub_113_Baird_Sparrow | Purity: 0.7666666666666666 | Num desc: 1 | Num protos: 3
# 	Proto: 12 1.0
# 	Proto: 18 0.6
# 	Proto: 15 0.7
# Node: 123+113 | Child: cub_123_Henslow_Sparrow | Purity: 0.9 | Num desc: 1 | Num protos: 2
# 	Proto: 1 0.9
# 	Proto: 9 0.9
# Number of prototypes in parts_presences:  5
# Part-related (purity>0.5): 5
# Node: 128+126 | Child: cub_126_Nelson_Sharp_tailed_Sparrow | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 16 0.9
# 	Proto: 17 1.0
# Node: 128+126 | Child: cub_128_Seaside_Sparrow | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 3 1.0
# 	Proto: 9 0.8
# 	Proto: 8 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 175+160 | Child: 160+109 | Purity: 0.9259259259259259 | Num desc: 2 | Num protos: 3
# 	Proto: 13 0.7777777777777778
# 	Proto: 10 1.0
# 	Proto: 11 1.0
# Node: 175+160 | Child: 175+176 | Purity: 0.925 | Num desc: 3 | Num protos: 4
# 	Proto: 1 1.0
# 	Proto: 6 0.9
# 	Proto: 4 0.8
# 	Proto: 0 1.0
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 165+164+163 | Child: 165+158 | Purity: 0.85 | Num desc: 2 | Num protos: 2
# 	Proto: 0 0.7
# 	Proto: 2 1.0
# Node: 165+164+163 | Child: cub_163_Cape_May_Warbler | Purity: 0.7555555555555555 | Num desc: 1 | Num protos: 3
# 	Proto: 19 0.6666666666666666
# 	Proto: 14 0.9
# 	Proto: 15 0.7
# Node: 165+164+163 | Child: cub_164_Cerulean_Warbler | Purity: 0.8 | Num desc: 1 | Num protos: 2
# 	Proto: 13 0.9
# 	Proto: 11 0.7
# Number of prototypes in parts_presences:  7
# Part-related (purity>0.5): 7
# Node: 175+176 | Child: 175+174 | Purity: 0.8972222222222221 | Num desc: 2 | Num protos: 4
# 	Proto: 5 0.8888888888888888
# 	Proto: 6 0.7
# 	Proto: 3 1.0
# 	Proto: 2 1.0
# Node: 175+176 | Child: cub_176_Prairie_Warbler | Purity: 0.9333333333333332 | Num desc: 1 | Num protos: 3
# 	Proto: 18 1.0
# 	Proto: 16 1.0
# 	Proto: 17 0.8
# Number of prototypes in parts_presences:  6
# Part-related (purity>0.5): 3
# Node: 160+109 | Child: cub_109_American_Redstart | Purity: 0.39999999999999997 | Num desc: 1 | Num protos: 3
# 	Proto: 13 0.8
# 	Proto: 18 0.1
# 	Proto: 17 0.3
# Node: 160+109 | Child: cub_160_Black_throated_Blue_Warbler | Purity: 0.7000000000000001 | Num desc: 1 | Num protos: 3
# 	Proto: 1 1.0
# 	Proto: 9 1.0
# 	Proto: 2 0.1
# Number of prototypes in parts_presences:  3
# Part-related (purity>0.5): 3
# Node: 165+158 | Child: cub_158_Bay_breasted_Warbler | Purity: 1.0 | Num desc: 1 | Num protos: 2
# 	Proto: 12 1.0
# 	Proto: 19 1.0
# Node: 165+158 | Child: cub_165_Chestnut_sided_Warbler | Purity: 0.9 | Num desc: 1 | Num protos: 1
# 	Proto: 7 0.9
# Number of prototypes in parts_presences:  4
# Part-related (purity>0.5): 4
# Node: 175+174 | Child: cub_174_Palm_Warbler | Purity: 0.85 | Num desc: 1 | Num protos: 2
# 	Proto: 16 1.0
# 	Proto: 17 0.7
# Node: 175+174 | Child: cub_175_Pine_Warbler | Purity: 0.95 | Num desc: 1 | Num protos: 2
# 	Proto: 8 0.9
# 	Proto: 2 1.0

# %%
print('Before masking')
print(np.nanmean(node_wise_purity))
print(np.nanstd(node_wise_purity))

print('After masking (of unmasked protos)')
print(np.nanmean(node_wise_purity_of_unmasked))
print(np.nanstd(node_wise_purity_of_unmasked))

print('Of masked protos')
print(np.nanmean(node_wise_purity_of_masked))
print(np.nanstd(node_wise_purity_of_masked))

print('% Masked', (masked_count/total_proto_count) * 100)
# Out:
# Before masking
# 0.7245531540829812
# 0.19346026634124774
# After masking (of unmasked protos)
# 0.7608326306602169
# 0.26739858433993197
# Of masked protos
# 0.2891387419165197
# 0.29139306271312104
# % Masked 14.976228209191758

# %% [markdown]
# # Visualizing part locations

# %%
# proto_parts_presences['17']

import pandas as pd
# df = pd.read_csv(list_csvfile_topk[0])
# df = pd.read_csv('runs/154-PruningNaiveHPIPNet_cnext13_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20/node_wise_top10/004+032_prototypes_top10_projectloader_last.csv')
df = pd.read_csv('runs/154-PruningNaiveHPIPNet_cnext13_CUB-18-imgnet-224_with-equalize-aug_img=224_nprotos=20/node_wise_top10/root_prototypes_top10_projectloader_last.csv')
print(list_csvfile_topk[0])
print(df.columns)

# %%
dict_node_wise_df.keys()
# Out:
# dict_keys(['root', '129+024+067', '089+046', '129+065', '024+051', '067+070', '089+090', '046+087', '129+192', '065+006', '024+031', '051+052', '067+068', '129+043', '192+081', '065+144', '006+071', '024+086', '031+004', '051+053', '067+069', '129+018', '043+078', '192+036', '081+083', '065+084', '144+147', '006+058', '071+072', '024+001', '031+032', '051+050', '129+107', '043+042', '078+038', '192+191', '036+188', '081+082', '065+061', '084+063', '144+143', '006+008', '024+100', '001+045', '031+033', '129+136', '107+151', '043+040', '078+041', '192+187', '191+189', '081+080', '082+079', '065+066', '061+064', '144+142', '006+005', '008+106', '024+023', '100+101', '001+003', '129+199', '136+085', '107+111', '151+153', '043+037', '040+102', '078+077', '192+190', '065+062', '144+145', '006+007', '024+025', '001+002', '129+118', '199+186', '136+138', '107+073', '111+112', '151+157', '153+154', '043+039', '065+059', '144+146', '129+104', '199+150', '186+185', '136+137', '107+093', '073+074', '151+156', '157+152', '153+155', '065+060', '144+141', '129+035', '199+094', '150+019', '107+030', '129+054', '035+055', '199+028', '150+149', '107+029', '129+175', '054+140', '035+048', '199+198', '150+091', '107+108', '129+011', '175+020', '054+057', '140+017', '035+056', '048+047', '199+194', '129+121', '011+013', '175+099', '054+014', '140+139', '035+034', '199+193', '129+117', '011+095', '013+088', '175+181', '054+016', '199+197', '193+195', '129+133', '117+114', '011+026', '095+096', '013+012', '175+168+173+183', '054+015', '199+196', '129+021', '133+130', '117+115', '011+049', '026+010', '095+098', '096+097', '175+162', '168+177', '173+161', '183+159', '129+128', '021+148', '133+076', '130+120', '117+116', '115+119', '011+009', '026+027', '175+167', '162+180', '168+200', '177+178', '173+179', '161+166', '183+184', '129+127', '128+131', '133+132', '175+169', '168+170', '173+172', '129+123', '128+124', '133+122', '175+165+182', '129+125', '123+113', '128+126', '175+160', '165+164+163', '175+176', '160+109', '165+158', '175+174'])

# %%
import os
import random
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import matplotlib.patches as patches

part_color_map = {
    1: 'red',
    2: 'blue',
    3: 'green',
    4: 'yellow',
    5: 'orange',
    6: 'purple',
    7: 'pink',
    8: 'brown',
    9: 'black',
    10: 'white',
    11: 'gray',
    12: 'cyan',
    13: 'magenta',
    14: 'lime',
    15: 'navy'
}

# Function to draw parts on an image
def draw_parts(img, part_locs):
    draw = ImageDraw.Draw(img)
    img_width, img_height = img.size
    for part_id, x_norm, y_norm, visible in part_locs:
        if visible:
            x = int(x_norm * img_width)
            y = int(y_norm * img_height)
            draw.ellipse((x - 2, y - 2, x + 2, y + 2), outline="red", fill=part_color_map[part_id])
    return img

def add_heatmap(latent_activation, input_image, only_peak=False, interpolate=True):
    """
    latent_activation -> np array of shape (H, W)
    input_image -> PIL image of size (H, W)
    """
    image_a = latent_activation#.cpu().numpy()
    # image_a[image_a != image_a.max()] = 0
    image_a = (image_a - image_a.min()) / (image_a.max() - image_a.min())
    
    input_image = np.array(input_image)
    image_b = (input_image - input_image.min()) / (input_image.max() - input_image.min())

    if interpolate:
        reshaped_image_a = np.array(Image.fromarray((image_a * 255).astype('uint8'))\
                                    .resize((input_image.shape[0], input_image.shape[1])))
    else:
        reshaped_image_a = np.array(Image.fromarray((image_a * 255).astype('uint8'))\
                                    .resize((input_image.shape[0], input_image.shape[1]), resample=Image.NEAREST))

    reshaped_image_a[reshaped_image_a != reshaped_image_a.max()] = 0
    
    normalized_heatmap = (reshaped_image_a - np.min(reshaped_image_a)) / (np.max(reshaped_image_a) - np.min(reshaped_image_a))
    
    heatmap_colormap = plt.get_cmap('jet')
    heatmap_colored = heatmap_colormap(normalized_heatmap)
    
    heatmap_colored_uint8 = (heatmap_colored[:, :, :3] * 255).astype(np.uint8)
    image_a_heatmap_pillow = Image.fromarray(heatmap_colored_uint8)
    image_b_pillow = Image.fromarray((image_b * 255).astype('uint8'))
#     pdb.set_trace()
    result_image = Image.blend(image_b_pillow, image_a_heatmap_pillow, alpha=0.7)
    
    return result_image

# Function to display images in a Jupyter notebook
def display_images(images, titles=None, bboxes=None):
    plt.figure(figsize=(15, 10))
    for i, img in enumerate(images, 1):
        plt.subplot(4, 5, i)
        plt.imshow(img)

        if bboxes:
            h_min_224, h_max_224, w_min_224, w_max_224 = bboxes[i-1]
            rect = patches.Rectangle((w_min_224, h_min_224), w_max_224 - w_min_224, h_max_224 - h_min_224,
                                 linewidth=1, edgecolor='r', facecolor='none')
            ax = plt.gca()
            ax.add_patch(rect)
        if titles:
            plt.title(titles[i-1])
        # plt.axis('off')
        
    plt.show()
    
# Randomly sample 10 images
# sampled_images = random.sample((dict_node_wise_df['052+053'][(dict_node_wise_df['052+053']['prototype'] == 12) & (dict_node_wise_df['052+053']['leaf'] == '050')][["node", "prototype", 'img name', 'scores', 'h_min_224', 'h_max_224', 'w_min_224', 'w_max_224', 'latent_activation']].values).tolist(), 10)
sampled_images = random.sample((dict_node_wise_df['054+016'][["node", "prototype", 'img name', 'scores', 'h_min_224', 'h_max_224', 'w_min_224', 'w_max_224', 'latent_activation']].values).tolist(), 10)
sampled_images = sorted(sampled_images, key=lambda x: x[3])[::-1]
# sampled_images = random.sample((df[(df['prototype'] == 10) & (df['leaf'] == '001')][["node", "prototype", 'img name', 'scores', 'h_min_224', 'h_max_224', 'w_min_224', 'w_max_224', 'latent_activation']].values).tolist(), 10)
# sampled_images = random.sample((df[df['max_part_activation'] > 0.7][['img_filename', 'img_path', 'activation']].values).tolist(), 1)
# sampled_images = random.sample((df[['img_filename', 'img_path', 'activation']].values).tolist(), 1)
# print(sampled_images)


# Draw parts or heatmap on the images
sampled_images_with_parts = []
sampled_images_bboxes = []
sampled_images_titles = []
for node_name, prototype_idx, img_path, score, h_min_224, h_max_224, w_min_224, w_max_224, latent_activation in sampled_images:
    # image_path = os.path.join(img_path)
    img_filename = ntpath.basename(img_path)
    img_index = img_filename_to_index[img_filename]
    image = Image.open(img_path)
    # pdb.set_trace()
    image = add_heatmap(latent_activation.clone().detach().cpu().numpy(), image, only_peak=True, interpolate=False)
    image = draw_parts(image, image_part_locs[img_index])
    sampled_images_with_parts.append(image)
    sampled_images_bboxes.append((h_min_224, h_max_224, w_min_224, w_max_224))
    sampled_images_titles.append(f'{round(score)}, N:{node_name}, P:{prototype_idx}')


# # Randomly sample 10 images
# sampled_images = random.sample((df[["node", "prototype", 'img name', 'scores', 'h_min_224', 'h_max_224', 'w_min_224', 'w_max_224']].values).tolist(), 10)
# # sampled_images = random.sample((df[(df['prototype'] == 10) & (df['leaf'] == '001')][["node", "prototype", 'img name', 'scores', 'h_min_224', 'h_max_224', 'w_min_224', 'w_max_224']].values).tolist(), 10)
# # sampled_images = random.sample((df[df['max_part_activation'] > 0.7][['img_filename', 'img_path', 'activation']].values).tolist(), 1)
# # sampled_images = random.sample((df[['img_filename', 'img_path', 'activation']].values).tolist(), 1)
# # print(sampled_images)


# # Draw parts or heatmap on the images
# sampled_images_with_parts = []
# sampled_images_bboxes = []
# sampled_images_titles = []
# for node_name, prototype_idx, img_path, score, h_min_224, h_max_224, w_min_224, w_max_224 in sampled_images:
#     # image_path = os.path.join(img_path)
#     img_filename = ntpath.basename(img_path)
#     img_index = img_filename_to_index[img_filename]
#     image = Image.open(img_path)
#     # pdb.set_trace()
#     # image = add_heatmap(latent_activation.clone().detach().cpu().numpy(), image)
#     image = draw_parts(image, image_part_locs[img_index])
#     sampled_images_with_parts.append(image)
#     sampled_images_bboxes.append((h_min_224, h_max_224, w_min_224, w_max_224))
#     sampled_images_titles.append(f'{round(score)}, N:{node_name}, P:{prototype_idx}')

# Display the images with parts
display_images(sampled_images_with_parts, titles=sampled_images_titles, bboxes=sampled_images_bboxes)

# %% [markdown]
# # HPnet

# %%
# run_path = "/home/harishbabu/projects/HPnet_lambda/saved_models/024_vgg19-14_cub18-224-prop-resized_10protos_kaiming-normal_batch=80_push-every=5_joint-eps=50_with-pretraining_CEDA=True"
# run_path = "/projects/ml4science/harishbabu/projects/HPnet_lambda/saved_models/029_vgg19-7_cub190-224-prop-resized_10protos_kaiming-normal_batch=80_push-every=5_joint-eps=50_with-pretraining_CEDA=True"
run_path = "/home/harishbabu/projects/HPnet_lambda/saved_models/037_vgg19-28_cub190-224-prop-resized_10protos_kaiming-normal_batch=80_push-every=5_joint-eps=50_CEDA=True"

# %%
import pandas as pd

csv_folder_path = os.path.join(run_path, 'node_wise_top10')
sample_csv_file = os.listdir(csv_folder_path)[0]
sample_image_path = pd.read_csv(os.path.join(csv_folder_path, sample_csv_file))['img name'][0]
print(sample_image_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       3 csv_folder_path = os.path.join(run_path, 'node_wise_top10')
# ----> 4 sample_csv_file = os.listdir(csv_folder_path)[0]
#       5 sample_image_path = pd.read_csv(os.path.join(csv_folder_path, sample_csv_file))['img name'][0]
#       6 print(sample_image_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/harishbabu/projects/HPnet_lambda/saved_models/037_vgg19-28_cub190-224-prop-resized_10protos_kaiming-normal_batch=80_push-every=5_joint-eps=50_CEDA=True/node_wise_top10'

# %%
parts_name_path = '/projects/ml4science/harishbabu/data/CUB_200_2011/parts/parts.txt'
imgs_id_path = '/projects/ml4science/harishbabu/data/CUB_200_2011/images_cub.txt'

# %%
image_meta_file_base_path = os.path.dirname(os.path.dirname(sample_image_path))
image_meta_filepath = os.path.join(image_meta_file_base_path, 'image_meta_file.json')

import json

with open(image_meta_filepath, 'r') as file:
    image_meta = json.load(file)    
print(image_meta)
# Out:
# {'cropped': True, 'padded': True, 'segmented': True, 'imagenet_background': True, 'is_employee': True, 'sample_class_name': 'cub_001_Black_footed_Albatross'}

# %%
dataset_path = '/projects/ml4science/harishbabu/data/CUB_200_2011/'  # part locs are loaded from here

if image_meta['cropped'] and image_meta['padded']:
    part_locs_file = os.path.join(dataset_path, 'parts', 'part_locs_normalized_after_cropped_after_padded.txt') 
    print('*-'*40)
    print('\t\t\tIMPORTANT: Using CROPPED and PADDED part locations')
    print('*-'*40)
elif not image_meta['cropped'] and image_meta['padded']:
    part_locs_file = os.path.join(dataset_path, 'parts', 'part_locs_normalized_after_padded.txt') 
    print('*-'*40)
    print('\t\t\tIMPORTANT: Using NOT CROPPED and PADDED part locations')
    print('*-'*40)
elif image_meta['cropped'] and not image_meta['padded']:
    part_locs_file = os.path.join(dataset_path, 'parts', 'part_locs_normalized_after_cropped.txt') 
    print('*-'*40)
    print('\t\t\tIMPORTANT: Using CROPPED and NOT PADDED part locations')
    print('*-'*40)
elif not image_meta['cropped'] and not image_meta['padded']:
    part_locs_file = os.path.join(dataset_path, 'parts', 'part_locs_normalized.txt') 
    print('*-'*40)
    print('\t\t\tIMPORTANT: Using NOT CROPPED and NOT PADDED part locations')
    print('*-'*40)
# Out:
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# 			IMPORTANT: Using CROPPED and PADDED part locations
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-

# %%
import ntpath
from collections import defaultdict

NUM_PARTS = 15
images_file = os.path.join(dataset_path, 'images_cub.txt')

# Read the image index to filename mapping
img_filename_to_index = {} # image filename to image index
with open(images_file, 'r') as file:
    for line in file:
        index, filename = line.strip().split()
        img_filename = ntpath.basename(filename)
        img_filename_to_index[img_filename] = int(index)

# Load part locations
image_part_locs = defaultdict(list)
with open(part_locs_file, 'r') as file:
    for line in file:
        parts = line.strip().split()
        image_index, part_id, x, y, visible = int(parts[0]), int(parts[1]), float(parts[2]), float(parts[3]), bool(float(parts[4]))
        image_part_locs[image_index].append((part_id, x, y, visible))

# %%
# def unshuffle_dataloader(dataloader):
#     if type(dataloader.dataset) == ImageFolder:
#         dataset = dataloader.dataset
#     else:
#         dataset = dataloader.dataset.dataset.dataset
#     new_dataloader = DataLoader(
#         dataset=dataset,
#         batch_size=dataloader.batch_size,
#         shuffle=False,
#         num_workers=dataloader.num_workers,
#         pin_memory=dataloader.pin_memory,
#         drop_last=dataloader.drop_last,
#         timeout=dataloader.timeout,
#         worker_init_fn=dataloader.worker_init_fn,
#         multiprocessing_context=dataloader.multiprocessing_context,
#         generator=dataloader.generator,
#         prefetch_factor=dataloader.prefetch_factor,'
#         persistent_workers=dataloader.persistent_workers
#     )
#     return new_dataloader

# projectloader = unshuffle_dataloader(projectloader)
# print(projectloader.batch_size)

# %%
list_csvfile_topk = []
list_node_wise_df = []
dict_node_wise_df = {}

node_wise_purity = []
for csvfile_topk in os.listdir(csv_folder_path):
    node_name = csvfile_topk.split('_')[0]
    node = root.get_node(node_name)
    csvfile_topk = os.path.join(csv_folder_path, csvfile_topk)
    list_csvfile_topk.append(csvfile_topk)
    dict_node_wise_df[node.name] = pd.read_csv(csvfile_topk)
    # node_purity = eval_prototypes_cub_parts_csv_nodewise(node, csvfile_topk, part_locs_file, parts_name_path, \
    #                           imgs_id_path, 'projectloader_topk_'+str(epoch), args, desc_threshold=0.2)
    node_purity, max_presence_purity  = eval_prototypes_cub_parts_csv_nodewise_maxmin(node, csvfile_topk, part_locs_file, parts_name_path, \
                              imgs_id_path, 'projectloader_topk_'+str(epoch), args, desc_threshold=0.2)
    node_wise_purity.append(node_purity)
# Out:
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 054+140 | Child: 054+057 | Purity: 0.0125 | Num desc: 5 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.125
# 	Proto: 6 0.0
# Node: 054+140 | Child: 140+017 | Purity: 0.09 | Num desc: 3 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.1
# 	Proto: 17 0.1
# 	Proto: 13 0.2
# 	Proto: 19 0.1
# 	Proto: 15 0.1
# 	Proto: 16 0.1
# 	Proto: 18 0.1
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 129+125 | Child: cub_129_Song_Sparrow | Purity: 0.08222222222222222 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2222222222222222
# 	Proto: 1 0.0
# 	Proto: 9 0.2
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.1
# 	Proto: 5 0.0
# 	Proto: 8 0.2
# 	Proto: 3 0.0
# 	Proto: 6 0.1
# Node: 129+125 | Child: cub_125_Lincoln_Sparrow | Purity: 0.13 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.1
# 	Proto: 11 0.1
# 	Proto: 17 0.2
# 	Proto: 13 0.2
# 	Proto: 19 0.1
# 	Proto: 15 0.1
# 	Proto: 16 0.1
# 	Proto: 18 0.1
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 011+095 | Child: 011+026 | Purity: 0.01111111111111111 | Num desc: 6 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.1111111111111111
# Node: 011+095 | Child: 095+096 | Purity: 0.0811111111111111 | Num desc: 4 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.1
# 	Proto: 11 0.4
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.0
# 	Proto: 15 0.1111111111111111
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 065+084 | Child: 065+061 | Purity: 0.01 | Num desc: 7 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.1
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 065+084 | Child: 084+063 | Purity: 0.06000000000000001 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.2
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.0
# 	Proto: 15 0.1
# 	Proto: 16 0.1
# 	Proto: 18 0.2
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 071+072 | Child: cub_071_Long_tailed_Jaeger | Purity: 0.0744047619047619 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.14285714285714285
# 	Proto: 1 0.3333333333333333
# 	Proto: 9 0.0
# 	Proto: 0 0.125
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.14285714285714285
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 071+072 | Child: cub_072_Pomarine_Jaeger | Purity: 0.19134920634920635 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3333333333333333
# 	Proto: 14 0.125
# 	Proto: 11 0.2222222222222222
# 	Proto: 17 0.0
# 	Proto: 13 0.2222222222222222
# 	Proto: 19 0.14285714285714285
# 	Proto: 15 0.5
# 	Proto: 16 0.125
# 	Proto: 18 0.14285714285714285
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 024+001 | Child: 024+100 | Purity: 0.08083333333333333 | Num desc: 5 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1
# 	Proto: 9 0.0
# 	Proto: 0 0.25
# 	Proto: 4 0.16666666666666666
# 	Proto: 2 0.125
# 	Proto: 5 0.0
# 	Proto: 8 0.16666666666666666
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 024+001 | Child: 001+045 | Purity: 0.07111111111111112 | Num desc: 4 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.1111111111111111
# 	Proto: 13 0.0
# 	Proto: 19 0.1
# 	Proto: 15 0.2
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 067+070 | Child: 067+068 | Purity: 0.18333333333333335 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.2222222222222222
# 	Proto: 1 0.2222222222222222
# 	Proto: 9 0.2222222222222222
# 	Proto: 0 0.1111111111111111
# 	Proto: 4 0.2222222222222222
# 	Proto: 2 0.16666666666666666
# 	Proto: 5 0.0
# 	Proto: 8 0.2222222222222222
# 	Proto: 3 0.2222222222222222
# 	Proto: 6 0.2222222222222222
# Node: 067+070 | Child: cub_070_Green_Violetear | Purity: 0.17333333333333334 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.4
# 	Proto: 11 0.3333333333333333
# 	Proto: 17 0.1
# 	Proto: 13 0.4
# 	Proto: 19 0.1
# 	Proto: 15 0.1
# 	Proto: 16 0.0
# 	Proto: 18 0.3
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 133+130 | Child: 133+076 | Purity: 0.021111111111111112 | Num desc: 4 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.1111111111111111
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 133+130 | Child: 130+120 | Purity: 0.01 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.1
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 129+199 | Child: 129+118 | Purity: 0.0 | Num desc: 82 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 129+199 | Child: 199+186 | Purity: 0.0 | Num desc: 15 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.0
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 153+154 | Child: 153+155 | Purity: 0.085 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.1
# 	Proto: 1 0.1
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.3
# 	Proto: 2 0.125
# 	Proto: 5 0.1
# 	Proto: 8 0.125
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 153+154 | Child: cub_154_Red_eyed_Vireo | Purity: 0.22305555555555556 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.25
# 	Proto: 14 0.2
# 	Proto: 11 0.25
# 	Proto: 17 0.2
# 	Proto: 13 0.125
# 	Proto: 19 0.25
# 	Proto: 15 0.3333333333333333
# 	Proto: 16 0.2
# 	Proto: 18 0.2
# 	Proto: 10 0.2222222222222222
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 129+043 | Child: 129+018 | Purity: 0.0 | Num desc: 118 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 129+043 | Child: 043+078 | Purity: 0.0 | Num desc: 10 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.0
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 199+194 | Child: 199+193 | Purity: 0.030000000000000006 | Num desc: 5 | Num protos: 10
# 	Proto: 7 0.1
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.1
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.1
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 199+194 | Child: cub_194_Cactus_Wren | Purity: 0.18753968253968253 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.3
# 	Proto: 11 0.14285714285714285
# 	Proto: 17 0.14285714285714285
# 	Proto: 13 0.14285714285714285
# 	Proto: 19 0.14285714285714285
# 	Proto: 15 0.14285714285714285
# 	Proto: 16 0.2
# 	Proto: 18 0.25
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 2
# Node: 161+166 | Child: cub_161_Blue_winged_Warbler | Purity: 0.24194444444444443 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.3
# 	Proto: 9 0.2
# 	Proto: 0 0.3
# 	Proto: 4 0.16666666666666666
# 	Proto: 2 0.1111111111111111
# 	Proto: 5 0.16666666666666666
# 	Proto: 8 0.3
# 	Proto: 3 0.375
# 	Proto: 6 0.3
# Node: 161+166 | Child: cub_166_Golden_winged_Warbler | Purity: 0.4011111111111111 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.3
# 	Proto: 11 0.3
# 	Proto: 17 0.5
# 	Proto: 13 0.5
# 	Proto: 19 0.6
# 	Proto: 15 0.1111111111111111
# 	Proto: 16 0.6
# 	Proto: 18 0.5
# 	Proto: 10 0.3
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 040+102 | Child: cub_040_Olive_sided_Flycatcher | Purity: 0.13111111111111112 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2222222222222222
# 	Proto: 1 0.2222222222222222
# 	Proto: 9 0.1111111111111111
# 	Proto: 0 0.0
# 	Proto: 4 0.1
# 	Proto: 2 0.0
# 	Proto: 5 0.1111111111111111
# 	Proto: 8 0.2222222222222222
# 	Proto: 3 0.2222222222222222
# 	Proto: 6 0.1
# Node: 040+102 | Child: cub_102_Western_Wood_Pewee | Purity: 0.3152777777777778 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2222222222222222
# 	Proto: 14 0.3333333333333333
# 	Proto: 11 0.2
# 	Proto: 17 0.3
# 	Proto: 13 0.5
# 	Proto: 19 0.2222222222222222
# 	Proto: 15 0.2222222222222222
# 	Proto: 16 0.4444444444444444
# 	Proto: 18 0.3333333333333333
# 	Proto: 10 0.375
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 011+013 | Child: 011+095 | Purity: 0.0 | Num desc: 10 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 011+013 | Child: 013+088 | Purity: 0.042222222222222223 | Num desc: 3 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.1
# 	Proto: 19 0.1
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.2222222222222222
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 168+200 | Child: 168+170 | Purity: 0.23999999999999994 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.3
# 	Proto: 1 0.3
# 	Proto: 9 0.0
# 	Proto: 0 0.3
# 	Proto: 4 0.3
# 	Proto: 2 0.3
# 	Proto: 5 0.2
# 	Proto: 8 0.1
# 	Proto: 3 0.3
# 	Proto: 6 0.3
# Node: 168+200 | Child: cub_200_Common_Yellowthroat | Purity: 0.29888888888888887 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.3
# 	Proto: 11 0.25
# 	Proto: 17 0.3
# 	Proto: 13 0.3
# 	Proto: 19 0.1
# 	Proto: 15 0.3
# 	Proto: 16 0.4444444444444444
# 	Proto: 18 0.25
# 	Proto: 10 0.4444444444444444
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 175+174 | Child: cub_175_Pine_Warbler | Purity: 0.1916666666666667 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.375
# 	Proto: 1 0.1
# 	Proto: 9 0.1
# 	Proto: 0 0.1
# 	Proto: 4 0.1
# 	Proto: 2 0.2222222222222222
# 	Proto: 5 0.375
# 	Proto: 8 0.1
# 	Proto: 3 0.2222222222222222
# 	Proto: 6 0.2222222222222222
# Node: 175+174 | Child: cub_174_Palm_Warbler | Purity: 0.17055555555555554 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1111111111111111
# 	Proto: 14 0.1
# 	Proto: 11 0.1
# 	Proto: 17 0.1111111111111111
# 	Proto: 13 0.3
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.1111111111111111
# 	Proto: 16 0.4
# 	Proto: 18 0.25
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 082+079 | Child: cub_082_Ringed_Kingfisher | Purity: 0.2633333333333333 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.1111111111111111
# 	Proto: 1 0.25
# 	Proto: 9 0.2222222222222222
# 	Proto: 0 0.2222222222222222
# 	Proto: 4 0.2222222222222222
# 	Proto: 2 0.25
# 	Proto: 5 0.3
# 	Proto: 8 0.2222222222222222
# 	Proto: 3 0.5
# 	Proto: 6 0.3333333333333333
# Node: 082+079 | Child: cub_079_Belted_Kingfisher | Purity: 0.2577777777777778 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.3333333333333333
# 	Proto: 11 0.3
# 	Proto: 17 0.2222222222222222
# 	Proto: 13 0.2
# 	Proto: 19 0.3
# 	Proto: 15 0.3
# 	Proto: 16 0.3
# 	Proto: 18 0.1
# 	Proto: 10 0.2222222222222222
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 129+133 | Child: 129+021 | Purity: 0.0 | Num desc: 11 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 129+133 | Child: 133+130 | Purity: 0.01 | Num desc: 6 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.1
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 078+038 | Child: 078+041 | Purity: 0.05111111111111111 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.2
# 	Proto: 4 0.1111111111111111
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.2
# Node: 078+038 | Child: cub_038_Great_Crested_Flycatcher | Purity: 0.21999999999999997 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.3333333333333333
# 	Proto: 11 0.0
# 	Proto: 17 0.3333333333333333
# 	Proto: 13 0.3
# 	Proto: 19 0.2
# 	Proto: 15 0.1
# 	Proto: 16 0.1
# 	Proto: 18 0.3333333333333333
# 	Proto: 10 0.4
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 168+177 | Child: 168+200 | Purity: 0.04 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.2
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 168+177 | Child: 177+178 | Purity: 0.11000000000000001 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.0
# 	Proto: 11 0.2
# 	Proto: 17 0.1
# 	Proto: 13 0.1
# 	Proto: 19 0.1
# 	Proto: 15 0.1
# 	Proto: 16 0.2
# 	Proto: 18 0.0
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 192+036 | Child: 192+191 | Purity: 0.05333333333333333 | Num desc: 5 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.2
# 	Proto: 2 0.0
# 	Proto: 5 0.3333333333333333
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 192+036 | Child: 036+188 | Purity: 0.1542857142857143 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.14285714285714285
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.3
# 	Proto: 19 0.2
# 	Proto: 15 0.3
# 	Proto: 16 0.3
# 	Proto: 18 0.3
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 026+010 | Child: 026+027 | Purity: 0.11111111111111112 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.1
# 	Proto: 1 0.1
# 	Proto: 9 0.2
# 	Proto: 0 0.1
# 	Proto: 4 0.0
# 	Proto: 2 0.2
# 	Proto: 5 0.2
# 	Proto: 8 0.1
# 	Proto: 3 0.1111111111111111
# 	Proto: 6 0.0
# Node: 026+010 | Child: cub_010_Red_winged_Blackbird | Purity: 0.18944444444444444 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.25
# 	Proto: 14 0.0
# 	Proto: 11 0.3
# 	Proto: 17 0.2222222222222222
# 	Proto: 13 0.2222222222222222
# 	Proto: 19 0.25
# 	Proto: 15 0.25
# 	Proto: 16 0.2
# 	Proto: 18 0.2
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 1
# Node: 192+187 | Child: 192+190 | Purity: 0.11000000000000001 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1
# 	Proto: 9 0.0
# 	Proto: 0 0.4
# 	Proto: 4 0.0
# 	Proto: 2 0.1
# 	Proto: 5 0.0
# 	Proto: 8 0.3
# 	Proto: 3 0.2
# 	Proto: 6 0.0
# Node: 192+187 | Child: cub_187_American_Three_toed_Woodpecker | Purity: 0.29000000000000004 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.4
# 	Proto: 11 0.2
# 	Proto: 17 0.4
# 	Proto: 13 0.0
# 	Proto: 19 0.4
# 	Proto: 15 0.5
# 	Proto: 16 0.6
# 	Proto: 18 0.2
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 006+005 | Child: 006+007 | Purity: 0.1177777777777778 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.1
# 	Proto: 1 0.1
# 	Proto: 9 0.0
# 	Proto: 0 0.2222222222222222
# 	Proto: 4 0.1111111111111111
# 	Proto: 2 0.1
# 	Proto: 5 0.1111111111111111
# 	Proto: 8 0.1111111111111111
# 	Proto: 3 0.2222222222222222
# 	Proto: 6 0.1
# Node: 006+005 | Child: cub_005_Crested_Auklet | Purity: 0.2047222222222222 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.2222222222222222
# 	Proto: 11 0.2222222222222222
# 	Proto: 17 0.4444444444444444
# 	Proto: 13 0.125
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.2222222222222222
# 	Proto: 16 0.0
# 	Proto: 18 0.2
# 	Proto: 10 0.4
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 133+132 | Child: 133+122 | Purity: 0.04444444444444444 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.2222222222222222
# 	Proto: 5 0.2222222222222222
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 133+132 | Child: cub_132_White_crowned_Sparrow | Purity: 0.13 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.1
# 	Proto: 11 0.0
# 	Proto: 17 0.1
# 	Proto: 13 0.2
# 	Proto: 19 0.1
# 	Proto: 15 0.5
# 	Proto: 16 0.2
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 011+009 | Child: cub_011_Rusty_Blackbird | Purity: 0.15333333333333335 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.1111111111111111
# 	Proto: 1 0.2
# 	Proto: 9 0.1111111111111111
# 	Proto: 0 0.3
# 	Proto: 4 0.2
# 	Proto: 2 0.2
# 	Proto: 5 0.0
# 	Proto: 8 0.1111111111111111
# 	Proto: 3 0.2
# 	Proto: 6 0.1
# Node: 011+009 | Child: cub_009_Brewer_Blackbird | Purity: 0.25222222222222224 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.2222222222222222
# 	Proto: 11 0.3
# 	Proto: 17 0.5
# 	Proto: 13 0.3
# 	Proto: 19 0.2
# 	Proto: 15 0.3
# 	Proto: 16 0.1
# 	Proto: 18 0.3
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 7
# Node: 024+025 | Child: cub_024_Red_faced_Cormorant | Purity: 0.41 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.25
# 	Proto: 1 0.6
# 	Proto: 9 0.6
# 	Proto: 0 0.25
# 	Proto: 4 0.25
# 	Proto: 2 0.6
# 	Proto: 5 0.25
# 	Proto: 8 0.6
# 	Proto: 3 0.2
# 	Proto: 6 0.5
# Node: 024+025 | Child: cub_025_Pelagic_Cormorant | Purity: 0.33611111111111114 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.8
# 	Proto: 14 0.8
# 	Proto: 11 0.3333333333333333
# 	Proto: 17 0.1
# 	Proto: 13 0.125
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.8
# 	Proto: 16 0.125
# 	Proto: 18 0.16666666666666666
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 054+016 | Child: 054+015 | Purity: 0.14095238095238097 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.14285714285714285
# 	Proto: 1 0.1111111111111111
# 	Proto: 9 0.0
# 	Proto: 0 0.3333333333333333
# 	Proto: 4 0.0
# 	Proto: 2 0.2222222222222222
# 	Proto: 5 0.1
# 	Proto: 8 0.2
# 	Proto: 3 0.1
# 	Proto: 6 0.2
# Node: 054+016 | Child: cub_016_Painted_Bunting | Purity: 0.2127777777777778 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.3333333333333333
# 	Proto: 11 0.125
# 	Proto: 17 0.2
# 	Proto: 13 0.125
# 	Proto: 19 0.2222222222222222
# 	Proto: 15 0.2222222222222222
# 	Proto: 16 0.2
# 	Proto: 18 0.2
# 	Proto: 10 0.3
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 150+019 | Child: 150+149 | Purity: 0.0325 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.1
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.1
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.125
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 150+019 | Child: cub_019_Gray_Catbird | Purity: 0.1107936507936508 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.3
# 	Proto: 11 0.0
# 	Proto: 17 0.2222222222222222
# 	Proto: 13 0.2857142857142857
# 	Proto: 19 0.1
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 1
# Node: 199+028 | Child: 199+198 | Purity: 0.01 | Num desc: 7 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.1
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 199+028 | Child: cub_028_Brown_Creeper | Purity: 0.2 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.6
# 	Proto: 14 0.1
# 	Proto: 11 0.1
# 	Proto: 17 0.1
# 	Proto: 13 0.1
# 	Proto: 19 0.3
# 	Proto: 15 0.3
# 	Proto: 16 0.2
# 	Proto: 18 0.1
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 065+061 | Child: 065+066 | Purity: 0.08222222222222222 | Num desc: 5 | Num protos: 10
# 	Proto: 7 0.3
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.2222222222222222
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.3
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 065+061 | Child: 061+064 | Purity: 0.05 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.1
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.1
# 	Proto: 19 0.1
# 	Proto: 15 0.0
# 	Proto: 16 0.1
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 130+120 | Child: cub_130_Tree_Sparrow | Purity: 0.09 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.1
# 	Proto: 9 0.1
# 	Proto: 0 0.1
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.1
# 	Proto: 8 0.1
# 	Proto: 3 0.1
# 	Proto: 6 0.1
# Node: 130+120 | Child: cub_120_Fox_Sparrow | Purity: 0.27083333333333337 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3333333333333333
# 	Proto: 14 0.1
# 	Proto: 11 0.4
# 	Proto: 17 0.4
# 	Proto: 13 0.125
# 	Proto: 19 0.3
# 	Proto: 15 0.125
# 	Proto: 16 0.4
# 	Proto: 18 0.125
# 	Proto: 10 0.4
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 4
# Node: 168+170 | Child: cub_168_Kentucky_Warbler | Purity: 0.3866666666666667 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.4
# 	Proto: 1 0.5555555555555556
# 	Proto: 9 0.2
# 	Proto: 0 0.2
# 	Proto: 4 0.5555555555555556
# 	Proto: 2 0.4
# 	Proto: 5 0.2
# 	Proto: 8 0.5555555555555556
# 	Proto: 3 0.6
# 	Proto: 6 0.2
# Node: 168+170 | Child: cub_170_Mourning_Warbler | Purity: 0.15678571428571425 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.14285714285714285
# 	Proto: 14 0.14285714285714285
# 	Proto: 11 0.125
# 	Proto: 17 0.3
# 	Proto: 13 0.14285714285714285
# 	Proto: 19 0.14285714285714285
# 	Proto: 15 0.14285714285714285
# 	Proto: 16 0.14285714285714285
# 	Proto: 18 0.14285714285714285
# 	Proto: 10 0.14285714285714285
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 129+104 | Child: 129+035 | Purity: 0.0 | Num desc: 80 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 129+104 | Child: cub_104_American_Pipit | Purity: 0.12111111111111113 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.1
# 	Proto: 11 0.0
# 	Proto: 17 0.1111111111111111
# 	Proto: 13 0.1
# 	Proto: 19 0.0
# 	Proto: 15 0.3
# 	Proto: 16 0.0
# 	Proto: 18 0.2
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 175+176 | Child: 175+174 | Purity: 0.14027777777777778 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.2222222222222222
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.2222222222222222
# 	Proto: 4 0.1
# 	Proto: 2 0.1111111111111111
# 	Proto: 5 0.3
# 	Proto: 8 0.125
# 	Proto: 3 0.1
# 	Proto: 6 0.2222222222222222
# Node: 175+176 | Child: cub_176_Prairie_Warbler | Purity: 0.1787301587301587 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2222222222222222
# 	Proto: 14 0.3
# 	Proto: 11 0.1
# 	Proto: 17 0.1
# 	Proto: 13 0.14285714285714285
# 	Proto: 19 0.3
# 	Proto: 15 0.1
# 	Proto: 16 0.2222222222222222
# 	Proto: 18 0.2
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 2
# Node: 089+090 | Child: cub_089_Hooded_Merganser | Purity: 0.2833333333333334 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.3
# 	Proto: 9 0.0
# 	Proto: 0 0.2
# 	Proto: 4 0.3
# 	Proto: 2 0.5555555555555556
# 	Proto: 5 0.5555555555555556
# 	Proto: 8 0.3
# 	Proto: 3 0.2
# 	Proto: 6 0.2222222222222222
# Node: 089+090 | Child: cub_090_Red_breasted_Merganser | Purity: 0.2 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.3
# 	Proto: 11 0.0
# 	Proto: 17 0.4
# 	Proto: 13 0.0
# 	Proto: 19 0.3
# 	Proto: 15 0.0
# 	Proto: 16 0.3
# 	Proto: 18 0.0
# 	Proto: 10 0.4
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 065+059 | Child: 065+060 | Purity: 0.06 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1
# 	Proto: 9 0.3
# 	Proto: 0 0.1
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.1
# Node: 065+059 | Child: cub_059_California_Gull | Purity: 0.24500000000000002 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.3
# 	Proto: 11 0.1
# 	Proto: 17 0.25
# 	Proto: 13 0.3
# 	Proto: 19 0.3
# 	Proto: 15 0.3
# 	Proto: 16 0.2
# 	Proto: 18 0.3
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 199+094 | Child: 199+028 | Purity: 0.01 | Num desc: 8 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.1
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 199+094 | Child: cub_094_White_breasted_Nuthatch | Purity: 0.19111111111111115 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.2
# 	Proto: 11 0.3
# 	Proto: 17 0.1
# 	Proto: 13 0.1
# 	Proto: 19 0.1
# 	Proto: 15 0.3
# 	Proto: 16 0.3
# 	Proto: 18 0.1
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 151+156 | Child: cub_151_Black_capped_Vireo | Purity: 0.28269841269841267 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.3
# 	Proto: 1 0.2857142857142857
# 	Proto: 9 0.2857142857142857
# 	Proto: 0 0.3333333333333333
# 	Proto: 4 0.4
# 	Proto: 2 0.4
# 	Proto: 5 0.3
# 	Proto: 8 0.3
# 	Proto: 3 0.1111111111111111
# 	Proto: 6 0.1111111111111111
# Node: 151+156 | Child: cub_156_White_eyed_Vireo | Purity: 0.25 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.0
# 	Proto: 11 0.3
# 	Proto: 17 0.4
# 	Proto: 13 0.4
# 	Proto: 19 0.4
# 	Proto: 15 0.3
# 	Proto: 16 0.2
# 	Proto: 18 0.3
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 006+007 | Child: cub_006_Least_Auklet | Purity: 0.20571428571428574 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2857142857142857
# 	Proto: 1 0.0
# 	Proto: 9 0.4
# 	Proto: 0 0.14285714285714285
# 	Proto: 4 0.1
# 	Proto: 2 0.2
# 	Proto: 5 0.14285714285714285
# 	Proto: 8 0.2
# 	Proto: 3 0.3
# 	Proto: 6 0.2857142857142857
# Node: 006+007 | Child: cub_007_Parakeet_Auklet | Purity: 0.225 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3333333333333333
# 	Proto: 14 0.1111111111111111
# 	Proto: 11 0.2222222222222222
# 	Proto: 17 0.4
# 	Proto: 13 0.1111111111111111
# 	Proto: 19 0.2222222222222222
# 	Proto: 15 0.1
# 	Proto: 16 0.25
# 	Proto: 18 0.1
# 	Proto: 10 0.4
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 107+093 | Child: 107+030 | Purity: 0.01 | Num desc: 4 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.1
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 107+093 | Child: cub_093_Clark_Nutcracker | Purity: 0.19111111111111112 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.1
# 	Proto: 11 0.1111111111111111
# 	Proto: 17 0.3
# 	Proto: 13 0.0
# 	Proto: 19 0.3
# 	Proto: 15 0.1
# 	Proto: 16 0.3
# 	Proto: 18 0.3
# 	Proto: 10 0.3
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 175+162 | Child: 175+167 | Purity: 0.0 | Num desc: 12 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 175+162 | Child: 162+180 | Purity: 0.09142857142857143 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.14285714285714285
# 	Proto: 11 0.0
# 	Proto: 17 0.2
# 	Proto: 13 0.0
# 	Proto: 19 0.0
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.2857142857142857
# 	Proto: 10 0.2857142857142857
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 140+139 | Child: cub_140_Summer_Tanager | Purity: 0.23000000000000004 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.1
# 	Proto: 9 0.2
# 	Proto: 0 0.1
# 	Proto: 4 0.5
# 	Proto: 2 0.2
# 	Proto: 5 0.2
# 	Proto: 8 0.4
# 	Proto: 3 0.2
# 	Proto: 6 0.2
# Node: 140+139 | Child: cub_139_Scarlet_Tanager | Purity: 0.20916666666666664 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.2222222222222222
# 	Proto: 11 0.4444444444444444
# 	Proto: 17 0.2222222222222222
# 	Proto: 13 0.125
# 	Proto: 19 0.2222222222222222
# 	Proto: 15 0.1
# 	Proto: 16 0.4444444444444444
# 	Proto: 18 0.2
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 129+123 | Child: 129+125 | Purity: 0.07333333333333333 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.1
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.1
# 	Proto: 8 0.1
# 	Proto: 3 0.1
# 	Proto: 6 0.3333333333333333
# Node: 129+123 | Child: 123+113 | Purity: 0.11027777777777778 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.2222222222222222
# 	Proto: 14 0.1
# 	Proto: 11 0.2222222222222222
# 	Proto: 17 0.0
# 	Proto: 13 0.1111111111111111
# 	Proto: 19 0.125
# 	Proto: 15 0.0
# 	Proto: 16 0.1
# 	Proto: 18 0.2222222222222222
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 153+155 | Child: cub_153_Philadelphia_Vireo | Purity: 0.18222222222222223 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2222222222222222
# 	Proto: 1 0.2222222222222222
# 	Proto: 9 0.2
# 	Proto: 0 0.2222222222222222
# 	Proto: 4 0.1
# 	Proto: 2 0.2222222222222222
# 	Proto: 5 0.2222222222222222
# 	Proto: 8 0.2
# 	Proto: 3 0.1111111111111111
# 	Proto: 6 0.1
# Node: 153+155 | Child: cub_155_Warbling_Vireo | Purity: 0.21500000000000002 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.125
# 	Proto: 11 0.4
# 	Proto: 17 0.2
# 	Proto: 13 0.3
# 	Proto: 19 0.4
# 	Proto: 15 0.2
# 	Proto: 16 0.2
# 	Proto: 18 0.2
# 	Proto: 10 0.125
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 144+141 | Child: cub_144_Common_Tern | Purity: 0.1925 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.2
# 	Proto: 9 0.2
# 	Proto: 0 0.125
# 	Proto: 4 0.2
# 	Proto: 2 0.2
# 	Proto: 5 0.2
# 	Proto: 8 0.2
# 	Proto: 3 0.2
# 	Proto: 6 0.2
# Node: 144+141 | Child: cub_141_Artic_Tern | Purity: 0.29444444444444445 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.1
# 	Proto: 11 0.2222222222222222
# 	Proto: 17 0.3
# 	Proto: 13 0.5
# 	Proto: 19 0.2
# 	Proto: 15 0.4
# 	Proto: 16 0.5
# 	Proto: 18 0.2222222222222222
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 001+045 | Child: 001+003 | Purity: 0.155 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.125
# 	Proto: 0 0.1
# 	Proto: 4 0.0
# 	Proto: 2 0.5
# 	Proto: 5 0.2
# 	Proto: 8 0.125
# 	Proto: 3 0.3
# 	Proto: 6 0.2
# Node: 001+045 | Child: cub_045_Northern_Fulmar | Purity: 0.1461111111111111 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.2
# 	Proto: 11 0.0
# 	Proto: 17 0.1111111111111111
# 	Proto: 13 0.3
# 	Proto: 19 0.2
# 	Proto: 15 0.2
# 	Proto: 16 0.125
# 	Proto: 18 0.125
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 144+146 | Child: 144+141 | Purity: 0.04 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.2
# 	Proto: 9 0.0
# 	Proto: 0 0.1
# 	Proto: 4 0.1
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 144+146 | Child: cub_146_Forsters_Tern | Purity: 0.17 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.1
# 	Proto: 11 0.2
# 	Proto: 17 0.2
# 	Proto: 13 0.1
# 	Proto: 19 0.2
# 	Proto: 15 0.2
# 	Proto: 16 0.1
# 	Proto: 18 0.3
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 081+083 | Child: 081+082 | Purity: 0.04928571428571429 | Num desc: 4 | Num protos: 10
# 	Proto: 7 0.14285714285714285
# 	Proto: 1 0.1
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.25
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 081+083 | Child: cub_083_White_breasted_Kingfisher | Purity: 0.07722222222222222 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.125
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.125
# 	Proto: 16 0.2
# 	Proto: 18 0.1111111111111111
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 199+150 | Child: 199+094 | Purity: 0.01 | Num desc: 9 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.1
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 199+150 | Child: 150+019 | Purity: 0.08539682539682539 | Num desc: 4 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.14285714285714285
# 	Proto: 17 0.3
# 	Proto: 13 0.1111111111111111
# 	Proto: 19 0.3
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 054+014 | Child: 054+016 | Purity: 0.052500000000000005 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.125
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.1
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.1
# 	Proto: 3 0.1
# 	Proto: 6 0.1
# Node: 054+014 | Child: cub_014_Indigo_Bunting | Purity: 0.1716666666666667 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2222222222222222
# 	Proto: 14 0.1111111111111111
# 	Proto: 11 0.125
# 	Proto: 17 0.0
# 	Proto: 13 0.2
# 	Proto: 19 0.3
# 	Proto: 15 0.2222222222222222
# 	Proto: 16 0.125
# 	Proto: 18 0.1111111111111111
# 	Proto: 10 0.3
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 024+100 | Child: 024+023 | Purity: 0.09178571428571428 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.25
# 	Proto: 9 0.0
# 	Proto: 0 0.1
# 	Proto: 4 0.0
# 	Proto: 2 0.14285714285714285
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.3
# 	Proto: 6 0.125
# Node: 024+100 | Child: 100+101 | Purity: 0.1478968253968254 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.0
# 	Proto: 11 0.125
# 	Proto: 17 0.2
# 	Proto: 13 0.14285714285714285
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.2
# 	Proto: 16 0.3
# 	Proto: 18 0.0
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 107+111 | Child: 107+073 | Purity: 0.01111111111111111 | Num desc: 7 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.1111111111111111
# Node: 107+111 | Child: 111+112 | Purity: 0.21999999999999997 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.0
# 	Proto: 11 0.3
# 	Proto: 17 0.3
# 	Proto: 13 0.3
# 	Proto: 19 0.3
# 	Proto: 15 0.3
# 	Proto: 16 0.3
# 	Proto: 18 0.0
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 144+145 | Child: 144+146 | Purity: 0.02 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.2
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 144+145 | Child: cub_145_Elegant_Tern | Purity: 0.18222222222222223 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.16666666666666666
# 	Proto: 14 0.2
# 	Proto: 11 0.1
# 	Proto: 17 0.2222222222222222
# 	Proto: 13 0.16666666666666666
# 	Proto: 19 0.1
# 	Proto: 15 0.1
# 	Proto: 16 0.5
# 	Proto: 18 0.16666666666666666
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 043+037 | Child: 043+039 | Purity: 0.11273809523809523 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.125
# 	Proto: 1 0.125
# 	Proto: 9 0.0
# 	Proto: 0 0.16666666666666666
# 	Proto: 4 0.14285714285714285
# 	Proto: 2 0.125
# 	Proto: 5 0.14285714285714285
# 	Proto: 8 0.1
# 	Proto: 3 0.2
# 	Proto: 6 0.0
# Node: 043+037 | Child: cub_037_Acadian_Flycatcher | Purity: 0.2375 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.375
# 	Proto: 11 0.25
# 	Proto: 17 0.1
# 	Proto: 13 0.2
# 	Proto: 19 0.125
# 	Proto: 15 0.3
# 	Proto: 16 0.375
# 	Proto: 18 0.2
# 	Proto: 10 0.25
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 129+136 | Child: 129+199 | Purity: 0.0 | Num desc: 97 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 129+136 | Child: 136+085 | Purity: 0.0611111111111111 | Num desc: 4 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.1
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.1
# 	Proto: 15 0.1
# 	Proto: 16 0.1111111111111111
# 	Proto: 18 0.1
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 1
# Node: 006+058 | Child: 006+008 | Purity: 0.01111111111111111 | Num desc: 5 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1111111111111111
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 006+058 | Child: cub_058_Pigeon_Guillemot | Purity: 0.2533333333333333 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.1111111111111111
# 	Proto: 11 0.3
# 	Proto: 17 0.3
# 	Proto: 13 0.3
# 	Proto: 19 0.3
# 	Proto: 15 0.1111111111111111
# 	Proto: 16 0.2
# 	Proto: 18 0.6
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 013+088 | Child: 013+012 | Purity: 0.03222222222222222 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1111111111111111
# 	Proto: 9 0.1111111111111111
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.1
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 013+088 | Child: cub_088_Western_Meadowlark | Purity: 0.09222222222222223 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.1
# 	Proto: 11 0.1111111111111111
# 	Proto: 17 0.1111111111111111
# 	Proto: 13 0.16666666666666666
# 	Proto: 19 0.0
# 	Proto: 15 0.1111111111111111
# 	Proto: 16 0.1
# 	Proto: 18 0.1111111111111111
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 065+144 | Child: 065+084 | Purity: 0.0 | Num desc: 9 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 065+144 | Child: 144+147 | Purity: 0.0 | Num desc: 7 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.0
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 1
# Node: 081+080 | Child: cub_081_Pied_Kingfisher | Purity: 0.37666666666666665 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.3333333333333333
# 	Proto: 1 0.5555555555555556
# 	Proto: 9 0.3
# 	Proto: 0 0.5
# 	Proto: 4 0.3
# 	Proto: 2 0.3
# 	Proto: 5 0.3
# 	Proto: 8 0.4
# 	Proto: 3 0.3333333333333333
# 	Proto: 6 0.4444444444444444
# Node: 081+080 | Child: cub_080_Green_Kingfisher | Purity: 0.27785714285714286 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3333333333333333
# 	Proto: 14 0.25
# 	Proto: 11 0.2
# 	Proto: 17 0.3
# 	Proto: 13 0.2
# 	Proto: 19 0.3333333333333333
# 	Proto: 15 0.2
# 	Proto: 16 0.2
# 	Proto: 18 0.3333333333333333
# 	Proto: 10 0.42857142857142855
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 191+189 | Child: cub_191_Red_headed_Woodpecker | Purity: 0.14158730158730162 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.1
# 	Proto: 1 0.2222222222222222
# 	Proto: 9 0.1
# 	Proto: 0 0.1111111111111111
# 	Proto: 4 0.0
# 	Proto: 2 0.2857142857142857
# 	Proto: 5 0.1111111111111111
# 	Proto: 8 0.2857142857142857
# 	Proto: 3 0.1
# 	Proto: 6 0.1
# Node: 191+189 | Child: cub_189_Red_bellied_Woodpecker | Purity: 0.3211111111111111 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.1
# 	Proto: 11 0.3
# 	Proto: 17 0.3
# 	Proto: 13 0.4
# 	Proto: 19 0.5
# 	Proto: 15 0.3
# 	Proto: 16 0.4
# 	Proto: 18 0.1111111111111111
# 	Proto: 10 0.5
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 024+023 | Child: 024+025 | Purity: 0.16333333333333333 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.4
# 	Proto: 1 0.5
# 	Proto: 9 0.3333333333333333
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.4
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 024+023 | Child: cub_023_Brandt_Cormorant | Purity: 0.21857142857142856 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.4
# 	Proto: 11 0.3
# 	Proto: 17 0.2
# 	Proto: 13 0.0
# 	Proto: 19 0.2857142857142857
# 	Proto: 15 0.0
# 	Proto: 16 0.1
# 	Proto: 18 0.2
# 	Proto: 10 0.4
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 1
# Node: 199+196 | Child: cub_199_Winter_Wren | Purity: 0.38 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.5
# 	Proto: 1 0.5
# 	Proto: 9 0.3
# 	Proto: 0 0.2
# 	Proto: 4 0.5
# 	Proto: 2 0.5
# 	Proto: 5 0.3
# 	Proto: 8 0.5
# 	Proto: 3 0.2
# 	Proto: 6 0.3
# Node: 199+196 | Child: cub_196_House_Wren | Purity: 0.22222222222222224 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.2
# 	Proto: 11 0.2222222222222222
# 	Proto: 17 0.2222222222222222
# 	Proto: 13 0.1
# 	Proto: 19 0.2
# 	Proto: 15 0.5555555555555556
# 	Proto: 16 0.2
# 	Proto: 18 0.1
# 	Proto: 10 0.2222222222222222
# Number of prototypes in parts_presences:  40
# Part-related (purity>0.5): 0
# Node: 175+168+173+183 | Child: 175+162 | Purity: 0.0 | Num desc: 14 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 175+168+173+183 | Child: 168+177 | Purity: 0.07333333333333333 | Num desc: 5 | Num protos: 10
# 	Proto: 12 0.16666666666666666
# 	Proto: 14 0.1
# 	Proto: 11 0.16666666666666666
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.1
# 	Proto: 15 0.1
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.1
# Node: 175+168+173+183 | Child: 173+161 | Purity: 0.11904761904761903 | Num desc: 5 | Num protos: 10
# 	Proto: 23 0.0
# 	Proto: 20 0.1111111111111111
# 	Proto: 24 0.0
# 	Proto: 28 0.2857142857142857
# 	Proto: 21 0.2857142857142857
# 	Proto: 22 0.0
# 	Proto: 27 0.1111111111111111
# 	Proto: 25 0.1111111111111111
# 	Proto: 26 0.0
# 	Proto: 29 0.2857142857142857
# Node: 175+168+173+183 | Child: 183+159 | Purity: 0.12666666666666665 | Num desc: 3 | Num protos: 10
# 	Proto: 31 0.5
# 	Proto: 34 0.0
# 	Proto: 39 0.0
# 	Proto: 36 0.16666666666666666
# 	Proto: 35 0.0
# 	Proto: 32 0.0
# 	Proto: 30 0.0
# 	Proto: 38 0.0
# 	Proto: 37 0.1
# 	Proto: 33 0.5
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 150+091 | Child: cub_150_Sage_Thrasher | Purity: 0.10222222222222224 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.0
# 	Proto: 9 0.1
# 	Proto: 0 0.0
# 	Proto: 4 0.2
# 	Proto: 2 0.1
# 	Proto: 5 0.1
# 	Proto: 8 0.1111111111111111
# 	Proto: 3 0.1111111111111111
# 	Proto: 6 0.1
# Node: 150+091 | Child: cub_091_Mockingbird | Purity: 0.15333333333333335 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.2
# 	Proto: 11 0.0
# 	Proto: 17 0.1
# 	Proto: 13 0.3
# 	Proto: 19 0.0
# 	Proto: 15 0.1111111111111111
# 	Proto: 16 0.2222222222222222
# 	Proto: 18 0.3
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 175+167 | Child: 175+169 | Purity: 0.0 | Num desc: 11 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 175+167 | Child: cub_167_Hooded_Warbler | Purity: 0.20972222222222223 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.2
# 	Proto: 11 0.0
# 	Proto: 17 0.375
# 	Proto: 13 0.2222222222222222
# 	Proto: 19 0.2
# 	Proto: 15 0.2
# 	Proto: 16 0.2
# 	Proto: 18 0.2
# 	Proto: 10 0.3
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: root | Child: 129+024+067 | Purity: 0.0 | Num desc: 186 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: root | Child: 089+046 | Purity: 0.01 | Num desc: 4 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.1
# 	Proto: 13 0.0
# 	Proto: 19 0.0
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 107+073 | Child: 107+093 | Purity: 0.08 | Num desc: 5 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.3
# 	Proto: 9 0.0
# 	Proto: 0 0.3
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.1
# 	Proto: 8 0.1
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 107+073 | Child: 073+074 | Purity: 0.06694444444444445 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.1111111111111111
# 	Proto: 17 0.1111111111111111
# 	Proto: 13 0.1
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.125
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 084+063 | Child: cub_084_Red_legged_Kittiwake | Purity: 0.125 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.125
# 	Proto: 1 0.125
# 	Proto: 9 0.125
# 	Proto: 0 0.125
# 	Proto: 4 0.125
# 	Proto: 2 0.125
# 	Proto: 5 0.125
# 	Proto: 8 0.125
# 	Proto: 3 0.125
# 	Proto: 6 0.125
# Node: 084+063 | Child: cub_063_Ivory_Gull | Purity: 0.21075396825396825 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.14285714285714285
# 	Proto: 11 0.14285714285714285
# 	Proto: 17 0.2
# 	Proto: 13 0.5
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.5
# 	Proto: 16 0.14285714285714285
# 	Proto: 18 0.125
# 	Proto: 10 0.14285714285714285
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 133+076 | Child: 133+132 | Purity: 0.11222222222222222 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.4
# 	Proto: 9 0.1
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.4
# 	Proto: 5 0.1111111111111111
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.1111111111111111
# Node: 133+076 | Child: cub_076_Dark_eyed_Junco | Purity: 0.24333333333333332 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.4
# 	Proto: 11 0.2222222222222222
# 	Proto: 17 0.3
# 	Proto: 13 0.1
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.3
# 	Proto: 16 0.2
# 	Proto: 18 0.2
# 	Proto: 10 0.3
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 140+017 | Child: 140+139 | Purity: 0.07333333333333333 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.2222222222222222
# 	Proto: 1 0.1111111111111111
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.1
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.3
# Node: 140+017 | Child: cub_017_Cardinal | Purity: 0.09333333333333334 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.3333333333333333
# 	Proto: 11 0.1
# 	Proto: 17 0.1
# 	Proto: 13 0.1
# 	Proto: 19 0.0
# 	Proto: 15 0.0
# 	Proto: 16 0.1
# 	Proto: 18 0.1
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 031+033 | Child: cub_031_Black_billed_Cuckoo | Purity: 0.12166666666666667 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0
| Num desc: 1 | Num protos: 10
# 	Proto: 7 0.3
# 	Proto: 1 0.2222222222222222
# 	Proto: 9 0.2
# 	Proto: 0 0.0
# 	Proto: 4 0.2222222222222222
# 	Proto: 2 0.3
# 	Proto: 5 0.3
# 	Proto: 8 0.4
# 	Proto: 3 0.1111111111111111
# 	Proto: 6 0.1111111111111111
# Node: 095+098 | Child: cub_098_Scott_Oriole | Purity: 0.18444444444444447 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.2
# 	Proto: 11 0.2
# 	Proto: 17 0.3333333333333333
# 	Proto: 13 0.0
# 	Proto: 19 0.1
# 	Proto: 15 0.2
# 	Proto: 16 0.3
# 	Proto: 18 0.1111111111111111
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 051+053 | Child: 051+050 | Purity: 0.09444444444444443 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.1111111111111111
# 	Proto: 1 0.1111111111111111
# 	Proto: 9 0.1
# 	Proto: 0 0.0
# 	Proto: 4 0.1
# 	Proto: 2 0.1
# 	Proto: 5 0.2222222222222222
# 	Proto: 8 0.1
# 	Proto: 3 0.1
# 	Proto: 6 0.0
# Node: 051+053 | Child: cub_053_Western_Grebe | Purity: 0.15000000000000002 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.2
# 	Proto: 11 0.0
# 	Proto: 17 0.2
# 	Proto: 13 0.1
# 	Proto: 19 0.4
# 	Proto: 15 0.1
# 	Proto: 16 0.1
# 	Proto: 18 0.1
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 10
# Node: 036+188 | Child: cub_036_Northern_Flicker | Purity: 0.35623015873015873 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.1111111111111111
# 	Proto: 1 0.6
# 	Proto: 9 0.14285714285714285
# 	Proto: 0 0.6
# 	Proto: 4 0.25
# 	Proto: 2 0.6
# 	Proto: 5 0.6
# 	Proto: 8 0.3333333333333333
# 	Proto: 3 0.125
# 	Proto: 6 0.2
# Node: 036+188 | Child: cub_188_Pileated_Woodpecker | Purity: 0.4822222222222223 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1111111111111111
# 	Proto: 14 0.7
# 	Proto: 11 0.0
# 	Proto: 17 0.4
# 	Proto: 13 0.7
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.7
# 	Proto: 16 0.7
# 	Proto: 18 0.7
# 	Proto: 10 0.7
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 144+143 | Child: 144+142 | Purity: 0.01 | Num desc: 5 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.1
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 144+143 | Child: cub_143_Caspian_Tern | Purity: 0.22222222222222224 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.1
# 	Proto: 11 0.3
# 	Proto: 17 0.3
# 	Proto: 13 0.3
# 	Proto: 19 0.1
# 	Proto: 15 0.3
# 	Proto: 16 0.2
# 	Proto: 18 0.2222222222222222
# 	Proto: 10 0.3
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 129+127 | Child: 129+123 | Purity: 0.08123015873015872 | Num desc: 4 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.125
# 	Proto: 0 0.0
# 	Proto: 4 0.14285714285714285
# 	Proto: 2 0.1111111111111111
# 	Proto: 5 0.0
# 	Proto: 8 0.3333333333333333
# 	Proto: 3 0.0
# 	Proto: 6 0.1
# Node: 129+127 | Child: cub_127_Savannah_Sparrow | Purity: 0.23027777777777772 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.1
# 	Proto: 11 0.125
# 	Proto: 17 0.4444444444444444
# 	Proto: 13 0.0
# 	Proto: 19 0.4444444444444444
# 	Proto: 15 0.4444444444444444
# 	Proto: 16 0.0
# 	Proto: 18 0.4444444444444444
# 	Proto: 10 0.3
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 011+026 | Child: 011+049 | Purity: 0.06428571428571428 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.1
# 	Proto: 4 0.0
# 	Proto: 2 0.1
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.1
# 	Proto: 6 0.14285714285714285
# Node: 011+026 | Child: 026+010 | Purity: 0.10111111111111111 | Num desc: 3 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.1
# 	Proto: 11 0.1
# 	Proto: 17 0.0
# 	Proto: 13 0.2
# 	Proto: 19 0.1
# 	Proto: 15 0.1
# 	Proto: 16 0.2
# 	Proto: 18 0.1
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 133+122 | Child: cub_133_White_throated_Sparrow | Purity: 0.07333333333333333 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.1
# 	Proto: 5 0.1111111111111111
# 	Proto: 8 0.2
# 	Proto: 3 0.1111111111111111
# 	Proto: 6 0.1111111111111111
# Node: 133+122 | Child: cub_122_Harris_Sparrow | Purity: 0.2733333333333333 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.3
# 	Proto: 11 0.1
# 	Proto: 17 0.4444444444444444
# 	Proto: 13 0.4444444444444444
# 	Proto: 19 0.2
# 	Proto: 15 0.1
# 	Proto: 16 0.1
# 	Proto: 18 0.3
# 	Proto: 10 0.4444444444444444
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 175+099 | Child: 175+181 | Purity: 0.0 | Num desc: 28 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 175+099 | Child: cub_099_Ovenbird | Purity: 0.30333333333333334 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.3
# 	Proto: 11 0.3
# 	Proto: 17 0.1
# 	Proto: 13 0.5
# 	Proto: 19 0.5
# 	Proto: 15 0.3
# 	Proto: 16 0.3333333333333333
# 	Proto: 18 0.1
# 	Proto: 10 0.3
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 175+160 | Child: 175+176 | Purity: 0.021111111111111112 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.1111111111111111
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.1
# Node: 175+160 | Child: 160+109 | Purity: 0.11333333333333333 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.1
# 	Proto: 11 0.2
# 	Proto: 17 0.0
# 	Proto: 13 0.3333333333333333
# 	Proto: 19 0.2
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 151+153 | Child: 151+157 | Purity: 0.09722222222222222 | Num desc: 4 | Num protos: 10
# 	Proto: 7 0.1
# 	Proto: 1 0.0
# 	Proto: 9 0.1
# 	Proto: 0 0.125
# 	Proto: 4 0.1
# 	Proto: 2 0.2222222222222222
# 	Proto: 5 0.0
# 	Proto: 8 0.1
# 	Proto: 3 0.125
# 	Proto: 6 0.1
# Node: 151+153 | Child: 153+154 | Purity: 0.10222222222222221 | Num desc: 3 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.1
# 	Proto: 11 0.1
# 	Proto: 17 0.1
# 	Proto: 13 0.2
# 	Proto: 19 0.1111111111111111
# 	Proto: 15 0.0
# 	Proto: 16 0.1
# 	Proto: 18 0.1
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 2
# Node: 051+050 | Child: cub_051_Horned_Grebe | Purity: 0.32222222222222224 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.5
# 	Proto: 1 0.2
# 	Proto: 9 0.16666666666666666
# 	Proto: 0 0.6
# 	Proto: 4 0.5555555555555556
# 	Proto: 2 0.16666666666666666
# 	Proto: 5 0.16666666666666666
# 	Proto: 8 0.16666666666666666
# 	Proto: 3 0.5
# 	Proto: 6 0.2
# Node: 051+050 | Child: cub_050_Eared_Grebe | Purity: 0.1911904761904762 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1111111111111111
# 	Proto: 14 0.1
# 	Proto: 11 0.2222222222222222
# 	Proto: 17 0.2
# 	Proto: 13 0.4
# 	Proto: 19 0.42857142857142855
# 	Proto: 15 0.2
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.25
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 035+055 | Child: 035+048 | Purity: 0.0625 | Num desc: 5 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1
# 	Proto: 9 0.1
# 	Proto: 0 0.1
# 	Proto: 4 0.125
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.2
# Node: 035+055 | Child: cub_055_Evening_Grosbeak | Purity: 0.1766666666666667 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.1
# 	Proto: 11 0.1
# 	Proto: 17 0.3333333333333333
# 	Proto: 13 0.2
# 	Proto: 19 0.1
# 	Proto: 15 0.1
# 	Proto: 16 0.1
# 	Proto: 18 0.3333333333333333
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 065+006 | Child: 065+144 | Purity: 0.01 | Num desc: 16 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 065+006 | Child: 006+071 | Purity: 0.0 | Num desc: 8 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.0
# 	Proto: 17 0.0
# 	Proto: 13 0.0
# 	Proto: 19 0.0
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 128+131 | Child: 128+124 | Purity: 0.07222222222222222 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.1111111111111111
# 	Proto: 1 0.2
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.1111111111111111
# 	Proto: 8 0.0
# 	Proto: 3 0.3
# 	Proto: 6 0.0
# Node: 128+131 | Child: cub_131_Vesper_Sparrow | Purity: 0.2944444444444444 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.2222222222222222
# 	Proto: 11 0.5
# 	Proto: 17 0.5
# 	Proto: 13 0.2222222222222222
# 	Proto: 19 0.2
# 	Proto: 15 0.5
# 	Proto: 16 0.1
# 	Proto: 18 0.1
# 	Proto: 10 0.5
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 024+051 | Child: 024+031 | Purity: 0.0 | Num desc: 14 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 024+051 | Child: 051+052 | Purity: 0.08333333333333333 | Num desc: 4 | Num protos: 10
# 	Proto: 12 0.1
# 	Proto: 14 0.0
# 	Proto: 11 0.2
# 	Proto: 17 0.0
# 	Proto: 13 0.1111111111111111
# 	Proto: 19 0.2222222222222222
# 	Proto: 15 0.0
# 	Proto: 16 0.0
# 	Proto: 18 0.0
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 065+062 | Child: 065+059 | Purity: 0.06666666666666668 | Num desc: 3 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.1111111111111111
# 	Proto: 2 0.4444444444444444
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.1111111111111111
# 	Proto: 6 0.0
# Node: 065+062 | Child: cub_062_Herring_Gull | Purity: 0.135 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.0
# 	Proto: 11 0.2
# 	Proto: 17 0.25
# 	Proto: 13 0.0
# 	Proto: 19 0.2
# 	Proto: 15 0.0
# 	Proto: 16 0.2
# 	Proto: 18 0.1
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 2
# Node: 183+159 | Child: 183+184 | Purity: 0.20000000000000004 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.2
# 	Proto: 9 0.1
# 	Proto: 0 0.2
# 	Proto: 4 0.2
# 	Proto: 2 0.1
# 	Proto: 5 0.1
# 	Proto: 8 0.2
# 	Proto: 3 0.5
# 	Proto: 6 0.2
# Node: 183+159 | Child: cub_159_Black_and_white_Warbler | Purity: 0.27146825396825397 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.42857142857142855
# 	Proto: 11 0.125
# 	Proto: 17 0.2
# 	Proto: 13 0.125
# 	Proto: 19 0.2
# 	Proto: 15 0.5555555555555556
# 	Proto: 16 0.5555555555555556
# 	Proto: 18 0.2
# 	Proto: 10 0.125
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 013+012 | Child: cub_013_Bobolink | Purity: 0.27666666666666667 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.4
# 	Proto: 1 0.0
# 	Proto: 9 0.1
# 	Proto: 0 0.1
# 	Proto: 4 0.4
# 	Proto: 2 0.3333333333333333
# 	Proto: 5 0.4
# 	Proto: 8 0.3
# 	Proto: 3 0.3333333333333333
# 	Proto: 6 0.4
# Node: 013+012 | Child: cub_012_Yellow_headed_Blackbird | Purity: 0.23583333333333334 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.2222222222222222
# 	Proto: 11 0.2222222222222222
# 	Proto: 17 0.125
# 	Proto: 13 0.3333333333333333
# 	Proto: 19 0.3
# 	Proto: 15 0.2222222222222222
# 	Proto: 16 0.3
# 	Proto: 18 0.3333333333333333
# 	Proto: 10 0.1
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 073+074 | Child: cub_073_Blue_Jay | Purity: 0.18694444444444444 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.1111111111111111
# 	Proto: 1 0.125
# 	Proto: 9 0.4
# 	Proto: 0 0.1111111111111111
# 	Proto: 4 0.2
# 	Proto: 2 0.3
# 	Proto: 5 0.1
# 	Proto: 8 0.2
# 	Proto: 3 0.2222222222222222
# 	Proto: 6 0.1
# Node: 073+074 | Child: cub_074_Florida_Jay | Purity: 0.23861111111111116 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.3
# 	Proto: 14 0.2
# 	Proto: 11 0.3
# 	Proto: 17 0.2
# 	Proto: 13 0.375
# 	Proto: 19 0.2
# 	Proto: 15 0.3
# 	Proto: 16 0.2
# 	Proto: 18 0.1111111111111111
# 	Proto: 10 0.2
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 046+087 | Child: cub_046_Gadwall | Purity: 0.12 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.1
# 	Proto: 9 0.2
# 	Proto: 0 0.0
# 	Proto: 4 0.1
# 	Proto: 2 0.2
# 	Proto: 5 0.1
# 	Proto: 8 0.1
# 	Proto: 3 0.1
# 	Proto: 6 0.3
# Node: 046+087 | Child: cub_087_Mallard | Purity: 0.31777777777777777 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.4
# 	Proto: 14 0.16666666666666666
# 	Proto: 11 0.1111111111111111
# 	Proto: 17 0.25
# 	Proto: 13 0.4
# 	Proto: 19 0.4
# 	Proto: 15 0.4
# 	Proto: 16 0.4
# 	Proto: 18 0.4
# 	Proto: 10 0.25
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 095+096 | Child: 095+098 | Purity: 0.07583333333333334 | Num desc: 2 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.1
# 	Proto: 4 0.0
# 	Proto: 2 0.125
# 	Proto: 5 0.1
# 	Proto: 8 0.1111111111111111
# 	Proto: 3 0.2222222222222222
# 	Proto: 6 0.1
# Node: 095+096 | Child: 096+097 | Purity: 0.14666666666666667 | Num desc: 2 | Num protos: 10
# 	Proto: 12 0.2
# 	Proto: 14 0.2
# 	Proto: 11 0.1
# 	Proto: 17 0.2222222222222222
# 	Proto: 13 0.1
# 	Proto: 19 0.1
# 	Proto: 15 0.2222222222222222
# 	Proto: 16 0.1
# 	Proto: 18 0.0
# 	Proto: 10 0.2222222222222222
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 123+113 | Child: cub_123_Henslow_Sparrow | Purity: 0.23361111111111113 | Num desc: 1 | Num protos: 10
# 	Proto: 7 0.2
# 	Proto: 1 0.375
# 	Proto: 9 0.375
# 	Proto: 0 0.2
# 	Proto: 4 0.3
# 	Proto: 2 0.375
# 	Proto: 5 0.1
# 	Proto: 8 0.1111111111111111
# 	Proto: 3 0.2
# 	Proto: 6 0.1
# Node: 123+113 | Child: cub_113_Baird_Sparrow | Purity: 0.2944444444444445 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.4
# 	Proto: 14 0.4
# 	Proto: 11 0.4
# 	Proto: 17 0.2
# 	Proto: 13 0.3
# 	Proto: 19 0.3333333333333333
# 	Proto: 15 0.2
# 	Proto: 16 0.4
# 	Proto: 18 0.2
# 	Proto: 10 0.1111111111111111
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 129+118 | Child: 129+104 | Purity: 0.0 | Num desc: 81 | Num protos: 10
# 	Proto: 7 0.0
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 129+118 | Child: cub_118_House_Sparrow | Purity: 0.13111111111111112 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.1111111111111111
# 	Proto: 14 0.2
# 	Proto: 11 0.0
# 	Proto: 17 0.2
# 	Proto: 13 0.2
# 	Proto: 19 0.0
# 	Proto: 15 0.2
# 	Proto: 16 0.2
# 	Proto: 18 0.2
# 	Proto: 10 0.0
# Number of prototypes in parts_presences:  20
# Part-related (purity>0.5): 0
# Node: 117+114 | Child: 117+115 | Purity: 0.01111111111111111 | Num desc: 4 | Num protos: 10
# 	Proto: 7 0.1111111111111111
# 	Proto: 1 0.0
# 	Proto: 9 0.0
# 	Proto: 0 0.0
# 	Proto: 4 0.0
# 	Proto: 2 0.0
# 	Proto: 5 0.0
# 	Proto: 8 0.0
# 	Proto: 3 0.0
# 	Proto: 6 0.0
# Node: 117+114 | Child: cub_114_Black_throated_Sparrow | Purity: 0.1952380952380952 | Num desc: 1 | Num protos: 10
# 	Proto: 12 0.0
# 	Proto: 14 0.0
# 	Proto: 11 0.2
# 	Proto: 17 0.2
# 	Proto: 13 0.1
# 	Proto: 19 0.16666666666666666
# 	Proto: 15 0.1
# 	Proto: 16 0.2857142857142857
# 	Proto: 18 0.4
# 	Proto: 10 0.5

# %%
print(np.mean(node_wise_purity))
print(np.nanstd(node_wise_purity))
# Out:
# 0.13704631067402806
# 0.08932978613101183
